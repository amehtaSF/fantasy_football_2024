# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np

import gymnasium as gym
from gymnasium import spaces
import numpy as npimport 

import math
import random
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count
from pprint import pprint
from typing import List, Tuple, Dict, Any, Union

import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %% [markdown]
# actions: [QB, RB, WR, TE, K, DEF]
#
# state: [
#     next 15 QB FP
#
#     next 30 RB FP
#
#     next 30 WR FP
#
#     next 15 TE FP
#
#     next 15 Ks FP
#
#     next 15 DEF FP
#
#     team comps: 6 positions * 12 managers
#
#     n until next pick (scaled  /12)
#
#     round (scaled scaled /15)
#
#     ]
#
#
# 120 future players
# current team = 6 spots for QBs, 6 spots for k, 6 spots for def, 9 spots for RB, 9 for WR, 8 for TE (this allows full starters and anything else) = 44
# +1 for picks remaining
# +1 for number of opp picks before next pick
# 166 total
#
# or 330 if i include a variance with each player
#
#
# reward function: sum fpts when starting lineup is full, 0 when starting lineup not full

# %%
df_sleeper = pd.read_csv("data/sleeper/all_players.csv")
# df_sleeper = df_sleeper.loc[df_sleeper["rank_int"] < 50]
print(df_sleeper.shape)
df_sleeper.columns
# Out:
# (3670, 56)
# Index(['sleeper_id', 'injury_notes', 'oddsjam_id', 'search_last_name',
#        'college', 'team_abbr', 'birth_state', 'yahoo_id', 'search_first_name',
#        'pandascore_id', 'years_exp', 'fantasy_positions', 'injury_status',
#        'active', 'team', 'competitions', 'high_school', 'number', 'birth_city',
#        'search_full_name', 'last_name', 'birth_country',
#        'practice_description', 'depth_chart_order', 'fantasy_data_id',
#        'status', 'injury_start_date', 'news_updated', 'age', 'search_rank',
#        'practice_participation', 'opta_id', 'full_name', 'swish_id',
#        'birth_date', 'rotowire_id', 'weight', 'height', 'stats_id', 'espn_id',
#        'metadata', 'player_id', 'first_name', 'sport', 'injury_body_part',
#        'position', 'gsis_id', 'sportradar_id', 'hashtag',
#        'depth_chart_position', 'rotoworld_id', 'Player Id', 'positional_rank',
#        'adp', 'adp_date', 'rank_int'],
#       dtype='object')

# %%
SCORING = {
    'pass_yd': .04,
    'pass_td': 4,
    'pass_2pt': 2,
    'pass_int': -1,
    'rush_yd': .1,
    'rush_td': 6,
    'rush_2pt': 2,
    'rec_rcpt': .5,
    'rec_yd': .1,
    'rec_td': 6,
    'rec_2pt': 2,
    'fg_1_39_made': 3,
    'fg_40_49_made': 4,
    'fg_50_made': 5,
    'xp_missed': -1,
    'xp_made': 1,
    'def_td': 6,
    'def_int': 2,
    'def_sck': 1,
    'def_fum_rec': 2,
    'def_fum_forced': 1,
    'def_sfty': 2,
    'remainder': 1
}

POSITIONS = ['QB', 'RB', 'WR', 'TE', 'K', 'DEF']
STARTER_COMPOSITION = {'QB': 1, 'RB': 2, 'WR': 2, 'FLEX': 2, 'TE': 1, 'K': 1, 'DEF': 1}
TEAM_SIZE = 15

# %%
df_qb_proj = pd.read_csv("data/projections/QB_projections.csv")
df_rb_proj = pd.read_csv("data/projections/RB_projections.csv")
df_wr_proj = pd.read_csv("data/projections/WR_projections.csv")
df_te_proj = pd.read_csv("data/projections/TE_projections.csv")
df_k_proj = pd.read_csv("data/projections/K_projections.csv")
df_def_proj = pd.read_csv("data/projections/DEF_projections.csv")

df_qb_proj = df_qb_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)
df_rb_proj = df_rb_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)
df_wr_proj = df_wr_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)
df_te_proj = df_te_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)
df_k_proj = df_k_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)
df_def_proj = df_def_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)

df_proj = pd.concat([df_qb_proj, df_rb_proj, df_wr_proj, df_te_proj, df_k_proj, df_def_proj])
df_proj.columns

df_proj_agg = df_proj.groupby('sleeper_id')['fpts'].agg(['mean', 'std']).reset_index()
df_proj_agg['sleeper_id'] = df_proj_agg['sleeper_id'].astype(str)


df_players = df_proj_agg.merge(df_sleeper.loc[:, ['sleeper_id', 'full_name', 'position', 'team']], 
                                on='sleeper_id', 
                                how='left')
print(df_players.shape)
df_players = df_players.dropna(subset=['mean', 'std'])
print(df_players.shape)
# Out:
# (796, 6)
# (647, 6)

# %%
# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display
plt.ion()

# if GPU is to be used
device = torch.device(
    "cuda" if torch.cuda.is_available() else
    "mps" if torch.backends.mps.is_available() else
    "cpu"
)

# %% [markdown]
# # Init environment and RL network

# %%
from rl_env import DraftEnv

from sarsa import (
    SARSA, 
    NUM_MGRS, NUM_DRAFT_ROUNDS, ACTION_SPACE_DIM, 
    STATE_SPACE_DIM, STARTER_COMPOSITION
    )

# %%
# BATCH_SIZE is the number of transitions sampled from the replay buffer
# GAMMA is the discount factor as mentioned in the previous section
# EPS_START is the starting value of epsilon
# EPS_END is the final value of epsilon
# EPS_DECAY controls the rate of exponential decay of epsilon, higher means a slower decay
# TAU is the update rate of the target network
# LR is the learning rate of the ``AdamW`` optimizer
BATCH_SIZE = 128
GAMMA = 0.99
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 1000
TAU = 0.005
LR = 1e-4

env = DraftEnv(df_players)

# Get number of actions from gym action space
n_actions = env.action_space.n
# Get the number of state observations
state, info = env.reset()
n_observations = len(state)

# mgr_networks = {i: {} for i in range(NUM_MGRS)}
# for mgr in mgr_networks.values():
#     mgr["policy"] = DQN(n_observations, n_actions).to(device)
#     mgr["target"] = DQN(n_observations, n_actions).to(device)
#     mgr["optimizer"] = optim.AdamW(mgr["policy"].parameters(), lr=LR, amsgrad=True)
#     mgr["memory"] = ReplayMemory(1000)
#     mgr["target"].load_state_dict(mgr["policy"].state_dict())

steps_done = 0

policy_net = DQN(n_observations, n_actions).to(device)
target_net = DQN(n_observations, n_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())
optimizer = optim.AdamW(policy_net.parameters(), lr=LR, amsgrad=True)
memory = ReplayMemory(10000)

# %%
# BATCH_SIZE is the number of transitions sampled from the replay buffer
# GAMMA is the discount factor as mentioned in the previous section
# EPS_START is the starting value of epsilon
# EPS_END is the final value of epsilon
# EPS_DECAY controls the rate of exponential decay of epsilon, higher means a slower decay
# TAU is the update rate of the target network
# LR is the learning rate of the ``AdamW`` optimizer
BATCH_SIZE = 128
GAMMA = 0.99
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 10000
TAU = 0.005
LR = 1e-4

env = DraftEnv(df_players)

# Get number of actions from gym action space
n_actions = env.action_space.n
# Get the number of state observations
state, info = env.reset()
n_observations = len(state)


steps_done = 0

# %%
def select_action(state, policy_net, env, device):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            # t.max(1) will return the largest column value of each row.
            # second column on max result is index of where max element was
            # found, so we pick action with the larger expected reward.
            return policy_net(state).max(1).indices.view(1, 1)
    else:
        if random.random() < 0.5:
            return torch.tensor([[env.action_space.sample()]], device=device, dtype=torch.long)
        else:
            return torch.tensor([[env.reasonable_option()]], device=device, dtype=torch.long)


def optimize_model(memory, policy_net, target_net, optimizer):
    if len(memory) < BATCH_SIZE:
        return 
    transitions = memory.sample(BATCH_SIZE)
    # Transpose the batch (see https://stackoverflow.com/a/19343/3343043 for
    # detailed explanation). This converts batch-array of Transitions
    # to Transition of batch-arrays.
    batch = Transition(*zip(*transitions))

    # Compute a mask of non-final states and concatenate the batch elements
    # (a final state would've been the one after which simulation ended)
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
    # columns of actions taken. These are the actions which would've been taken
    # for each batch state according to policy_net
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    # Compute V(s_{t+1}) for all next states.
    # Expected values of actions for non_final_next_states are computed based
    # on the "older" target_net; selecting their best reward with max(1).values
    # This is merged based on the mask, such that we'll have either the expected
    # state value or 0 in case the state was final.
    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    with torch.no_grad():
        next_state_values[non_final_mask] = target_net(non_final_next_states).max(1).values
    # Compute the expected Q values
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Compute Huber loss
    criterion = nn.SmoothL1Loss()
    loss = criterion(state_action_values, expected_state_action_values.unsqueeze(1))

    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    # In-place gradient clipping
    torch.nn.utils.clip_grad_value_(policy_net.parameters(), 100)
    optimizer.step()
    
    return loss

# %%
if torch.cuda.is_available() or torch.backends.mps.is_available():
    num_episodes = 10000
    # num_episodes = 50
else:
    num_episodes = 50

drafts = []
losses = []
rewards = []

# losses = np.zeros(num_episodes * NUM_DRAFT_ROUNDS)
# rewards = np.zeros(num_episodes * NUM_DRAFT_ROUNDS)

# %%
RL_MGR = 1

for i_episode in range(num_episodes):
    
    env.reset()
    print(f"Episode: {i_episode}")
    
    for _, row in env.draft.iterrows():
        
        if row['mgr'] == RL_MGR:
        
            state = torch.tensor(env.get_state(), dtype=torch.float32, device=device).unsqueeze(0)
            action = select_action(state, policy_net, env, device)
            observation, reward, terminated, info = env.step(action.item())
            reward = torch.tensor([reward], dtype=torch.float32, device=device)

            done = terminated 
        
            if terminated:
                next_state = None
            else:
                next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)

            # Store the transition in memory
            memory.push(state, action, next_state, reward)
        
            # Move to the next state
            state = next_state
            
            loss = optimize_model(memory, policy_net, target_net, optimizer)
            

            losses.append(loss.item() if loss is not None else 0)
            rewards.append(reward.item())
            
            drafts.append(env.draft.copy())
            
        else:
            env.step(env.reasonable_option())
            
    # print(f"Running average reward:{np.sum(rewards[counter-10:counter])}")
    # print(f"Running average loss: {np.mean(losses[counter-10:counter])}")
    print(f"Running average reward:{np.sum(rewards[-15:])}")
    print(f"Running average loss: {np.mean(losses[-15:])}")
    eps_threshold = EPS_END + (EPS_START - EPS_END) * math.exp(-1. * steps_done / EPS_DECAY)
    print(f"Epsilon: {eps_threshold}")

        
print('Complete')
# Out:
# Episode: 0
# Running average reward:3.0649932622909546
# Running average loss: 0.0
# Epsilon: 0.8987259557720543
# Episode: 1
# Running average reward:1.1174814105033875
# Running average loss: 0.0
# Epsilon: 0.8974538211778671
# Episode: 2
# Running average reward:2.6775987446308136
# Running average loss: 0.0
# Epsilon: 0.896183593355135
# Episode: 3
# Running average reward:1.1632568165659904
# Running average loss: 0.0
# Epsilon: 0.894915269445845
# Episode: 4
# Running average reward:1.8032822608947754
# Running average loss: 0.0
# Epsilon: 0.8936488465962676
# Episode: 5
# Running average reward:1.471555896103382
# Running average loss: 0.0
# Epsilon: 0.8923843219569512
# Episode: 6
# Running average reward:2.189922019839287
# Running average loss: 0.0
# Epsilon: 0.8911216926827145
# Episode: 7
# Running average reward:1.4195832908153534
# Running average loss: 0.0
# Epsilon: 0.8898609559326409
# Episode: 8
# Running average reward:1.6809300258755684
# Running average loss: 0.03965023308992386
# Epsilon: 0.8886021088700727
# Episode: 9
# Running average reward:1.0803036540746689
# Running average loss: 0.011860573850572109
# Epsilon: 0.8873451486626033
# Episode: 10
# Running average reward:2.632067948579788
# Running average loss: 0.00575676211155951
# Epsilon: 0.8860900724820715
# Episode: 11
# Running average reward:1.4869189858436584
# Running average loss: 0.004093582788482308
# Epsilon: 0.8848368775045556
# Episode: 12
# Running average reward:2.342769533395767
# Running average loss: 0.0032354798167943954
# Epsilon: 0.8835855609103663
# Episode: 13
# Running average reward:1.5715973526239395
# Running average loss: 0.0023877406492829323
# Epsilon: 0.8823361198840407
# Episode: 14
# Running average reward:2.1929022073745728
# Running average loss: 0.001996628334745765
# Epsilon: 0.881088551614336
# Episode: 15
# Running average reward:1.4475468918681145
# Running average loss: 0.0014946589712053538
# Epsilon: 0.879842853294223
# Episode: 16
# Running average reward:2.1234932839870453
# Running average loss: 0.0012428001500666142
# Epsilon: 0.8785990221208799
# Episode: 17
# Running average reward:1.3495165556669235
# Running average loss: 0.0010335513507016003
# Epsilon: 0.8773570552956863
# Episode: 18
# Running average reward:2.4085428565740585
# Running average loss: 0.0009735609986819327
# Epsilon: 0.8761169500242162
# Episode: 19
# Running average reward:1.7383272796869278
# Running average loss: 0.0009428720513824373
# Epsilon: 0.874878703516232
# Episode: 20
# Running average reward:2.705621376633644
# Running average loss: 0.0008867935743182897
# Epsilon: 0.8736423129856787
# Episode: 21
# Running average reward:1.2891678512096405
# Running average loss: 0.0007922044780571014
# Epsilon: 0.8724077756506773
# Episode: 22
# Running average reward:2.9793277233839035
# Running average loss: 0.0017069469671696425
# Epsilon: 0.8711750887335178
# Episode: 23
# Running average reward:1.6055909544229507
# Running average loss: 0.0016834908514283598
# Epsilon: 0.8699442494606546
# Episode: 24
# Running average reward:2.779900163412094
# Running average loss: 0.0011472128448076547
# Epsilon: 0.8687152550626985
# Episode: 25
# Running average reward:1.0560431852936745
# Running average loss: 0.0009884881495963783
# Epsilon: 0.8674881027744118
# Episode: 26
# Running average reward:2.8599241375923157
# Running average loss: 0.000842067605117336
# Epsilon: 0.8662627898347011
# Episode: 27
# Running average reward:1.3196088075637817
# Running average loss: 0.0007182228117017075
# Epsilon: 0.8650393134866119
# Episode: 28
# Running average reward:2.180653288960457
# Running average loss: 0.000608824664959684
# Epsilon: 0.863817670977322
# Episode: 29
# Running average reward:1.4482188820838928
# Running average loss: 0.0005508764006663114
# Epsilon: 0.862597859558135
# Episode: 30
# Running average reward:1.8731666803359985
# Running average loss: 0.000507073852350004
# Epsilon: 0.8613798764844748
# Episode: 31
# Running average reward:1.5311702266335487
# Running average loss: 0.0004312020173529163
# Epsilon: 0.8601637190158791
# Episode: 32
# Running average reward:2.26484152674675
# Running average loss: 0.0005193906225031241
# Epsilon: 0.8589493844159929
# Episode: 33
# Running average reward:1.2713944017887115
# Running average loss: 0.00040883683832362296
# Epsilon: 0.8577368699525629
# Episode: 34
# Running average reward:2.2635080367326736
# Running average loss: 0.00041003103251568973
# Epsilon: 0.856526172897431
# Episode: 35
# Running average reward:1.3007554337382317
# Running average loss: 0.0004143640020629391
# Epsilon: 0.8553172905265286
# Episode: 36
# Running average reward:1.8415669351816177
# Running average loss: 0.00037110591074451804
# Epsilon: 0.8541102201198695
# Episode: 37
# Running average reward:1.3672286048531532
# Running average loss: 0.00039981079753488303
# Epsilon: 0.8529049589615448
# Episode: 38
# Running average reward:3.22649148106575
# Running average loss: 0.0007207546499557793
# Epsilon: 0.8517015043397166
# Episode: 39
# Running average reward:1.5858916565775871
# Running average loss: 0.0006426945998100564
# Epsilon: 0.8504998535466114
# Episode: 40
# Running average reward:2.1512241065502167
# Running average loss: 0.0005602640594588593
# Epsilon: 0.8493000038785143
# Episode: 41
# Running average reward:1.531683050096035
# Running average loss: 0.000587458029622212
# Epsilon: 0.8481019526357633
# Episode: 42
# Running average reward:2.5946004986763
# Running average loss: 0.000603232512366958
# Epsilon: 0.8469056971227423
# Episode: 43
# Running average reward:1.9095162451267242
# Running average loss: 0.000555494223954156
# Epsilon: 0.845711234647876
# Episode: 44
# Running average reward:2.503374144434929
# Running average loss: 0.00048715069715399295
# Epsilon: 0.8445185625236233
# Episode: 45
# Running average reward:1.30441465228796
# Running average loss: 0.0005069779901532457
# Epsilon: 0.8433276780664717
# Episode: 46
# Running average reward:2.913602203130722
# Running average loss: 0.0004136293660849333
# Epsilon: 0.8421385785969303
# Episode: 47
# Running average reward:1.5339995473623276
# Running average loss: 0.0004172055254457518
# Epsilon: 0.8409512614395249
# Episode: 48
# Running average reward:2.4279467910528183
# Running average loss: 0.00035637445689644663
# Epsilon: 0.8397657239227914
# Episode: 49
# Running average reward:1.414054460823536
# Running average loss: 0.00040318800893146545
# Epsilon: 0.8385819633792699
# Episode: 50
# Running average reward:2.441812813282013
# Running average loss: 0.00044192433706484734
# Epsilon: 0.8373999771454989
# Episode: 51
# Running average reward:1.6495967656373978
# Running average loss: 0.00040904386842157694
# Epsilon: 0.8362197625620084
# Episode: 52
# Running average reward:3.1237647980451584
# Running average loss: 0.0004836680687731132
# Epsilon: 0.8350413169733155
# Episode: 53
# Running average reward:1.5301482304930687
# Running average loss: 0.0008094220625935123
# Epsilon: 0.8338646377279169
# Episode: 54
# Running average reward:2.571534350514412
# Running average loss: 0.0006167128798551857
# Epsilon: 0.8326897221782839
# Episode: 55
# Running average reward:1.8802938535809517
# Running average loss: 0.0006206614838447422
# Epsilon: 0.831516567680856
# Episode: 56
# Running average reward:3.1401048749685287
# Running average loss: 0.0005704187031369656
# Epsilon: 0.830345171596035
# Episode: 57
# Running average reward:1.3213893994688988
# Running average loss: 0.0005342702002963051
# Epsilon: 0.8291755312881794
# Episode: 58
# Running average reward:2.6047586798667908
# Running average loss: 0.0005138066248036921
# Epsilon: 0.8280076441255979
# Episode: 59
# Running average reward:1.8066353648900986
# Running average loss: 0.0004930726456223056
# Epsilon: 0.826841507480544
# Episode: 60
# Running average reward:1.8723215013742447
# Running average loss: 0.0004340626503108069
# Epsilon: 0.8256771187292096
# Episode: 61
# Running average reward:1.4901278614997864
# Running average loss: 0.00044593692873604593
# Epsilon: 0.8245144752517195
# Episode: 62
# Running average reward:3.304381161928177
# Running average loss: 0.0003913940105121583
# Epsilon: 0.8233535744321255
# Episode: 63
# Running average reward:1.5359925329685211
# Running average loss: 0.0004879419575445354
# Epsilon: 0.8221944136584003
# Episode: 64
# Running average reward:2.6918877959251404
# Running average loss: 0.00047019485791679474
# Epsilon: 0.8210369903224315
# Episode: 65
# Running average reward:1.7475518584251404
# Running average loss: 0.00036978994467062876
# Epsilon: 0.8198813018200163
# Episode: 66
# Running average reward:2.571359544992447
# Running average loss: 0.00042597511783242225
# Epsilon: 0.8187273455508549
# Episode: 67
# Running average reward:1.5848539918661118
# Running average loss: 0.0004228460427839309
# Epsilon: 0.8175751189185453
# Episode: 68
# Running average reward:1.972520798444748
# Running average loss: 0.000439403040218167
# Epsilon: 0.8164246193305772
# Episode: 69
# Running average reward:1.612542249262333
# Running average loss: 0.00041699188877828417
# Epsilon: 0.8152758441983258
# Episode: 70
# Running average reward:2.2220814675092697
# Running average loss: 0.0003766077104955912
# Epsilon: 0.8141287909370467
# Episode: 71
# Running average reward:1.152131475508213
# Running average loss: 0.00041352185944560916
# Epsilon: 0.8129834569658697
# Episode: 72
# Running average reward:2.999916732311249
# Running average loss: 0.00042218468443024906
# Epsilon: 0.8118398397077926
# Episode: 73
# Running average reward:1.2304372489452362
# Running average loss: 0.00038734739064238966
# Epsilon: 0.8106979365896764
# Episode: 74
# Running average reward:1.898848444223404
# Running average loss: 0.00037594985333271324
# Epsilon: 0.8095577450422383
# Episode: 75
# Running average reward:1.5671968758106232
# Running average loss: 0.00040620573854539544
# Epsilon: 0.808419262500047
# Episode: 76
# Running average reward:2.7288099378347397
# Running average loss: 0.0004141602519666776
# Epsilon: 0.8072824864015165
# Episode: 77
# Running average reward:1.9934168756008148
# Running average loss: 0.0003369814599864185
# Epsilon: 0.8061474141888997
# Episode: 78
# Running average reward:2.6642052978277206
# Running average loss: 0.00041096707573160527
# Epsilon: 0.8050140433082839
# Episode: 79
# Running average reward:1.1404990181326866
# Running average loss: 0.0004984200379112736
# Epsilon: 0.8038823712095838
# Episode: 80
# Running average reward:2.778200179338455
# Running average loss: 0.0003761109139304608
# Epsilon: 0.8027523953465373
# Episode: 81
# Running average reward:0.9494267031550407
# Running average loss: 0.00035956918727606533
# Epsilon: 0.8016241131766978
# Episode: 82
# Running average reward:3.0558206886053085
# Running average loss: 0.0003843574406346306
# Epsilon: 0.80049752216143
# Episode: 83
# Running average reward:0.9211076647043228
# Running average loss: 0.00037857114512007684
# Epsilon: 0.7993726197659037
# Episode: 84
# Running average reward:3.542039230465889
# Running average loss: 0.0004434920381754637
# Epsilon: 0.798249403459088
# Episode: 85
# Running average reward:2.1492438167333603
# Running average loss: 0.00044829269754700365
# Epsilon: 0.7971278707137457
# Episode: 86
# Running average reward:2.5869625210762024
# Running average loss: 0.00046858814312145114
# Epsilon: 0.7960080190064277
# Episode: 87
# Running average reward:1.8731594383716583
# Running average loss: 0.00047246777394320815
# Epsilon: 0.7948898458174672
# Episode: 88
# Running average reward:2.2673617899417877
# Running average loss: 0.0005007731728255749
# Epsilon: 0.7937733486309742
# Episode: 89
# Running average reward:1.5014864355325699
# Running average loss: 0.0004445156140718609
# Epsilon: 0.7926585249348292
# Episode: 90
# Running average reward:2.485302209854126
# Running average loss: 0.0004258665518136695
# Epsilon: 0.7915453722206788
# Episode: 91
# Running average reward:1.5822491347789764
# Running average loss: 0.0003711250057676807
# Epsilon: 0.7904338879839287
# Episode: 92
# Running average reward:2.8966328352689743
# Running average loss: 0.00039090140926418827
# Epsilon: 0.7893240697237388
# Episode: 93
# Running average reward:1.3021197095513344
# Running average loss: 0.00039146005583461373
# Epsilon: 0.7882159149430177
# Episode: 94
# Running average reward:2.3309051394462585
# Running average loss: 0.0003925588389392942
# Epsilon: 0.7871094211484168
# Episode: 95
# Running average reward:1.8171200454235077
# Running average loss: 0.00038919367070775477
# Epsilon: 0.7860045858503243
# Episode: 96
# Running average reward:2.530978783965111
# Running average loss: 0.00040334785007871686
# Epsilon: 0.7849014065628604
# Episode: 97
# Running average reward:1.9033271223306656
# Running average loss: 0.0004287036776077002
# Epsilon: 0.7837998808038715
# Episode: 98
# Running average reward:3.0665020793676376
# Running average loss: 0.0004889353789621964
# Epsilon: 0.782700006094924
# Episode: 99
# Running average reward:1.650350421667099
# Running average loss: 0.0004620248335413635
# Epsilon: 0.7816017799612992
# Episode: 100
# Running average reward:2.223091810941696
# Running average loss: 0.0004187906510196626
# Epsilon: 0.7805051999319879
# Episode: 101
# Running average reward:1.659800462424755
# Running average loss: 0.00038081692473497243
# Epsilon: 0.7794102635396848
# Episode: 102
# Running average reward:2.7867115885019302
# Running average loss: 0.0003141918306937441
# Epsilon: 0.7783169683207822
# Episode: 103
# Running average reward:1.373726300895214
# Running average loss: 0.0003860230557620525
# Epsilon: 0.7772253118153657
# Episode: 104
# Running average reward:2.5286606550216675
# Running average loss: 0.0003577945957658812
# Epsilon: 0.7761352915672076
# Episode: 105
# Running average reward:1.1706089451909065
# Running average loss: 0.0004039032151922584
# Epsilon: 0.7750469051237618
# Episode: 106
# Running average reward:2.425133928656578
# Running average loss: 0.0003654226311482489
# Epsilon: 0.7739601500361584
# Episode: 107
# Running average reward:1.880649372935295
# Running average loss: 0.00032695916161173955
# Epsilon: 0.772875023859198
# Episode: 108
# Running average reward:3.5948482900857925
# Running average loss: 0.0003232213464798406
# Epsilon: 0.7717915241513463
# Episode: 109
# Running average reward:1.4118334650993347
# Running average loss: 0.00039147412753663956
# Epsilon: 0.7707096484747286
# Episode: 110
# Running average reward:2.0472793132066727
# Running average loss: 0.00033085692557506264
# Epsilon: 0.7696293943951237
# Episode: 111
# Running average reward:1.7913904935121536
# Running average loss: 0.00034628344292286783
# Epsilon: 0.7685507594819599
# Episode: 112
# Running average reward:2.193981185555458
# Running average loss: 0.00040654506592545657
# Epsilon: 0.7674737413083081
# Episode: 113
# Running average reward:1.0644258111715317
# Running average loss: 0.0004098134551895782
# Epsilon: 0.7663983374508769
# Episode: 114
# Running average reward:2.0879849940538406
# Running average loss: 0.00036811674945056436
# Epsilon: 0.7653245454900073
# Episode: 115
# Running average reward:1.1134138703346252
# Running average loss: 0.0003604624449508265
# Epsilon: 0.7642523630096667
# Episode: 116
# Running average reward:2.254401206970215
# Running average loss: 0.0003908000799128786
# Epsilon: 0.7631817875974443
# Episode: 117
# Running average reward:1.8916315287351608
# Running average loss: 0.0004292978526791558
# Epsilon: 0.7621128168445448
# Episode: 118
# Running average reward:2.3073283582925797
# Running average loss: 0.00040013389370869846
# Epsilon: 0.7610454483457837
# Episode: 119
# Running average reward:1.753007858991623
# Running average loss: 0.0003741331718629226
# Epsilon: 0.7599796796995812
# Episode: 120
# Running average reward:2.3120642006397247
# Running average loss: 0.00038355487631633876
# Epsilon: 0.7589155085079576
# Episode: 121
# Running average reward:1.5716870948672295
# Running average loss: 0.00037480233586393295
# Epsilon: 0.7578529323765273
# Episode: 122
# Running average reward:2.872954472899437
# Running average loss: 0.0003288252715719864
# Epsilon: 0.7567919489144935
# Episode: 123
# Running average reward:1.487135373055935
# Running average loss: 0.0004122262937016785
# Epsilon: 0.7557325557346428
# Episode: 124
# Running average reward:2.188509374856949
# Running average loss: 0.00039045776939019563
# Epsilon: 0.7546747504533403
# Episode: 125
# Running average reward:1.566981203854084
# Running average loss: 0.0003640114009613171
# Epsilon: 0.7536185306905236
# Episode: 126
# Running average reward:2.2904592007398605
# Running average loss: 0.00036247820826247336
# Epsilon: 0.7525638940696978
# Episode: 127
# Running average reward:1.172922931611538
# Running average loss: 0.00036477964895311745
# Epsilon: 0.75151083821793
# Episode: 128
# Running average reward:3.188300237059593
# Running average loss: 0.00033682526263874025
# Epsilon: 0.7504593607658443
# Episode: 129
# Running average reward:1.8391187638044357
# Running average loss: 0.0003797636512899771
# Epsilon: 0.7494094593476157
# Episode: 130
# Running average reward:2.5452404767274857
# Running average loss: 0.000402456580195576
# Epsilon: 0.7483611316009656
# Episode: 131
# Running average reward:1.4091055765748024
# Running average loss: 0.00039809886366128924
# Epsilon: 0.7473143751671564
# Episode: 132
# Running average reward:2.5994600653648376
# Running average loss: 0.0004106007516384125
# Epsilon: 0.7462691876909855
# Episode: 133
# Running average reward:1.2997643798589706
# Running average loss: 0.0003771630086703226
# Epsilon: 0.7452255668207806
# Episode: 134
# Running average reward:2.1542945504188538
# Running average loss: 0.00036796134954784063
# Epsilon: 0.7441835102083942
# Episode: 135
# Running average reward:1.3776513412594795
# Running average loss: 0.0003531677735736594
# Epsilon: 0.7431430155091988
# Episode: 136
# Running average reward:2.691849857568741
# Running average loss: 0.000406967120943591
# Epsilon: 0.7421040803820808
# Episode: 137
# Running average reward:1.4021068811416626
# Running average loss: 0.00037539572222158315
# Epsilon: 0.7410667024894354
# Episode: 138
# Running average reward:2.3384581208229065
# Running average loss: 0.0003991636011051014
# Epsilon: 0.7400308794971622
# Episode: 139
# Running average reward:1.2114963382482529
# Running average loss: 0.00037105494411662223
# Epsilon: 0.738996609074659
# Episode: 140
# Running average reward:2.7572027891874313
# Running average loss: 0.0003638321388280019
# Epsilon: 0.737963888894817
# Episode: 141
# Running average reward:1.3379020020365715
# Running average loss: 0.000332586606964469
# Epsilon: 0.7369327166340152
# Episode: 142
# Running average reward:3.3613039702177048
# Running average loss: 0.0003952482016757131
# Epsilon: 0.7359030899721155
# Episode: 143
# Running average reward:1.6022747308015823
# Running average loss: 0.0003778284095460549
# Epsilon: 0.7348750065924577
# Episode: 144
# Running average reward:3.1812379211187363
# Running average loss: 0.00044027688272763044
# Epsilon: 0.7338484641818537
# Episode: 145
# Running average reward:1.5938101261854172
# Running average loss: 0.00035121268301736565
# Epsilon: 0.7328234604305826
# Episode: 146
# Running average reward:2.063571348786354
# Running average loss: 0.0003396128275198862
# Epsilon: 0.7317999930323854
# Episode: 147
# Running average reward:1.47712392359972
# Running average loss: 0.00037889499217271807
# Epsilon: 0.7307780596844603
# Episode: 148
# Running average reward:2.3192874789237976
# Running average loss: 0.0004070231632795185
# Epsilon: 0.7297576580874566
# Episode: 149
# Running average reward:1.2278064116835594
# Running average loss: 0.000361714672180824
# Epsilon: 0.7287387859454705
# Episode: 150
# Running average reward:2.721734270453453
# Running average loss: 0.000396860163891688
# Epsilon: 0.7277214409660391
# Episode: 151
# Running average reward:1.096508502960205
# Running average loss: 0.0004154909023782238
# Epsilon: 0.7267056208601357
# Episode: 152
# Running average reward:2.7446959614753723
# Running average loss: 0.0003836151241557673
# Epsilon: 0.7256913233421648
# Episode: 153
# Running average reward:1.6208005249500275
# Running average loss: 0.00040394530369667334
# Epsilon: 0.7246785461299563
# Episode: 154
# Running average reward:2.3024525940418243
# Running average loss: 0.00039393788902089
# Epsilon: 0.7236672869447615
# Episode: 155
# Running average reward:1.7564160972833633
# Running average loss: 0.0004162572760833427
# Epsilon: 0.7226575435112463
# Episode: 156
# Running average reward:2.3145506978034973
# Running average loss: 0.00040009923686739056
# Epsilon: 0.7216493135574878
# Episode: 157
# Running average reward:1.8863823264837265
# Running average loss: 0.000347535964101553
# Epsilon: 0.7206425948149683
# Episode: 158
# Running average reward:3.1151017546653748
# Running average loss: 0.0004469853651244193
# Epsilon: 0.71963738501857
# Episode: 159
# Running average reward:1.5729532912373543
# Running average loss: 0.0003547891290509142
# Epsilon: 0.7186336819065705
# Episode: 160
# Running average reward:2.427622839808464
# Running average loss: 0.00036619659222196787
# Epsilon: 0.7176314832206372
# Episode: 161
# Running average reward:1.4683718755841255
# Running average loss: 0.0004253472143318504
# Epsilon: 0.716630786705823
# Episode: 162
# Running average reward:3.1131776720285416
# Running average loss: 0.00039890328189358116
# Epsilon: 0.7156315901105601
# Episode: 163
# Running average reward:1.3842721655964851
# Running average loss: 0.0004436046758200973
# Epsilon: 0.7146338911866557
# Episode: 164
# Running average reward:2.1307420879602432
# Running average loss: 0.0003659229609183967
# Epsilon: 0.7136376876892869
# Episode: 165
# Running average reward:1.491874821484089
# Running average loss: 0.00037989720585756003
# Epsilon: 0.7126429773769953
# Episode: 166
# Running average reward:2.188021630048752
# Running average loss: 0.0003655285108834505
# Epsilon: 0.7116497580116825
# Episode: 167
# Running average reward:2.0845214128494263
# Running average loss: 0.0004014695587102324
# Epsilon: 0.7106580273586042
# Episode: 168
# Running average reward:1.9666897431015968
# Running average loss: 0.0003733592253411189
# Epsilon: 0.7096677831863663
# Episode: 169
# Running average reward:1.5666464865207672
# Running average loss: 0.00047845375374890866
# Epsilon: 0.7086790232669189
# Episode: 170
# Running average reward:3.2434815615415573
# Running average loss: 0.0004499846399994567
# Epsilon: 0.7076917453755516
# Episode: 171
# Running average reward:1.173711158335209
# Running average loss: 0.0003733565943548456
# Epsilon: 0.7067059472908889
# Episode: 172
# Running average reward:1.9180416017770767
# Running average loss: 0.0003990457131294534
# Epsilon: 0.7057216267948846
# Episode: 173
# Running average reward:2.0379342436790466
# Running average loss: 0.00045137707638787106
# Epsilon: 0.7047387816728173
# Episode: 174
# Running average reward:2.2767671793699265
# Running average loss: 0.0004491580359172076
# Epsilon: 0.7037574097132849
# Episode: 175
# Running average reward:1.583001270890236
# Running average loss: 0.000448662496637553
# Epsilon: 0.7027775087082002
# Episode: 176
# Running average reward:2.671239495277405
# Running average loss: 0.0004334351746365428
# Epsilon: 0.7017990764527856
# Episode: 177
# Running average reward:1.1275350600481033
# Running average loss: 0.0004180605261353776
# Epsilon: 0.7008221107455679
# Episode: 178
# Running average reward:2.191185772418976
# Running average loss: 0.00045650610991287977
# Epsilon: 0.6998466093883738
# Episode: 179
# Running average reward:1.185701496899128
# Running average loss: 0.0004603676294209436
# Epsilon: 0.6988725701863252
# Episode: 180
# Running average reward:2.3525402545928955
# Running average loss: 0.0004348736518295482
# Epsilon: 0.6978999909478332
# Episode: 181
# Running average reward:1.7048275247216225
# Running average loss: 0.0004160885349847376
# Epsilon: 0.6969288694845942
# Episode: 182
# Running average reward:1.9239619597792625
# Running average loss: 0.0004642848070943728
# Epsilon: 0.6959592036115844
# Episode: 183
# Running average reward:1.238092228770256
# Running average loss: 0.0005115113192005083
# Epsilon: 0.6949909911470552
# Episode: 184
# Running average reward:1.9399093091487885
# Running average loss: 0.0004548388853436336
# Epsilon: 0.6940242299125282
# Episode: 185
# Running average reward:2.3368531614542007
# Running average loss: 0.0005232251598499716
# Epsilon: 0.6930589177327903
# Episode: 186
# Running average reward:2.539444237947464
# Running average loss: 0.0005322076583979651
# Epsilon: 0.6920950524358885
# Episode: 187
# Running average reward:1.2278183549642563
# Running average loss: 0.000552875196444802
# Epsilon: 0.6911326318531257
# Episode: 188
# Running average reward:2.327662080526352
# Running average loss: 0.0005127926880959422
# Epsilon: 0.6901716538190549
# Episode: 189
# Running average reward:1.3856277912855148
# Running average loss: 0.00047091366432141515
# Epsilon: 0.6892121161714753
# Episode: 190
# Running average reward:2.8716955184936523
# Running average loss: 0.0004282623965991661
# Epsilon: 0.6882540167514267
# Episode: 191
# Running average reward:1.6835956797003746
# Running average loss: 0.0005063971184426919
# Epsilon: 0.6872973534031851
# Episode: 192
# Running average reward:2.488802582025528
# Running average loss: 0.0004909396782750263
# Epsilon: 0.6863421239742576
# Episode: 193
# Running average reward:1.6374257802963257
# Running average loss: 0.0005026965605793521
# Epsilon: 0.6853883263153774
# Episode: 194
# Running average reward:3.138247162103653
# Running average loss: 0.00043419159192126244
# Epsilon: 0.6844359582804995
# Episode: 195
# Running average reward:1.6286323517560959
# Running average loss: 0.00044129848247393967
# Epsilon: 0.6834850177267954
# Episode: 196
# Running average reward:2.500984340906143
# Running average loss: 0.00043307660962454975
# Epsilon: 0.6825355025146485
# Episode: 197
# Running average reward:1.894502267241478
# Running average loss: 0.0004526594595517963
# Epsilon: 0.6815874105076489
# Episode: 198
# Running average reward:2.629230797290802
# Running average loss: 0.0005201352352742106
# Epsilon: 0.6806407395725895
# Episode: 199
# Running average reward:1.7213192582130432
# Running average loss: 0.00043687255820259454
# Epsilon: 0.6796954875794602
# Episode: 200
# Running average reward:2.3190755248069763
# Running average loss: 0.00043210787698626517
# Epsilon: 0.6787516524014436
# Episode: 201
# Running average reward:1.6794096305966377
# Running average loss: 0.0005969349644146859
# Epsilon: 0.6778092319149103
# Episode: 202
# Running average reward:2.5671187341213226
# Running average loss: 0.0004789571394212544
# Epsilon: 0.6768682239994135
# Episode: 203
# Running average reward:1.4887753427028656
# Running average loss: 0.0005046663107350468
# Epsilon: 0.675928626537685
# Episode: 204
# Running average reward:2.2198069393634796
# Running average loss: 0.00042287735850550235
# Epsilon: 0.6749904374156306
# Episode: 205
# Running average reward:1.4676213040947914
# Running average loss: 0.00045988954370841385
# Epsilon: 0.6740536545223239
# Episode: 206
# Running average reward:2.0581097453832626
# Running average loss: 0.0004294092883355916
# Epsilon: 0.6731182757500032
# Episode: 207
# Running average reward:1.2470851987600327
# Running average loss: 0.00043836119293700905
# Epsilon: 0.6721842989940657
# Episode: 208
# Running average reward:2.8002462536096573
# Running average loss: 0.0004138035379583016
# Epsilon: 0.6712517221530635
# Episode: 209
# Running average reward:1.5181531459093094
# Running average loss: 0.0004585057409713045
# Epsilon: 0.6703205431286983
# Episode: 210
# Running average reward:2.178105980157852
# Running average loss: 0.00048191257228609176
# Epsilon: 0.6693907598258169
# Episode: 211
# Running average reward:1.467773199081421
# Running average loss: 0.0005753350676968693
# Epsilon: 0.6684623701524062
# Episode: 212
# Running average reward:2.293478935956955
# Running average loss: 0.0005070407467428594
# Epsilon: 0.6675353720195892
# Episode: 213
# Running average reward:1.620053008198738
# Running average loss: 0.0004228519013850018
# Epsilon: 0.66660976334162
# Episode: 214
# Running average reward:3.1502396166324615
# Running average loss: 0.00047287569614127276
# Epsilon: 0.6656855420358784
# Episode: 215
# Running average reward:1.482297234237194
# Running average loss: 0.0004905668698484078
# Epsilon: 0.664762706022866
# Episode: 216
# Running average reward:1.7797032594680786
# Running average loss: 0.00048382613458670677
# Epsilon: 0.6638412532262017
# Episode: 217
# Running average reward:1.5298433676362038
# Running average loss: 0.0004843376576900482
# Epsilon: 0.662921181572616
# Episode: 218
# Running average reward:3.040107250213623
# Running average loss: 0.000509712242637761
# Epsilon: 0.6620024889919475
# Episode: 219
# Running average reward:1.6716287434101105
# Running average loss: 0.0005047099810326471
# Epsilon: 0.6610851734171372
# Episode: 220
# Running average reward:2.737272188067436
# Running average loss: 0.0006415096548153087
# Epsilon: 0.6601692327842251
# Episode: 221
# Running average reward:1.7397371381521225
# Running average loss: 0.0004963708517607302
# Epsilon: 0.6592546650323442
# Episode: 222
# Running average reward:3.4687499403953552
# Running average loss: 0.0005404770112363621
# Epsilon: 0.6583414681037165
# Episode: 223
# Running average reward:1.9864130914211273
# Running average loss: 0.000525288685457781
# Epsilon: 0.6574296399436487
# Episode: 224
# Running average reward:2.733584299683571
# Running average loss: 0.0005051108833868057
# Epsilon: 0.6565191785005271
# Episode: 225
# Running average reward:1.389618694782257
# Running average loss: 0.00048663602210581304
# Epsilon: 0.655610081725813
# Episode: 226
# Running average reward:2.5534529089927673
# Running average loss: 0.000502473334199749
# Epsilon: 0.6547023475740382
# Episode: 227
# Running average reward:1.1849365383386612
# Running average loss: 0.00048749627894721924
# Epsilon: 0.6537959740028007
# Episode: 228
# Running average reward:3.0487957894802094
# Running average loss: 0.0004605770111083984
# Epsilon: 0.6528909589727593
# Episode: 229
# Running average reward:1.5606179609894753
# Running average loss: 0.0005689288285793736
# Epsilon: 0.65198730044763
# Episode: 230
# Running average reward:3.2480918765068054
# Running average loss: 0.0005044636054662988
# Epsilon: 0.6510849963941806
# Episode: 231
# Running average reward:1.5575327426195145
# Running average loss: 0.0005222523992415518
# Epsilon: 0.6501840447822268
# Episode: 232
# Running average reward:2.3103211522102356
# Running average loss: 0.0005144914612174034
# Epsilon: 0.6492844435846269
# Episode: 233
# Running average reward:2.1754543632268906
# Running average loss: 0.0005036144953919575
# Epsilon: 0.6483861907772779
# Episode: 234
# Running average reward:2.238003671169281
# Running average loss: 0.0004934088879963383
# Epsilon: 0.6474892843391105
# Episode: 235
# Running average reward:1.4426360800862312
# Running average loss: 0.0005149144388269633
# Epsilon: 0.6465937222520849
# Episode: 236
# Running average reward:3.139336049556732
# Running average loss: 0.0004686460335506126
# Epsilon: 0.6456995025011862
# Episode: 237
# Running average reward:0.9621282368898392
# Running average loss: 0.0004997318756068125
# Epsilon: 0.6448066230744194
# Episode: 238
# Running average reward:2.600719392299652
# Running average loss: 0.0005057162692537531
# Epsilon: 0.6439150819628054
# Episode: 239
# Running average reward:1.3667576238512993
# Running average loss: 0.00046729324385523795
# Epsilon: 0.6430248771603764
# Episode: 240
# Running average reward:2.6915315091609955
# Running average loss: 0.0005183707806281745
# Epsilon: 0.6421360066641711
# Episode: 241
# Running average reward:1.8202351927757263
# Running average loss: 0.0004806165350601077
# Epsilon: 0.6412484684742309
# Episode: 242
# Running average reward:2.170878604054451
# Running average loss: 0.0005426909861853346
# Epsilon: 0.6403622605935939
# Episode: 243
# Running average reward:1.6322646141052246
# Running average loss: 0.0005395089159719646
# Epsilon: 0.6394773810282924
# Episode: 244
# Running average reward:2.7419863641262054
# Running average loss: 0.00048647889343556017
# Epsilon: 0.638593827787347
# Episode: 245
# Running average reward:1.7784717977046967
# Running average loss: 0.0005262253631372005
# Epsilon: 0.6377115988827622
# Episode: 246
# Running average reward:3.1461156606674194
# Running average loss: 0.0004976002703187988
# Epsilon: 0.636830692329523
# Episode: 247
# Running average reward:1.6357503086328506
# Running average loss: 0.0005390296515543014
# Epsilon: 0.635951106145589
# Episode: 248
# Running average reward:1.9661665856838226
# Running average loss: 0.00044295534607954325
# Epsilon: 0.6350728383518912
# Episode: 249
# Running average reward:1.4070864468812943
# Running average loss: 0.0004899118037428706
# Epsilon: 0.6341958869723264
# Episode: 250
# Running average reward:2.868935778737068
# Running average loss: 0.0004853506514336914
# Epsilon: 0.6333202500337537
# Episode: 251
# Running average reward:1.620649941265583
# Running average loss: 0.0005523772008018569
# Epsilon: 0.6324459255659898
# Episode: 252
# Running average reward:3.169355258345604
# Running average loss: 0.0005773911951109767
# Epsilon: 0.6315729116018041
# Episode: 253
# Running average reward:1.3822960704565048
# Running average loss: 0.00045867323933634907
# Epsilon: 0.6307012061769147
# Episode: 254
# Running average reward:2.616946116089821
# Running average loss: 0.0004479525057831779
# Epsilon: 0.6298308073299844
# Episode: 255
# Running average reward:1.8564271032810211
# Running average loss: 0.000491430886904709
# Epsilon: 0.6289617131026151
# Episode: 256
# Running average reward:2.8787965774536133
# Running average loss: 0.0004737765702884644
# Epsilon: 0.6280939215393445
# Episode: 257
# Running average reward:1.7610087543725967
# Running average loss: 0.000488617701921612
# Epsilon: 0.6272274306876413
# Episode: 258
# Running average reward:2.220006063580513
# Running average loss: 0.00046128875692375004
# Epsilon: 0.6263622385979006
# Episode: 259
# Running average reward:1.448910504579544
# Running average loss: 0.0005080791306681931
# Epsilon: 0.62549834332344
# Episode: 260
# Running average reward:2.250815361738205
# Running average loss: 0.0005168144503841177
# Epsilon: 0.6246357429204946
# Episode: 261
# Running average reward:1.3233418837189674
# Running average loss: 0.0005261962418444454
# Epsilon: 0.6237744354482132
# Episode: 262
# Running average reward:2.9955733120441437
# Running average loss: 0.000555383731261827
# Epsilon: 0.6229144189686536
# Episode: 263
# Running average reward:1.416614755988121
# Running average loss: 0.0005539159727049991
# Epsilon: 0.6220556915467784
# Episode: 264
# Running average reward:3.3877147883176804
# Running average loss: 0.0005694186926120892
# Epsilon: 0.6211982512504506
# Episode: 265
# Running average reward:1.8037551045417786
# Running average loss: 0.0005271646106848494
# Epsilon: 0.620342096150429
# Episode: 266
# Running average reward:2.986071079969406
# Running average loss: 0.0006508254504296928
# Epsilon: 0.6194872243203644
# Episode: 267
# Running average reward:1.8663099259138107
# Running average loss: 0.0005668677913490683
# Epsilon: 0.6186336338367947
# Episode: 268
# Running average reward:2.330849215388298
# Running average loss: 0.0005427453928859904
# Epsilon: 0.6177813227791411
# Episode: 269
# Running average reward:1.5769233778119087
# Running average loss: 0.0005027852486819029
# Epsilon: 0.6169302892297033
# Episode: 270
# Running average reward:2.018675446510315
# Running average loss: 0.0005232842260738835
# Epsilon: 0.6160805312736554
# Episode: 271
# Running average reward:1.9612840563058853
# Running average loss: 0.0005689682642696425
# Epsilon: 0.6152320469990417
# Episode: 272
# Running average reward:2.450823314487934
# Running average loss: 0.0005478240054799244
# Epsilon: 0.6143848344967721
# Episode: 273
# Running average reward:1.9012765511870384
# Running average loss: 0.0005614554887870326
# Epsilon: 0.6135388918606184
# Episode: 274
# Running average reward:2.73318187892437
# Running average loss: 0.0005552749877097085
# Epsilon: 0.612694217187209
# Episode: 275
# Running average reward:1.2482346072793007
# Running average loss: 0.0006256026856135577
# Epsilon: 0.6118508085760257
# Episode: 276
# Running average reward:2.107887387275696
# Running average loss: 0.0005064491066150367
# Epsilon: 0.6110086641293987
# Episode: 277
# Running average reward:1.8344108313322067
# Running average loss: 0.0004840482346480712
# Epsilon: 0.6101677819525027
# Episode: 278
# Running average reward:2.897701859474182
# Running average loss: 0.0005523459607502445
# Epsilon: 0.6093281601533523
# Episode: 279
# Running average reward:1.8889284878969193
# Running average loss: 0.0005135043174959719
# Epsilon: 0.6084897968427982
# Episode: 280
# Running average reward:1.846918672323227
# Running average loss: 0.000680005963658914
# Epsilon: 0.6076526901345228
# Episode: 281
# Running average reward:1.459854707121849
# Running average loss: 0.0005633098480757326
# Epsilon: 0.6068168381450354
# Episode: 282
# Running average reward:2.077312156558037
# Running average loss: 0.0005540026701055467
# Epsilon: 0.6059822389936687
# Episode: 283
# Running average reward:1.3915991485118866
# Running average loss: 0.0006337533181067556
# Epsilon: 0.6051488908025743
# Episode: 284
# Running average reward:1.9137280732393265
# Running average loss: 0.0007188301417045296
# Epsilon: 0.6043167916967184
# Episode: 285
# Running average reward:2.1481611728668213
# Running average loss: 0.0006033303594449535
# Epsilon: 0.6034859398038777
# Episode: 286
# Running average reward:2.123535633087158
# Running average loss: 0.0006054913857951761
# Epsilon: 0.6026563332546351
# Episode: 287

# %%
# plot losses for each manager
for i, loss in losses.items():
    plt.plot(loss)
# add legend for each manager
plt.legend([f"Mgr {i}" for i in losses.keys()])
plt.ioff()
plt.show()

# %%
# pd.set_option('display.max_rows', None)  # Show all rows
# pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.width', None)  # Automatically adjust the display width
# pd.set_option('display.max_colwidth', None)  # Show full content of each column
# # display(env.draft.loc[env.draft["mgr"] == 0])
# display(env.)
# pd.reset_option('display.max_rows')
# pd.reset_option('display.max_columns')
# pd.reset_option('display.width')
# pd.reset_option('display.max_colwidth')

print(env.draft.loc[env.draft["mgr"] == 0])
# env.compute_reward(1)

for i in range(NUM_MGRS):
    print(f"Manager {i} reward: {env.compute_reward(i)}")
# Out:
#      round  mgr sleeper_id            full_name team position   fp_mean  \
# 0        0    0       4984           Josh Allen  BUF       QB       1.0
# 23       1    0       4892       Baker Mayfield   TB       QB  0.736689
# 24       2    0       8155          Breece Hall  NYJ       RB  0.714236
# 47       3    0       8205        Isiah Pacheco   KC       RB  0.584847
# 48       4    0       5850          Josh Jacobs   GB       RB  0.580631
# 71       5    0       7611  Rhamondre Stevenson   NE       RB  0.487682
# 72       6    0       7611  Rhamondre Stevenson   NE       RB  0.487682
# 95       7    0       6130     Devin Singletary  NYG       RB  0.450854
# 96       8    0      11533       Brandon Aubrey  DAL        K  0.375178
# 119      9    0      11533       Brandon Aubrey  DAL        K  0.375178
# 120     10    0      11533       Brandon Aubrey  DAL        K  0.375178
# 143     11    0       5248          Gus Edwards  LAC       RB  0.356908
# 144     12    0       5248          Gus Edwards  LAC       RB  0.356908
# 167     13    0       8134        Khalil Shakir  BUF       WR  0.341044
# 168     14    0       9224          Chase Brown  CIN       RB   0.33311
#
#         fp_std
# 0    51.322362
# 23   30.119865
# 24   25.676804
# 47   19.167158
# 48   26.584809
# 71   22.999671
# 72   22.999671
# 95   32.788531
# 96    4.589032
# 119   4.589032
# 120   4.589032
# 143  34.333775
# 144  34.333775
# 167  18.868019
# 168  25.849831
# Manager 0 reward: 0.05444825289315424
# Manager 1 reward: 0.05069990880021744
# Manager 2 reward: 0.04996091414545714
# Manager 3 reward: 0.06091928493522075
# Manager 4 reward: 0.06117545042606684
# Manager 5 reward: 0.06587074177894844
# Manager 6 reward: 0.05344269984338702
# Manager 7 reward: 0.058150298496738854
# Manager 8 reward: 0.05477281579245727
# Manager 9 reward: 0.020333646912953716
# Manager 10 reward: 0.05868411108878583
# Manager 11 reward: 0.038928783079250705

# %%
import sys
import os

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

import tqdm

import torch
import torch.optim as optim
from torch.autograd import Variable
import torch.nn.functional as F
import torch.nn as nn

from IPython.display import clear_output
from IPython import display

from rl_env import (
    DraftEnv, ACTION_SPACE_DIM,
    STATE_SCHEMA, STARTER_COMPOSITION,
    STATE_SPACE_DIM, NUM_DRAFT_ROUNDS,
    NUM_MGRS
)

# %matplotlib inline

# %% [markdown]
# https://medium.com/@ym1942/policy-gradient-methods-from-reinforce-to-actor-critic-d56ff0f0af0a
#
# https://medium.com/@ym1942/proximal-policy-optimization-tutorial-f722f23beb83

# %% [markdown]
# # Init players

# %%
df_sleeper = pd.read_csv("data/sleeper/all_players.csv")
# df_sleeper = df_sleeper.loc[df_sleeper["rank_int"] < 50]
print(df_sleeper.shape)
df_sleeper.columns
# Out:
# (3670, 56)
# Index(['sleeper_id', 'injury_notes', 'oddsjam_id', 'search_last_name',
#        'college', 'team_abbr', 'birth_state', 'yahoo_id', 'search_first_name',
#        'pandascore_id', 'years_exp', 'fantasy_positions', 'injury_status',
#        'active', 'team', 'competitions', 'high_school', 'number', 'birth_city',
#        'search_full_name', 'last_name', 'birth_country',
#        'practice_description', 'depth_chart_order', 'fantasy_data_id',
#        'status', 'injury_start_date', 'news_updated', 'age', 'search_rank',
#        'practice_participation', 'opta_id', 'full_name', 'swish_id',
#        'birth_date', 'rotowire_id', 'weight', 'height', 'stats_id', 'espn_id',
#        'metadata', 'player_id', 'first_name', 'sport', 'injury_body_part',
#        'position', 'gsis_id', 'sportradar_id', 'hashtag',
#        'depth_chart_position', 'rotoworld_id', 'Player Id', 'positional_rank',
#        'adp', 'adp_date', 'rank_int'],
#       dtype='object')

# %%
df_qb_proj = pd.read_csv("data/projections/QB_projections.csv")
df_rb_proj = pd.read_csv("data/projections/RB_projections.csv")
df_wr_proj = pd.read_csv("data/projections/WR_projections.csv")
df_te_proj = pd.read_csv("data/projections/TE_projections.csv")
df_k_proj = pd.read_csv("data/projections/K_projections.csv")
df_def_proj = pd.read_csv("data/projections/DEF_projections.csv")

df_qb_proj = df_qb_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)
df_rb_proj = df_rb_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)
df_wr_proj = df_wr_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)
df_te_proj = df_te_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)
df_k_proj = df_k_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)
df_def_proj = df_def_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)

df_proj = pd.concat([df_qb_proj, df_rb_proj, df_wr_proj, df_te_proj, df_k_proj, df_def_proj])
df_proj = pd.concat([df_qb_proj, df_rb_proj, df_wr_proj, df_te_proj, df_k_proj, df_def_proj])
df_proj.columns

df_proj_agg = df_proj.groupby('sleeper_id')['fpts'].agg(['mean', 'std']).reset_index()
df_proj_agg['sleeper_id'] = df_proj_agg['sleeper_id'].astype(str)


df_players = df_proj_agg.merge(df_sleeper.loc[:, ['sleeper_id', 'full_name', 'position', 'team']], 
                                on='sleeper_id', 
                                how='left')
print(df_players.shape)
df_players = df_players.dropna(subset=['mean', 'std'])
print(df_players.shape)
# Out:
# (796, 6)
# (647, 6)

# %% [markdown]
# # Constants

# %%
SCORING = {
    'pass_yd': .04,
    'pass_td': 4,
    'pass_2pt': 2,
    'pass_int': -1,
    'rush_yd': .1,
    'rush_td': 6,
    'rush_2pt': 2,
    'rec_rcpt': .5,
    'rec_yd': .1,
    'rec_td': 6,
    'rec_2pt': 2,
    'fg_1_39_made': 3,
    'fg_40_49_made': 4,
    'fg_50_made': 5,
    'xp_missed': -1,
    'xp_made': 1,
    'def_td': 6,
    'def_int': 2,
    'def_sck': 1,
    'def_fum_rec': 2,
    'def_fum_forced': 1,
    'def_sfty': 2,
    'remainder': 1
}

POSITIONS = ['QB', 'RB', 'WR', 'TE', 'K', 'DEF']
STARTER_COMPOSITION = {'QB': 1, 'RB': 2, 'WR': 2, 'FLEX': 2, 'TE': 1, 'K': 1, 'DEF': 1}
TEAM_SIZE = 15

# %% [markdown]
# # Init plotting and compute

# %%
# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display
plt.ion()

# if GPU is to be used
device = torch.device(
    "cuda" if torch.cuda.is_available() else
    "mps" if torch.backends.mps.is_available() else
    "cpu"
)

# %% [markdown]
# # Init network

# %%
# class RNN(nn.Module):
#     """
#     Basic RNN block. This represents a single layer of RNN
#     https://solardevs.com/blog/rnn-from-scratch-pytorch/
#     """
#     def __init__(self, input_size: int, hidden_size: int, output_size: int, batch_size: int) -> None:
#         """
#         input_size: Number of features of your input vector
#         hidden_size: Number of hidden neurons
#         output_size: Number of features of your output vector
#         """
#         super().__init__()
#         self.input_size = input_size
#         self.hidden_size = hidden_size
#         self.output_size = output_size
#         self.batch_size = batch_size
#         self.i2h = nn.Linear(input_size, hidden_size, bias=False)
#         self.h2h = nn.Linear(hidden_size, hidden_size)
#         self.h2o = nn.Linear(hidden_size, output_size)
    
#     def forward(self, x, hidden_state) -> tuple[torch.Tensor, torch.Tensor]:
#         """
#         Returns computed output and tanh(i2h + h2h)
#         Inputs
#         ------
#         x: Input vector
#         hidden_state: Previous hidden state
#         Outputs
#         -------
#         out: Linear output (without activation because of how pytorch works)
#         hidden_state: New hidden state matrix
#         """
#         x = self.i2h(x)
#         hidden_state = self.h2h(hidden_state)
#         hidden_state = torch.tanh(x + hidden_state)
#         out = self.h2o(hidden_state)
#         return out, hidden_state
        
#     def init_zero_hidden(self, batch_size=1) -> torch.Tensor:
#         """
# 				Helper function.
#         Returns a hidden state with specified batch size. Defaults to 1
#         """
#         return torch.zeros(batch_size, self.hidden_size, requires_grad=False)

# %%
hidden_size = 32
class PolicyNet(nn.Module):
    def __init__(self):
        super(PolicyNet, self).__init__()
        self.fc1 = nn.Linear(STATE_SPACE_DIM, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, ACTION_SPACE_DIM)

    def forward(self, x):
        x = nn.functional.relu(self.fc1(x))
        x = nn.functional.relu(self.fc2(x))
        x = self.fc3(x)
        x = nn.functional.softmax(x, dim=1)
        return x

# %% [markdown]
# # Generate episode function

# %%
def generate_single_episode(env, policy_net, rl_mgr: int=1):
    """
    Generates an episode by executing the current policy in the given env
    """
    states = []
    actions = []
    rewards = []
    log_probs = []
        
    state, _ = env.reset()
    
    mgr_turns = [d["mgr"] for d in env.turns]
    for turn_i, mgr_num in enumerate(mgr_turns):
        
        if mgr_num == rl_mgr:
            state = torch.from_numpy(state).float().unsqueeze(0).to(device)
            probs = policy_net.forward(state) # get each action choice probability with the current policy network
            action = np.random.choice(env.action_space.n, p=np.squeeze(probs.detach().cpu().numpy())) # probablistic
            # action = np.argmax(probs.detach().numpy()) # greedy
            
            # compute the log_prob to use this in parameter update
            log_prob = torch.log(probs.squeeze(0)[action])
            
            # append values
            states.append(state)
            actions.append(action)
            log_probs.append(log_prob)
            
            # take a selected action
            state, reward, terminated, _ = env.step(action)
            rewards.append(reward)
        else:
            env.step(env.reasonable_option())


    return states, actions, rewards, log_probs

# %%
# policy_net = PolicyNet()
# policy_net.to(device)

# num_episodes = 2500
# gamma = 0.99
# lr_policy_net = 2**-13
# optimizer = torch.optim.Adam(policy_net.parameters(), lr=lr_policy_net)

# for episode_num in range(num_episodes):
#     env = DraftEnv(df_players)
#     states, actions, rewards, log_probs = generate_single_episode(env, policy_net)
#     print(f"Episode {episode_num} completed with reward: {rewards[-1]}")
#     discounted_rewards = []
#     for t in range(len(rewards)):
#         Gt = 0  # Gt is the total discounted reward from time t
#         pw = 0  # pw is the power of gamma
#         for r in rewards[t:]:
#             # at each time step, the total discounted reward is calculated 
#             # by summing the weighted rewards from that time step to the end
#             Gt = Gt + gamma**pw * r
#             pw = pw + 1
#         discounted_rewards.append(Gt)
#     discounted_rewards = torch.tensor(discounted_rewards)
#     discounted_rewards = (discounted_rewards - discounted_rewards.mean()) / (discounted_rewards.std() + 1e-9) # normalize discounted rewards
#     policy_gradient = []
#     for log_prob, Gt in zip(log_probs, discounted_rewards):
#         Gt = Gt.to(dtype=torch.float32).to(device)
#         policy_gradient.append(-log_prob * Gt)
    
#     optimizer.zero_grad()
#     policy_gradient = torch.stack(policy_gradient).sum()
#     policy_gradient.backward()
#     optimizer.step()
# Out:
# Episode 0 completed with reward: 0.24765935426298302
# Episode 1 completed with reward: 0.2923474022271939
# Episode 2 completed with reward: 0.2671241060341797
# Episode 3 completed with reward: 0.5231723382267398
# Episode 4 completed with reward: 0.31389737676788687
# Episode 5 completed with reward: 0.24610688646542458
# Episode 6 completed with reward: 0.3559025659626467
# Episode 7 completed with reward: 0.31629535284194304
# Episode 8 completed with reward: 0.49949971180482866
# Episode 9 completed with reward: 0.26663125537214605
# Episode 10 completed with reward: 0.2733747727072241
# Episode 11 completed with reward: 0.33061614965393044
# Episode 12 completed with reward: 0.2949345029116824
# Episode 13 completed with reward: 0.24265667936929516
# Episode 14 completed with reward: 0.2867401780391171
# Episode 15 completed with reward: 0.30094874320240206
# Episode 16 completed with reward: 0.2670030677620757
# Episode 17 completed with reward: 0.28871887174529554
# Episode 18 completed with reward: 0.3369269808500162
# Episode 19 completed with reward: 0.36564365709879626
# Episode 20 completed with reward: 0.2880930012355006
# Episode 21 completed with reward: 0.3377308055354178
# Episode 22 completed with reward: 0.3186579278834258
# Episode 23 completed with reward: 0.4744581286446553
# Episode 24 completed with reward: 0.27596246799671514
# Episode 25 completed with reward: 0.27010660218220284
# Episode 26 completed with reward: 0.2876910460272565
# Episode 27 completed with reward: 0.326451298332262
# Episode 28 completed with reward: 0.23928213764392983
# Episode 29 completed with reward: 0.3295951182235776
# Episode 30 completed with reward: 0.33715587604006486
# Episode 31 completed with reward: 0.3531484194324049
# Episode 32 completed with reward: 0.22059244026007038
# Episode 33 completed with reward: 0.2649882457227648
# Episode 34 completed with reward: 0.30342095520766166
# Episode 35 completed with reward: 0.34694486390014345
# Episode 36 completed with reward: 0.28667129749130793
# Episode 37 completed with reward: 0.29439337819948663
# Episode 38 completed with reward: 0.3329506633275112
# Episode 39 completed with reward: 0.2999857437257979
# Episode 40 completed with reward: 0.2768142027703632
# Episode 41 completed with reward: 0.2150149899411811
# Episode 42 completed with reward: 0.312880807667363
# Episode 43 completed with reward: 0.33847821959363183
# Episode 44 completed with reward: 0.33908802344340516
# Episode 45 completed with reward: 0.3286578690434931
# Episode 46 completed with reward: 0.3401365677707041
# Episode 47 completed with reward: 0.29697310918064573
# Episode 48 completed with reward: 0.28090406998382506
# Episode 49 completed with reward: 0.235816087078236
# Episode 50 completed with reward: 0.2782098612671755
# Episode 51 completed with reward: 0.3046536546516242
# Episode 52 completed with reward: 0.31167248981991247
# Episode 53 completed with reward: 0.28609872963874344
# Episode 54 completed with reward: 0.3096944408654247
# Episode 55 completed with reward: 0.27206405501873016
# Episode 56 completed with reward: 0.28555064174080924
# Episode 57 completed with reward: 0.333130229791578
# Episode 58 completed with reward: 0.3331440432651964
# Episode 59 completed with reward: 0.2913838506247088
# Episode 60 completed with reward: 0.3105804986345276
# Episode 61 completed with reward: 0.3116910333316309
# Episode 62 completed with reward: 0.32364337708608026
# Episode 63 completed with reward: 0.31489870457216196
# Episode 64 completed with reward: 0.25986427087415015
# Episode 65 completed with reward: 0.2679052780019234
# Episode 66 completed with reward: 0.3136448427137818
# Episode 67 completed with reward: 0.3420192357741412
# Episode 68 completed with reward: 0.3667120358839478
# Episode 69 completed with reward: 0.5091614171819103
# Episode 70 completed with reward: 0.34800501649768606
# Episode 71 completed with reward: 0.3020772987364931
# Episode 72 completed with reward: 0.3020933788270649
# Episode 73 completed with reward: 0.22814168615950717
# Episode 74 completed with reward: 0.32404140829371303
# Episode 75 completed with reward: 0.30287527123285846
# Episode 76 completed with reward: 0.4372760149988402
# Episode 77 completed with reward: 0.2799686003100047
# Episode 78 completed with reward: 0.30390948720402017
# Episode 79 completed with reward: 0.48171874510338597
# Episode 80 completed with reward: 0.5024151333676272
# Episode 81 completed with reward: 0.35059057033208274
# Episode 82 completed with reward: 0.2893624607100457
# Episode 83 completed with reward: 0.3620843586389453
# Episode 84 completed with reward: 0.29550912369922444
# Episode 85 completed with reward: 0.33078500914814407
# Episode 86 completed with reward: 0.5228017717573255
# Episode 87 completed with reward: 0.4336326044835897
# Episode 88 completed with reward: 0.26577687956077933
# Episode 89 completed with reward: 0.3280506959419482
# Episode 90 completed with reward: 0.34187140016648415
# Episode 91 completed with reward: 0.29457722547297427
# Episode 92 completed with reward: 0.2957068850654236
# Episode 93 completed with reward: 0.3122065548695415
# Episode 94 completed with reward: 0.3166357763449108
# Episode 95 completed with reward: 0.3022089280571236
# Episode 96 completed with reward: 0.3360727417373069
# Episode 97 completed with reward: 0.3142847275032511
# Episode 98 completed with reward: 0.32510096347979284
# Episode 99 completed with reward: 0.3095483199929999
# Episode 100 completed with reward: 0.30926488020099624
# Episode 101 completed with reward: 0.5105639508669257
# Episode 102 completed with reward: 0.491909815108075
# Episode 103 completed with reward: 0.479645736841987
# Episode 104 completed with reward: 0.2940250220704138
# Episode 105 completed with reward: 0.33092308832702416
# Episode 106 completed with reward: 0.500911565109599
# Episode 107 completed with reward: 0.46251876874126696
# Episode 108 completed with reward: 0.2825433681528883
# Episode 109 completed with reward: 0.4697235926990817
# Episode 110 completed with reward: 0.30777884563153196
# Episode 111 completed with reward: 0.31271330511435624
# Episode 112 completed with reward: 0.2972788001058713
# Episode 113 completed with reward: 0.22137546642809935
# Episode 114 completed with reward: 0.5073330238322898
# Episode 115 completed with reward: 0.33931533225194155
# Episode 116 completed with reward: 0.32293631248118737
# Episode 117 completed with reward: 0.3066293784460328
# Episode 118 completed with reward: 0.4355107681806808
# Episode 119 completed with reward: 0.28798547968840804
# Episode 120 completed with reward: 0.2973421466244062
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 11
#       9 for episode_num in range(num_episodes):
#      10     env = DraftEnv(df_players)
# ---> 11     states, actions, rewards, log_probs = generate_single_episode(env, policy_net)
#      12     print(f"Episode {episode_num} completed with reward: {rewards[-1]}")
#      13     discounted_rewards = []
#
# Cell In[25], line 33, in generate_single_episode(env, policy_net, rl_mgr)
#      31         rewards.append(reward)
#      32     else:
# ---> 33         env.step(env.reasonable_option())
#      36 return states, actions, rewards, log_probs
#
# File ~/files/fun_projects/fantasy_football_2024/rl_env.py:301, in DraftEnv.step(self, action)
#     296 else:
#     297     self.cur_round += 1
# --> 301 reward = self.compute_reward(mgr_num)
#     302 # if done:
#     303 #     reward = self.compute_reward(mgr_num)
#     304 #     return self.state, reward, done, info
#     305 # else:
#     306 #     return self.state, 0, done, info
#     307 return self.state, reward, done, info
#
# File ~/files/fun_projects/fantasy_football_2024/rl_env.py:230, in DraftEnv.compute_reward(self, mgr_num)
#     227 team = team.sort_values(by=self.objective, ascending=False).reset_index(drop=True)
#     229 starters = self.get_starters(mgr_num)
# --> 230 bench = self.get_bench(mgr_num)
#     232 starters_sum = starters[self.objective].sum()
#     233 bench_sum = bench[self.objective].sum()
#
# File ~/files/fun_projects/fantasy_football_2024/rl_env.py:221, in DraftEnv.get_bench(self, mgr_num)
#     219     mgr_num = self.get_cur_mgr()
#     220 team = self.draft.loc[(self.draft["mgr"] == mgr_num)].copy()
# --> 221 starter_ids = self.get_starters(mgr_num)['sleeper_id'].values
#     222 return team.loc[~team["sleeper_id"].isin(starter_ids)]
#
# File ~/files/fun_projects/fantasy_football_2024/rl_env.py:209, in DraftEnv.get_starters(self, mgr_num)
#     207 starter_ids = []
#     208 for pos in STARTER_COMPOSITION.keys():
# --> 209     players_pos = team.loc[team["team_pos"] == pos]
#     210     players_pos = players_pos.sort_values(by=self.objective, ascending=False).reset_index(drop=True)
#     211     pos_starter_ids = players_pos.iloc[:STARTER_COMPOSITION[pos]]['sleeper_id'].values
#
# File ~/files/fun_projects/fantasy_football_2024/venv/lib/python3.9/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/files/fun_projects/fantasy_football_2024/venv/lib/python3.9/site-packages/pandas/core/indexing.py:1413, in _LocIndexer._getitem_axis(self, key, axis)
#    1411     return self._get_slice_axis(key, axis=axis)
#    1412 elif com.is_bool_indexer(key):
# -> 1413     return self._getbool_axis(key, axis=axis)
#    1414 elif is_list_like_indexer(key):
#    1415     # an iterable multi-selection
#    1416     if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#
# KeyboardInterrupt:

# %% [markdown]
# # Try 2

# %%
import sys
import torch  
import gym
import numpy as np  
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
import matplotlib.pyplot as plt

# Constants
GAMMA = 0.9

class PolicyNetwork(nn.Module):
    def __init__(self, num_inputs, num_actions, hidden_size, learning_rate=3e-4):
        super(PolicyNetwork, self).__init__()

        self.num_actions = num_actions
        self.linear1 = nn.Linear(num_inputs, hidden_size)
        self.linear2 = nn.Linear(hidden_size, num_actions)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)

    def forward(self, state):
        x = F.relu(self.linear1(state))
        x = F.softmax(self.linear2(x), dim=1)
        return x 
    
    def get_action(self, state):
        state = torch.from_numpy(state).float().unsqueeze(0)
        probs = self.forward(state)
        highest_prob_action = np.random.choice(self.num_actions, p=np.squeeze(probs.detach().numpy()))
        log_prob = torch.log(probs.squeeze(0)[highest_prob_action])
        return highest_prob_action, log_prob

# %%
def update_policy(policy_network, rewards, log_probs):
    discounted_rewards = []

    for t in range(len(rewards)):
        Gt = 0 
        pw = 0
        for r in rewards[t:]:
            Gt = Gt + GAMMA**pw * r
            pw = pw + 1
        discounted_rewards.append(Gt)
        
    discounted_rewards = torch.tensor(discounted_rewards)
    discounted_rewards = (discounted_rewards - discounted_rewards.mean()) / (discounted_rewards.std() + 1e-9) # normalize discounted rewards

    policy_gradient = []
    for log_prob, Gt in zip(log_probs, discounted_rewards):
        policy_gradient.append(-log_prob * Gt)
    
    policy_network.optimizer.zero_grad()
    policy_gradient = torch.stack(policy_gradient).sum()
    policy_gradient.backward()
    policy_network.optimizer.step()

# %%
env = DraftEnv(df_players)
RL_MGR = 1

policy_net = PolicyNetwork(env.observation_space.shape[0], env.action_space.n, 128)

max_episode_num = 50000
all_rewards = []

for episode in range(max_episode_num):
    state, _ = env.reset()
    log_probs = []
    rewards = []

    for _, row in env.draft.iterrows():

        if row['mgr'] == RL_MGR:
            action, log_prob = policy_net.get_action(state)
            state, reward, done, _ = env.step(action)
            log_probs.append(log_prob)
            rewards.append(reward)
        else:
            action = env.reasonable_option()
            # print(f'Action: {action}')
            env.step(action)
            
    
    update_policy(policy_net, rewards, log_probs)
    all_rewards.append(np.sum(rewards))
    if episode % 1 == 0:
        print("episode: {}, total reward: {}, average_reward: {}".format(episode, np.round(np.sum(rewards), decimals = 3), np.mean(all_rewards)))
# Out:
# episode: 0, total reward: -0.771, average_reward: -0.7714529277172797
# episode: 1, total reward: -0.805, average_reward: -0.7883612665349773
# episode: 2, total reward: -0.777, average_reward: -0.7847351419974874
# episode: 3, total reward: -0.811, average_reward: -0.7911925969173608
# episode: 4, total reward: -0.766, average_reward: -0.7862504329158746
# episode: 5, total reward: -0.769, average_reward: -0.7833536270892467
# episode: 6, total reward: -0.755, average_reward: -0.7793224489504046
# episode: 7, total reward: -0.73, average_reward: -0.7732038143140634
# episode: 8, total reward: -0.744, average_reward: -0.769924384251142
# episode: 9, total reward: -0.757, average_reward: -0.768664153656015
# episode: 10, total reward: -0.817, average_reward: -0.7730348846015165
# episode: 11, total reward: -0.734, average_reward: -0.76976425234714
# episode: 12, total reward: -0.784, average_reward: -0.770891145448483
# episode: 13, total reward: -0.859, average_reward: -0.7772068613710366
# episode: 14, total reward: -0.721, average_reward: -0.77344573128103
# episode: 15, total reward: -0.822, average_reward: -0.7764733851151804
# episode: 16, total reward: -0.742, average_reward: -0.7744215839760572
# episode: 17, total reward: 0.817, average_reward: -0.6860350734090755
# episode: 18, total reward: -0.759, average_reward: -0.68985082128551
# episode: 19, total reward: 1.256, average_reward: -0.5925699066280161
# episode: 20, total reward: -0.777, average_reward: -0.601343228189483
# episode: 21, total reward: -0.734, average_reward: -0.6073651792786783
# episode: 22, total reward: -0.828, average_reward: -0.6169581062926407
# episode: 23, total reward: -0.782, average_reward: -0.6238405065302246
# episode: 24, total reward: -0.856, average_reward: -0.6331088984973602
# episode: 25, total reward: -0.834, average_reward: -0.6408167790088812
# episode: 26, total reward: -0.803, average_reward: -0.6468276472318357
# episode: 27, total reward: -0.741, average_reward: -0.6501763983491653
# episode: 28, total reward: -0.828, average_reward: -0.6563024531550589
# episode: 29, total reward: -0.736, average_reward: -0.6589494566819601
# episode: 30, total reward: 1.509, average_reward: -0.589018367910074
# episode: 31, total reward: -0.701, average_reward: -0.5925257272292694
# episode: 32, total reward: -0.799, average_reward: -0.5987734978112484
# episode: 33, total reward: -0.755, average_reward: -0.6033809123637807
# episode: 34, total reward: -0.792, average_reward: -0.6087647874192434
# episode: 35, total reward: -0.761, average_reward: -0.612984150620527
# episode: 36, total reward: -0.793, average_reward: -0.617852341204193
# episode: 37, total reward: -0.801, average_reward: -0.6226801611727479
# episode: 38, total reward: -0.8, average_reward: -0.6272341408888734
# episode: 39, total reward: -0.741, average_reward: -0.6300734868666586
# episode: 40, total reward: -0.8, average_reward: -0.6342236382114579
# episode: 41, total reward: -0.796, average_reward: -0.6380676637503628
# episode: 42, total reward: -0.796, average_reward: -0.6417360611377225
# episode: 43, total reward: -0.757, average_reward: -0.6443525591303599
# episode: 44, total reward: -0.787, average_reward: -0.6475321984217115
# episode: 45, total reward: -0.784, average_reward: -0.650495529130506
# episode: 46, total reward: -0.718, average_reward: -0.6519219361289896
# episode: 47, total reward: -0.746, average_reward: -0.6538887016622724
# episode: 48, total reward: -0.758, average_reward: -0.6560226516650095
# episode: 49, total reward: -0.75, average_reward: -0.6579070659646571
# episode: 50, total reward: -0.817, average_reward: -0.6610192569819112
# episode: 51, total reward: 0.798, average_reward: -0.6329642311591067
# episode: 52, total reward: -0.783, average_reward: -0.6358009244743191
# episode: 53, total reward: -0.724, average_reward: -0.6374338232761926
# episode: 54, total reward: -0.829, average_reward: -0.6409116709136761
# episode: 55, total reward: -0.788, average_reward: -0.6435400515274655
# episode: 56, total reward: -0.783, average_reward: -0.6459909209806237
# episode: 57, total reward: -0.73, average_reward: -0.6474363509460229
# episode: 58, total reward: -0.764, average_reward: -0.6494086359639211
# episode: 59, total reward: -0.785, average_reward: -0.6516642973667063
# episode: 60, total reward: -0.768, average_reward: -0.6535743580747149
# episode: 61, total reward: -0.787, average_reward: -0.6557243741822677
# episode: 62, total reward: -0.835, average_reward: -0.6585684413117499
# episode: 63, total reward: -0.807, average_reward: -0.660892710607704
# episode: 64, total reward: -0.822, average_reward: -0.6633782718584342
# episode: 65, total reward: -0.759, average_reward: -0.6648269796728267
# episode: 66, total reward: -0.801, average_reward: -0.6668545942583756
# episode: 67, total reward: -0.741, average_reward: -0.6679423062097114
# episode: 68, total reward: -0.754, average_reward: -0.6691891808169904
# episode: 69, total reward: -0.781, average_reward: -0.6707898646875671
# episode: 70, total reward: -0.771, average_reward: -0.6722011332638922
# episode: 71, total reward: 0.748, average_reward: -0.6524716373541852
# episode: 72, total reward: -0.793, average_reward: -0.6544005750280678
# episode: 73, total reward: -0.792, average_reward: -0.6562558186416059
# episode: 74, total reward: -0.793, average_reward: -0.6580854946298248
# episode: 75, total reward: -0.765, average_reward: -0.6594863761727945
# episode: 76, total reward: -0.802, average_reward: -0.6613364881382829
# episode: 77, total reward: -0.73, average_reward: -0.6622190719659046
# episode: 78, total reward: -0.792, average_reward: -0.6638669230671911
# episode: 79, total reward: -0.758, average_reward: -0.6650402198403847
# episode: 80, total reward: -0.76, average_reward: -0.6662090140730462
# episode: 81, total reward: -0.78, average_reward: -0.6675942083581763
# episode: 82, total reward: -0.742, average_reward: -0.6684966173098486
# episode: 83, total reward: -0.776, average_reward: -0.6697733940498433
# episode: 84, total reward: -0.762, average_reward: -0.6708578499864907
# episode: 85, total reward: -0.704, average_reward: -0.6712418117962734
# episode: 86, total reward: -0.713, average_reward: -0.6717273185448545
# episode: 87, total reward: -0.713, average_reward: -0.6722007702918659
# episode: 88, total reward: -0.814, average_reward: -0.6737915664487973
# episode: 89, total reward: -0.709, average_reward: -0.6741875598425098
# episode: 90, total reward: -0.825, average_reward: -0.6758480302086308
# episode: 91, total reward: -0.801, average_reward: -0.6772097600585972
# episode: 92, total reward: -0.772, average_reward: -0.678226848772442
# episode: 93, total reward: -0.706, average_reward: -0.6785185514082991
# episode: 94, total reward: -0.736, average_reward: -0.679127688701704
# episode: 95, total reward: 1.228, average_reward: -0.6592667895709138
# episode: 96, total reward: -0.663, average_reward: -0.6593085802673516
# episode: 97, total reward: -0.79, average_reward: -0.6606452811208109
# episode: 98, total reward: -0.803, average_reward: -0.6620829373065062
# episode: 99, total reward: -0.788, average_reward: -0.6633446031188761
# episode: 100, total reward: 0.819, average_reward: -0.6486663891664926
# episode: 101, total reward: -0.778, average_reward: -0.6499320796610609
# episode: 102, total reward: -0.743, average_reward: -0.6508314034884024
# episode: 103, total reward: -0.756, average_reward: -0.6518404060416215
# episode: 104, total reward: -0.833, average_reward: -0.6535672038024906
# episode: 105, total reward: -0.821, average_reward: -0.6551459916184994
# episode: 106, total reward: -0.692, average_reward: -0.6554902592869059
# episode: 107, total reward: -0.807, average_reward: -0.6568900272763343
# episode: 108, total reward: 2.126, average_reward: -0.6313613698054766
# episode: 109, total reward: 0.699, average_reward: -0.6192654748887901
# episode: 110, total reward: 1.608, average_reward: -0.5991993535331156
# episode: 111, total reward: -0.762, average_reward: -0.6006498089666074
# episode: 112, total reward: -0.806, average_reward: -0.6024668994131657
# episode: 113, total reward: -0.75, average_reward: -0.60375864096714
# episode: 114, total reward: -0.763, average_reward: -0.6051440343317747
# episode: 115, total reward: 1.678, average_reward: -0.5854640433136974
# episode: 116, total reward: -0.751, average_reward: -0.5868830455819332
# episode: 117, total reward: 0.785, average_reward: -0.5752534665168789
# episode: 118, total reward: -0.764, average_reward: -0.5768385596293174
# episode: 119, total reward: -0.794, average_reward: -0.5786440998993119
# episode: 120, total reward: -0.702, average_reward: -0.5796670326010037
# episode: 121, total reward: -0.727, average_reward: -0.580871706031137
# episode: 122, total reward: -0.759, average_reward: -0.5823237276922856
# episode: 123, total reward: -0.77, average_reward: -0.5838389891929762
# episode: 124, total reward: -0.788, average_reward: -0.5854759418737704
# episode: 125, total reward: -0.728, average_reward: -0.5866056878462846
# episode: 126, total reward: -0.775, average_reward: -0.5880910485512263
# episode: 127, total reward: -0.769, average_reward: -0.5895032791526059
# episode: 128, total reward: 2.055, average_reward: -0.5689999340877828
# episode: 129, total reward: -0.66, average_reward: -0.5696996268730093
# episode: 130, total reward: -0.748, average_reward: -0.5710590026192292
# episode: 131, total reward: -0.779, average_reward: -0.5726331278390742
# episode: 132, total reward: -0.85, average_reward: -0.5747156510647196
# episode: 133, total reward: -0.757, average_reward: -0.5760755205543695
# episode: 134, total reward: -0.744, average_reward: -0.5773228479488005
# episode: 135, total reward: -0.761, average_reward: -0.5786729228102017
# episode: 136, total reward: -0.788, average_reward: -0.5801994526336861
# episode: 137, total reward: -0.741, average_reward: -0.5813619522663508
# episode: 138, total reward: -0.772, average_reward: -0.5827319915570924
# episode: 139, total reward: -0.702, average_reward: -0.5835873798381757
# episode: 140, total reward: -0.746, average_reward: -0.5847371209412874
# episode: 141, total reward: -0.702, average_reward: -0.5855615503806233
# episode: 142, total reward: -0.781, average_reward: -0.5869269597000032
# episode: 143, total reward: -0.682, average_reward: -0.5875892608262906
# episode: 144, total reward: -0.753, average_reward: -0.5887281114329794
# episode: 145, total reward: -0.69, average_reward: -0.5894205367107632
# episode: 146, total reward: -0.773, average_reward: -0.5906694151608379
# episode: 147, total reward: -0.697, average_reward: -0.5913896288406096
# episode: 148, total reward: 1.267, average_reward: -0.5789179714180741
# episode: 149, total reward: -0.782, average_reward: -0.580271986938633
# episode: 150, total reward: -0.772, average_reward: -0.5815391845822
# episode: 151, total reward: -0.728, average_reward: -0.58250061076644
# episode: 152, total reward: -0.646, average_reward: -0.5829177610695487
# episode: 153, total reward: -0.784, average_reward: -0.584221501281441
# episode: 154, total reward: -0.736, average_reward: -0.5852032088409871
# episode: 155, total reward: 0.769, average_reward: -0.5765231916095305
# episode: 156, total reward: -0.714, average_reward: -0.5774017789336926
# episode: 157, total reward: -0.718, average_reward: -0.5782885495247517
# episode: 158, total reward: -0.766, average_reward: -0.5794665649237976
# episode: 159, total reward: 0.718, average_reward: -0.5713545471116588
# episode: 160, total reward: -0.705, average_reward: -0.5721871340488278
# episode: 161, total reward: -0.747, average_reward: -0.5732689682686243
# episode: 162, total reward: -0.779, average_reward: -0.574528376992411
# episode: 163, total reward: -0.761, average_reward: -0.5756679123449568
# episode: 164, total reward: 1.733, average_reward: -0.5616774266268519
# episode: 165, total reward: -0.716, average_reward: -0.5626070033321494
# episode: 166, total reward: -0.727, average_reward: -0.5635900563231901
# episode: 167, total reward: -0.765, average_reward: -0.5647909807345876
# episode: 168, total reward: 1.739, average_reward: -0.5511588801840989
# episode: 169, total reward: -0.723, average_reward: -0.5521674041985748
# episode: 170, total reward: 0.768, average_reward: -0.5444497253261255
# episode: 171, total reward: 0.808, average_reward: -0.5365878185163206
# episode: 172, total reward: 0.756, average_reward: -0.5291150531726337
# episode: 173, total reward: -0.711, average_reward: -0.5301617984594275
# episode: 174, total reward: -0.717, average_reward: -0.5312273309274105
# episode: 175, total reward: -0.763, average_reward: -0.5325433172326369
# episode: 176, total reward: -0.706, average_reward: -0.53352419217296
# episode: 177, total reward: -0.782, average_reward: -0.5349199921284179
# episode: 178, total reward: -0.818, average_reward: -0.5365015053746824
# episode: 179, total reward: -0.799, average_reward: -0.5379619689666078
# episode: 180, total reward: -0.778, average_reward: -0.5392856305012356
# episode: 181, total reward: -0.674, average_reward: -0.5400257879233968
# episode: 182, total reward: -0.669, average_reward: -0.5407307459968583
# episode: 183, total reward: -0.638, average_reward: -0.5412612734423518
# episode: 184, total reward: -0.79, average_reward: -0.5426038216898915
# episode: 185, total reward: -0.743, average_reward: -0.5436828689872591
# episode: 186, total reward: -0.754, average_reward: -0.5448073971682902
# episode: 187, total reward: -0.721, average_reward: -0.5457441610568338
# episode: 188, total reward: -0.764, average_reward: -0.5468995412583509
# episode: 189, total reward: -0.729, average_reward: -0.5478604105577671
# episode: 190, total reward: -0.797, average_reward: -0.5491660193948619
# episode: 191, total reward: 2.385, average_reward: -0.5338841028955637
# episode: 192, total reward: -0.716, average_reward: -0.534828702425063
# episode: 193, total reward: 0.827, average_reward: -0.5278106390910516
# episode: 194, total reward: 0.718, average_reward: -0.5214226165423789
# episode: 195, total reward: -0.734, average_reward: -0.5225061146909474
# episode: 196, total reward: -0.654, average_reward: -0.5231729135634401
# episode: 197, total reward: -0.699, average_reward: -0.5240589601899491
# episode: 198, total reward: -0.827, average_reward: -0.5255793286012015
# episode: 199, total reward: -0.711, average_reward: -0.5265069959328028
# episode: 200, total reward: 1.29, average_reward: -0.5174673311881103
# episode: 201, total reward: -0.769, average_reward: -0.5187112865798256
# episode: 202, total reward: -0.766, average_reward: -0.5199311964128078
# episode: 203, total reward: -0.776, average_reward: -0.5211865031590316
# episode: 204, total reward: -0.697, average_reward: -0.5220438130788952
# episode: 205, total reward: -0.733, average_reward: -0.5230695325386661
# episode: 206, total reward: -0.787, average_reward: -0.524346121328536
# episode: 207, total reward: -0.664, average_reward: -0.5250156906986501
# episode: 208, total reward: -0.785, average_reward: -0.5262603067658821
# episode: 209, total reward: -0.732, average_reward: -0.5272415519622693
# episode: 210, total reward: -0.704, average_reward: -0.5280802053035369
# episode: 211, total reward: -0.735, average_reward: -0.5290541628954701
# episode: 212, total reward: -0.675, average_reward: -0.529741371389779
# episode: 213, total reward: -0.714, average_reward: -0.5306018436455151
# episode: 214, total reward: -0.774, average_reward: -0.5317358808589164
# episode: 215, total reward: -0.678, average_reward: -0.5324124829794976
# episode: 216, total reward: -0.661, average_reward: -0.5330057534517336
# episode: 217, total reward: -0.74, average_reward: -0.5339556092981056
# episode: 218, total reward: -0.784, average_reward: -0.535097288353122
# episode: 219, total reward: 1.213, average_reward: -0.5271507651679609
# episode: 220, total reward: -0.751, average_reward: -0.5281647220053365
# episode: 221, total reward: -0.669, average_reward: -0.5287992948217681
# episode: 222, total reward: -0.677, average_reward: -0.5294626442229313
# episode: 223, total reward: -0.66, average_reward: -0.5300448038297275
# episode: 224, total reward: -0.751, average_reward: -0.5310284726615215
# episode: 225, total reward: -0.825, average_reward: -0.5323304446637466
# episode: 226, total reward: -0.717, average_reward: -0.5331431218411093
# episode: 227, total reward: -0.751, average_reward: -0.5340993629449585
# episode: 228, total reward: -0.811, average_reward: -0.5353096780622517
# episode: 229, total reward: -0.727, average_reward: -0.5361434162360929
# episode: 230, total reward: -0.697, average_reward: -0.5368398913403404
# episode: 231, total reward: 0.83, average_reward: -0.5309467355345053
# episode: 232, total reward: -0.768, average_reward: -0.5319627429715279
# episode: 233, total reward: 2.378, average_reward: -0.5195276994990924
# episode: 234, total reward: -0.76, average_reward: -0.5205521823126334
# episode: 235, total reward: -0.756, average_reward: -0.5215496427130335
# episode: 236, total reward: -0.771, average_reward: -0.5226015483431594
# episode: 237, total reward: -0.756, average_reward: -0.5235842235952562
# episode: 238, total reward: 0.826, average_reward: -0.5179368019693912
# episode: 239, total reward: -0.707, average_reward: -0.5187255936707003
# episode: 240, total reward: -0.754, average_reward: -0.5197035940076075
# episode: 241, total reward: -0.692, average_reward: -0.5204174221445923
# episode: 242, total reward: 1.706, average_reward: -0.5112564651374832
# episode: 243, total reward: -0.696, average_reward: -0.5120115745229917
# episode: 244, total reward: 0.723, average_reward: -0.5069718468720283
# episode: 245, total reward: -0.807, average_reward: -0.5081933303285895
# episode: 246, total reward: -0.759, average_reward: -0.5092099016649758
# episode: 247, total reward: -0.749, average_reward: -0.5101761625489316
# episode: 248, total reward: -0.775, average_reward: -0.5112410652682895
# episode: 249, total reward: 1.686, average_reward: -0.5024501831029571
# episode: 250, total reward: -0.753, average_reward: -0.5034491661645437
# episode: 251, total reward: -0.782, average_reward: -0.5045535587106225
# episode: 252, total reward: -0.735, average_reward: -0.5054651506310464
# episode: 253, total reward: -0.759, average_reward: -0.5064622972135475
# episode: 254, total reward: -0.772, average_reward: -0.5075028398894087
# episode: 255, total reward: -0.659, average_reward: -0.5080943836108749
# episode: 256, total reward: 1.124, average_reward: -0.5017426278428508
# episode: 257, total reward: 1.284, average_reward: -0.494821114686388
# episode: 258, total reward: -0.759, average_reward: -0.49584181499480967
# episode: 259, total reward: -0.746, average_reward: -0.4968032898011732
# episode: 260, total reward: -0.799, average_reward: -0.4979614400590225
# episode: 261, total reward: 2.064, average_reward: -0.48818327843361287
# episode: 262, total reward: 0.773, average_reward: -0.48338702326293187
# episode: 263, total reward: 1.131, average_reward: -0.47727308215934944
# episode: 264, total reward: -0.773, average_reward: -0.4783874223263642
# episode: 265, total reward: -0.746, average_reward: -0.47939306399612314
# episode: 266, total reward: -0.72, average_reward: -0.48029265242695013
# episode: 267, total reward: -0.685, average_reward: -0.48105468212111846
# episode: 268, total reward: 0.829, average_reward: -0.47618481571485205
# episode: 269, total reward: 0.766, average_reward: -0.4715857718178693
# episode: 270, total reward: -0.734, average_reward: -0.47255475239062816
# episode: 271, total reward: -0.75, average_reward: -0.4735757437886741
# episode: 272, total reward: -0.766, average_reward: -0.47464823791847577
# episode: 273, total reward: -0.713, average_reward: -0.47551641370470865
# episode: 274, total reward: -0.733, average_reward: -0.47645272506080305
# episode: 275, total reward: 1.578, average_reward: -0.46900765242102005
# episode: 276, total reward: -0.696, average_reward: -0.4698256954992534
# episode: 277, total reward: -0.748, average_reward: -0.47082625617304363
# episode: 278, total reward: -0.696, average_reward: -0.4716331998159295
# episode: 279, total reward: 1.735, average_reward: -0.4637507602791137
# episode: 280, total reward: -0.77, average_reward: -0.4648411382701482
# episode: 281, total reward: -0.74, average_reward: -0.46581582882967015
# episode: 282, total reward: -0.693, average_reward: -0.46661991202553027
# episode: 283, total reward: -0.736, average_reward: -0.4675690833813861
# episode: 284, total reward: -0.814, average_reward: -0.46878470629999225
# episode: 285, total reward: -0.695, average_reward: -0.4695755710497342
# episode: 286, total reward: -0.78, average_reward: -0.47065886283114966
# episode: 287, total reward: -0.765, average_reward: -0.47168209450270066
# episode: 288, total reward: -0.784, average_reward: -0.4727614697245603
# episode: 289, total reward: -0.734, average_reward: -0.47366188285001704
# episode: 290, total reward: 1.998, average_reward: -0.46516802640217253
# episode: 291, total reward: -0.794, average_reward: -0.4662926786049702
# episode: 292, total reward: -0.743, average_reward: -0.46723554105981396
# episode: 293, total reward: -0.798, average_reward: -0.4683604455126845
# episode: 294, total reward: -0.751, average_reward: -0.4693187588132438
# episode: 295, total reward: -0.794, average_reward: -0.47041622014931944
# episode: 296, total reward: -0.78, average_reward: -0.4714579715961191
# episode: 297, total reward: -0.719, average_reward: -0.4722872220394437
# episode: 298, total reward: 2.639, average_reward: -0.46188319281444556
# episode: 299, total reward: 1.563, average_reward: -0.4551350538580034
# episode: 300, total reward: -0.701, average_reward: -0.4559516126442666
# episode: 301, total reward: -0.756, average_reward: -0.4569452402379647
# episode: 302, total reward: -0.744, average_reward: -0.45789306207015135
# episode: 303, total reward: -0.686, average_reward: -0.45864417775213684
# episode: 304, total reward: 0.697, average_reward: -0.4548552339783947
# episode: 305, total reward: -0.734, average_reward: -0.4557672681872087
# episode: 306, total reward: -0.803, average_reward: -0.45689740701098625
# episode: 307, total reward: -0.749, average_reward: -0.45784730761602965
# episode: 308, total reward: -0.682, average_reward: -0.45857352624030384
# episode: 309, total reward: -0.69, average_reward: -0.45932010625890507
# episode: 310, total reward: -0.755, average_reward: -0.46027094025561427
# episode: 311, total reward: -0.718, average_reward: -0.4610965392307367
# episode: 312, total reward: -0.743, average_reward: -0.46199661649688434
# episode: 313, total reward: 2.061, average_reward: -0.45396006325907984
# episode: 314, total reward: -0.755, average_reward: -0.4549161123946158
# episode: 315, total reward: 1.579, average_reward: -0.4484784185500431
# episode: 316, total reward: 1.204, average_reward: -0.4432647415308057
# episode: 317, total reward: -0.734, average_reward: -0.4441790908367972
# episode: 318, total reward: -0.83, average_reward: -0.4453872363242228
# episode: 319, total reward: -0.771, average_reward: -0.4464053567023937
# episode: 320, total reward: -0.743, average_reward: -0.44733065069150757
# episode: 321, total reward: -0.726, average_reward: -0.44819562263490975
# episode: 322, total reward: -0.743, average_reward: -0.4491078639015838
# episode: 323, total reward: -0.742, average_reward: -0.4500121910605797
# episode: 324, total reward: -0.79, average_reward: -0.4510597130498431
# episode: 325, total reward: 2.053, average_reward: -0.4433792707052816
# episode: 326, total reward: -0.781, average_reward: -0.44441035358945735
# episode: 327, total reward: 1.946, average_reward: -0.4371236007772736
# episode: 328, total reward: 1.261, average_reward: -0.4319634070061458
# episode: 329, total reward: -0.728, average_reward: -0.432859730571593
# episode: 330, total reward: -0.743, average_reward: -0.4337964129129894
# episode: 331, total reward: -0.798, average_reward: -0.43489393380719704
# episode: 332, total reward: 0.788, average_reward: -0.4312201714467932
# episode: 333, total reward: -0.751, average_reward: -0.4321762120645057
# episode: 334, total reward: 0.81, average_reward: -0.4284670134813575
# episode: 335, total reward: -0.81, average_reward: -0.4296017362479703
# episode: 336, total reward: -0.745, average_reward: -0.43053894393232583
# episode: 337, total reward: 1.643, average_reward: -0.42440368794391153
# episode: 338, total reward: -0.73, average_reward: -0.4253052742823027
# episode: 339, total reward: -0.745, average_reward: -0.4262461323661455
# episode: 340, total reward: -0.735, average_reward: -0.4271512425588378
# episode: 341, total reward: 0.736, average_reward: -0.423750674148325
# episode: 342, total reward: -0.768, average_reward: -0.42475536819908355
# episode: 343, total reward: -0.809, average_reward: -0.42587242517536356
# episode: 344, total reward: -0.761, average_reward: -0.42684423246765596
# episode: 345, total reward: -0.701, average_reward: -0.427636015281535
# episode: 346, total reward: -0.767, average_reward: -0.428614600030539
# episode: 347, total reward: -0.745, average_reward: -0.4295234376555375
# episode: 348, total reward: -0.736, average_reward: -0.43040166357259435
# episode: 349, total reward: -0.74, average_reward: -0.43128598143020375
# episode: 350, total reward: -0.777, average_reward: -0.4322706726304277
# episode: 351, total reward: -0.78, average_reward: -0.43325774849246007
# episode: 352, total reward: -0.7, average_reward: -0.43401477142812095
# episode: 353, total reward: -0.777, average_reward: -0.4349823585775361
# episode: 354, total reward: -0.675, average_reward: -0.43565791516581176
# episode: 355, total reward: -0.775, average_reward: -0.4366122792253852
# episode: 356, total reward: -0.797, average_reward: -0.43762108076403694
# episode: 357, total reward: -0.666, average_reward: -0.4382585622951109
# episode: 358, total reward: 1.555, average_reward: -0.4327059172655096
# episode: 359, total reward: -0.743, average_reward: -0.43356729525442245
# episode: 360, total reward: -0.712, average_reward: -0.43433926742958007
# episode: 361, total reward: -0.779, average_reward: -0.43529055890203205
# episode: 362, total reward: 0.758, average_reward: -0.43200404085555794
# episode: 363, total reward: -0.798, average_reward: -0.43300986537184466
# episode: 364, total reward: -0.741, average_reward: -0.4338548399372223
# episode: 365, total reward: -0.721, average_reward: -0.4346386596278322
# episode: 366, total reward: -0.737, average_reward: -0.43546323518998514
# episode: 367, total reward: 1.649, average_reward: -0.42979941721333864
# episode: 368, total reward: -0.765, average_reward: -0.43070720644480204
# episode: 369, total reward: -0.724, average_reward: -0.431500794308189
# episode: 370, total reward: -0.757, average_reward: -0.4323791909162884
# episode: 371, total reward: 1.206, average_reward: -0.4279750907414729
# episode: 372, total reward: -0.696, average_reward: -0.42869359168735427
# episode: 373, total reward: -0.777, average_reward: -0.4296254204809056
# episode: 374, total reward: -0.754, average_reward: -0.43049133998699185
# episode: 375, total reward: -0.692, average_reward: -0.43118652801105284
# episode: 376, total reward: -0.814, average_reward: -0.4322017275196502
# episode: 377, total reward: -0.762, average_reward: -0.4330733375678278
# episode: 378, total reward: -0.809, average_reward: -0.4340655941866605
# episode: 379, total reward: -0.79, average_reward: -0.4350012712353444
# episode: 380, total reward: 1.729, average_reward: -0.4293226377336695
# episode: 381, total reward: -0.738, average_reward: -0.43013111041130264
# episode: 382, total reward: 1.413, average_reward: -0.42531916820744803
# episode: 383, total reward: -0.768, average_reward: -0.42621179597751846
# episode: 384, total reward: -0.736, average_reward: -0.42701526539103923
# episode: 385, total reward: -0.761, average_reward: -0.4278792314815497
# episode: 386, total reward: -0.733, average_reward: -0.42866797570939386
# episode: 387, total reward: 2.082, average_reward: -0.4221968464403909
# episode: 388, total reward: -0.752, average_reward: -0.4230437278123557
# episode: 389, total reward: -0.697, average_reward: -0.4237453321238058
# episode: 390, total reward: -0.705, average_reward: -0.4244652412628578
# episode: 391, total reward: -0.74, average_reward: -0.425269421453655
# episode: 392, total reward: -0.729, average_reward: -0.42604178180579594
# episode: 393, total reward: -0.658, average_reward: -0.42662968960503106
# episode: 394, total reward: -0.778, average_reward: -0.4275185514912982
# episode: 395, total reward: -0.728, average_reward: -0.42827788357737917
# episode: 396, total reward: -0.766, average_reward: -0.4291278829855861
# episode: 397, total reward: -0.735, average_reward: -0.429895596719906
# episode: 398, total reward: 2.167, average_reward: -0.4233878898818573
# episode: 399, total reward: -0.73, average_reward: -0.42415378697091666
# episode: 400, total reward: -0.829, average_reward: -0.4251626231149381
# episode: 401, total reward: -0.754, average_reward: -0.42598015711515574
# episode: 402, total reward: -0.765, average_reward: -0.4268203201545464
# episode: 403, total reward: -0.826, average_reward: -0.4278078672062983
# episode: 404, total reward: 1.746, average_reward: -0.42244067771014676
# episode: 405, total reward: -0.751, average_reward: -0.423250543891808
# episode: 406, total reward: -0.727, average_reward: -0.4239970348899113
# episode: 407, total reward: -0.768, average_reward: -0.4248412409896566
# episode: 408, total reward: -0.785, average_reward: -0.42572166490804036
# episode: 409, total reward: -0.775, average_reward: -0.4265739889946869
# episode: 410, total reward: -0.745, average_reward: -0.427349107822777
# episode: 411, total reward: -0.75, average_reward: -0.4281314452715219
# episode: 412, total reward: -0.772, average_reward: -0.42896389887313063
# episode: 413, total reward: -0.77, average_reward: -0.4297876967427533
# episode: 414, total reward: -0.693, average_reward: -0.4304215813632541
# episode: 415, total reward: -0.759, average_reward: -0.43121031239334295
# episode: 416, total reward: -0.654, average_reward: -0.43174421857195494
# episode: 417, total reward: -0.797, average_reward: -0.43261823570477353
# episode: 418, total reward: -0.792, average_reward: -0.43347597987154934
# episode: 419, total reward: -0.771, average_reward: -0.43427936793892535
# episode: 420, total reward: -0.778, average_reward: -0.43509604578367567
# episode: 421, total reward: -0.67, average_reward: -0.4356531723924682
# episode: 422, total reward: -0.779, average_reward: -0.43646553780082004
# episode: 423, total reward: -0.778, average_reward: -0.4372713344444955
# episode: 424, total reward: -0.71, average_reward: -0.43791345672185095
# episode: 425, total reward: -0.755, average_reward: -0.43865675037175433
# episode: 426, total reward: -0.77, average_reward: -0.4394322039630886
# episode: 427, total reward: 1.32, average_reward: -0.4353214020103655
# episode: 428, total reward: -0.768, average_reward: -0.4360979832170123
# episode: 429, total reward: -0.785, average_reward: -0.4369087909846403
# episode: 430, total reward: -0.751, average_reward: -0.4376364600673197
# episode: 431, total reward: 0.753, average_reward: -0.4348792545118738
# episode: 432, total reward: -0.77, average_reward: -0.4356530867763252
# episode: 433, total reward: -0.785, average_reward: -0.43645840334556985
# episode: 434, total reward: 2.399, average_reward: -0.4299411793036408
# episode: 435, total reward: -0.727, average_reward: -0.43062222907925707
# episode: 436, total reward: -0.79, average_reward: -0.43144518301696777
# episode: 437, total reward: -0.781, average_reward: -0.432243861072243
# episode: 438, total reward: -0.767, average_reward: -0.43300613396683846
# episode: 439, total reward: -0.8, average_reward: -0.4338394665595023
# episode: 440, total reward: -0.759, average_reward: -0.4345778174628584
# episode: 441, total reward: -0.796, average_reward: -0.4353964141977914
# episode: 442, total reward: -0.67, average_reward: -0.43592662100122054
# episode: 443, total reward: -0.682, average_reward: -0.43648098100987665
# episode: 444, total reward: -0.759, average_reward: -0.43720514537976585
# episode: 445, total reward: -0.802, average_reward: -0.43802281646704444
# episode: 446, total reward: -0.721, average_reward: -0.4386556069420892
# episode: 447, total reward: -0.726, average_reward: -0.4392962539483293
# episode: 448, total reward: -0.762, average_reward: -0.4400145424627611
# episode: 449, total reward: -0.723, average_reward: -0.44064266469775853
# episode: 450, total reward: -0.719, average_reward: -0.44126039860213073
# episode: 451, total reward: -0.659, average_reward: -0.44174171488290226
# episode: 452, total reward: -0.779, average_reward: -0.4424867483499545
# episode: 453, total reward: -0.756, average_reward: -0.4431765840949506
# episode: 454, total reward: -0.815, average_reward: -0.44399389121790217
# episode: 455, total reward: -0.766, average_reward: -0.444700416576795
# episode: 456, total reward: -0.737, average_reward: -0.4453397422214228
# episode: 457, total reward: 2.179, average_reward: -0.43961044716801007
# episode: 458, total reward: -0.73, average_reward: -0.4402438345649081
# episode: 459, total reward: -0.737, average_reward: -0.4408884093981018
# episode: 460, total reward: 0.813, average_reward: -0.438167777818063
# episode: 461, total reward: -0.772, average_reward: -0.43889137754762314
# episode: 462, total reward: -0.853, average_reward: -0.439786030783497
# episode: 463, total reward: -0.746, average_reward: -0.44044653586174615
# episode: 464, total reward: -0.749, average_reward: -0.4411096071902643
# episode: 465, total reward: -0.792, average_reward: -0.44186341299149634
# episode: 466, total reward: -0.727, average_reward: -0.4424741501152519
# episode: 467, total reward: -0.77, average_reward: -0.4431733700397051
# episode: 468, total reward: -0.746, average_reward: -0.44381808721901467
# episode: 469, total reward: -0.764, average_reward: -0.4444990976391482
# episode: 470, total reward: -0.701, average_reward: -0.44504432065326444
# episode: 471, total reward: -0.755, average_reward: -0.44570174181037275
# episode: 472, total reward: -0.797, average_reward: -0.44644430842803934
# episode: 473, total reward: -0.825, average_reward: -0.4472433633083983
# episode: 474, total reward: -0.792, average_reward: -0.4479691942100308
# episode: 475, total reward: -0.674, average_reward: -0.4484450524531206
# episode: 476, total reward: -0.726, average_reward: -0.4490260217108165
# episode: 477, total reward: -0.75, average_reward: -0.4496561488683431
# episode: 478, total reward: -0.824, average_reward: -0.4504373540615823
# episode: 479, total reward: -0.769, average_reward: -0.45110028639973093
# episode: 480, total reward: -0.816, average_reward: -0.45185979814477784
# episode: 481, total reward: -0.765, average_reward: -0.45250956522000835
# episode: 482, total reward: -0.745, average_reward: -0.4531154151937221
# episode: 483, total reward: -0.744, average_reward: -0.45371676246247117
# episode: 484, total reward: -0.786, average_reward: -0.45440227695757957
# episode: 485, total reward: -0.768, average_reward: -0.45504729117840187
# episode: 486, total reward: -0.759, average_reward: -0.4556714003105228
# episode: 487, total reward: -0.813, average_reward: -0.45640409318683794
# episode: 488, total reward: -0.762, average_reward: -0.4570280606495462
# episode: 489, total reward: -0.801, average_reward: -0.4577296471129724
# episode: 490, total reward: -0.802, average_reward: -0.4584305991118605
# episode: 491, total reward: -0.789, average_reward: -0.45910290969065487
# episode: 492, total reward: -0.768, average_reward: -0.4597292307425545
# episode: 493, total reward: -0.728, average_reward: -0.4602720408216063
# episode: 494, total reward: -0.768, average_reward: -0.46089465529108997
# episode: 495, total reward: -0.791, average_reward: -0.4615594208280079
# episode: 496, total reward: -0.821, average_reward: -0.46228181379990474
# episode: 497, total reward: -0.864, average_reward: -0.46308849774581895
# episode: 498, total reward: -0.725, average_reward: -0.46361370030593474
# episode: 499, total reward: -0.667, average_reward: -0.4640198764598629
# episode: 500, total reward: -0.805, average_reward: -0.46470065280963885
# episode: 501, total reward: -0.764, average_reward: -0.4652970585385171
# episode: 502, total reward: -0.855, average_reward: -0.4660717675187504
# episode: 503, total reward: -0.824, average_reward: -0.466782634902889
# episode: 504, total reward: -0.77, average_reward: -0.4673834789843187
# episode: 505, total reward: -0.809, average_reward: -0.4680577916323566
# episode: 506, total reward: -0.758, average_reward: -0.4686294236023101
# episode: 507, total reward: -0.75, average_reward: -0.46918370255256503
# episode: 508, total reward: -0.806, average_reward: -0.46984630122965215
# episode: 509, total reward: -0.822, average_reward: -0.4705366959825404
# episode: 510, total reward: -0.781, average_reward: -0.4711435470504807
# episode: 511, total reward: -0.657, average_reward: -0.471505656176355
# episode: 512, total reward: -0.773, average_reward: -0.4720935616818804
# episode: 513, total reward: -0.806, average_reward: -0.47274413179233254
# episode: 514, total reward: -0.783, average_reward: -0.4733464308420323
# episode: 515, total reward: -0.73, average_reward: -0.4738441905229238
# episode: 516, total reward: -0.814, average_reward: -0.47450197108816433
# episode: 517, total reward: -0.755, average_reward: -0.475042639850693
# episode: 518, total reward: -0.757, average_reward: -0.47558549894369745
# episode: 519, total reward: -0.797, average_reward: -0.47620325211232534
# episode: 520, total reward: -0.744, average_reward: -0.47671788480445315
# episode: 521, total reward: -0.811, average_reward: -0.4773590086972843
# episode: 522, total reward: -0.789, average_reward: -0.47795564357692
# episode: 523, total reward: -0.826, average_reward: -0.4786191921894665
# episode: 524, total reward: -0.77, average_reward: -0.47917460114915306
# episode: 525, total reward: -0.808, average_reward: -0.4798005586568107
# episode: 526, total reward: -0.72, average_reward: -0.4802563751902111
# episode: 527, total reward: -0.813, average_reward: -0.4808859912002733
# episode: 528, total reward: -0.744, average_reward: -0.48138294374214347
# episode: 529, total reward: -0.769, average_reward: -0.48192490715979514
# episode: 530, total reward: -0.765, average_reward: -0.48245708374932633
# episode: 531, total reward: -0.798, average_reward: -0.4830495099984994
# episode: 532, total reward: -0.73, average_reward: -0.4835137214972579
# episode: 533, total reward: -0.821, average_reward: -0.48414514416080623
# episode: 534, total reward: -0.771, average_reward: -0.48468185004153364
# episode: 535, total reward: -0.784, average_reward: -0.4852411667909827
# episode: 536, total reward: -0.788, average_reward: -0.48580484921264394
# episode: 537, total reward: -0.806, average_reward: -0.4864001214238277
# episode: 538, total reward: -0.815, average_reward: -0.48701026029520256
# episode: 539, total reward: -0.794, average_reward: -0.4875789506666374
# episode: 540, total reward: -0.852, average_reward: -0.4882533976202831
# episode: 541, total reward: -0.755, average_reward: -0.4887453491536856
# episode: 542, total reward: -0.766, average_reward: -0.4892566164725096
# episode: 543, total reward: -0.806, average_reward: -0.48983813641895546
# episode: 544, total reward: -0.762, average_reward: -0.4903367939228598
# episode: 545, total reward: -0.686, average_reward: -0.4906951261410045
# episode: 546, total reward: -0.78, average_reward: -0.4912234373332314
# episode: 547, total reward: -0.785, average_reward: -0.49175891685882706
# episode: 548, total reward: -0.82, average_reward: -0.4923569530337872
# episode: 549, total reward: -0.835, average_reward: -0.49297903736767734
# episode: 550, total reward: -0.749, average_reward: -0.49344433546783223
# episode: 551, total reward: -0.804, average_reward: -0.4940067593850224
# episode: 552, total reward: -0.754, average_reward: -0.49447685110337963
# episode: 553, total reward: -0.841, average_reward: -0.495101954795966
# episode: 554, total reward: -0.783, average_reward: -0.4956212294353401
# episode: 555, total reward: -0.767, average_reward: -0.49610855377043683
# episode: 556, total reward: -0.819, average_reward: -0.4966880817906524
# episode: 557, total reward: -0.774, average_reward: -0.49718423640845383
# episode: 558, total reward: -0.805, average_reward: -0.4977345616928805
# episode: 559, total reward: -0.755, average_reward: -0.49819453389335827
# episode: 560, total reward: -0.773, average_reward: -0.4986842984273199
# episode: 561, total reward: -0.823, average_reward: -0.49926098035557176
# episode: 562, total reward: -0.75, average_reward: -0.49970642963372025
# episode: 563, total reward: -0.804, average_reward: -0.5002457840807472
# episode: 564, total reward: -0.833, average_reward: -0.500835232296211
# episode: 565, total reward: -0.817, average_reward: -0.501393936971238
# episode: 566, total reward: -0.793, average_reward: -0.5019077340548511
# episode: 567, total reward: -0.762, average_reward: -0.5023648052668164
# episode: 568, total reward: -0.758, average_reward: -0.5028137495083169
# episode: 569, total reward: -0.792, average_reward: -0.5033219223209567
# episode: 570, total reward: -0.7, average_reward: -0.5036664211796457
# episode: 571, total reward: -0.825, average_reward: -0.504228519431348
# episode: 572, total reward: -0.8, average_reward: -0.5047445443952585
# episode: 573, total reward: -0.747, average_reward: -0.5051670475991851
# episode: 574, total reward: -0.781, average_reward: -0.5056462586116002
# episode: 575, total reward: -0.771, average_reward: -0.5061070784344944
# episode: 576, total reward: -0.702, average_reward: -0.5064468292073374
# episode: 577, total reward: -0.76, average_reward: -0.5068847423835591
# episode: 578, total reward: -0.826, average_reward: -0.5074356660837364
# episode: 579, total reward: -0.751, average_reward: -0.5078560368131407
# episode: 580, total reward: -0.852, average_reward: -0.5084491499211886
# episode: 581, total reward: -0.776, average_reward: -0.5089090876896302
# episode: 582, total reward: -0.766, average_reward: -0.5093508411543609
# episode: 583, total reward: -0.728, average_reward: -0.5097257990002989
# episode: 584, total reward: -0.792, average_reward: -0.5102075812717167
# episode: 585, total reward: -0.789, average_reward: -0.5106838559478434
# episode: 586, total reward: -0.831, average_reward: -0.5112298394434056
# episode: 587, total reward: -0.657, average_reward: -0.511478445129282
# episode: 588, total reward: -0.746, average_reward: -0.5118768863937891
# episode: 589, total reward: -0.762, average_reward: -0.5123002149907722
# episode: 590, total reward: -0.821, average_reward: -0.5128222861736168
# episode: 591, total reward: -0.744, average_reward: -0.5132131089682769
# episode: 592, total reward: -0.787, average_reward: -0.5136745028320138
# episode: 593, total reward: -0.805, average_reward: -0.5141657606215895
# episode: 594, total reward: -0.777, average_reward: -0.514608293132608
# episode: 595, total reward: -0.78, average_reward: -0.5150528114112966
# episode: 596, total reward: -0.757, average_reward: -0.5154577453611503
# episode: 597, total reward: -0.782, average_reward: -0.5159033556374585
# episode: 598, total reward: -0.765, average_reward: -0.5163193027921366
# episode: 599, total reward: -0.774, average_reward: -0.5167481558163505
# episode: 600, total reward: -0.73, average_reward: -0.5171031127089987
# episode: 601, total reward: -0.767, average_reward: -0.5175187999831156
# episode: 602, total reward: -0.751, average_reward: -0.517906412691567
# episode: 603, total reward: -0.839, average_reward: -0.5184386990099613
# episode: 604, total reward: -0.798, average_reward: -0.5189015196843193
# episode: 605, total reward: -0.766, average_reward: -0.5193086924940388
# episode: 606, total reward: -0.754, average_reward: -0.5196953943524986
# episode: 607, total reward: -0.821, average_reward: -0.5201904569009846
# episode: 608, total reward: -0.785, average_reward: -0.5206252377299394
# episode: 609, total reward: -0.788, average_reward: -0.5210636504450414
# episode: 610, total reward: -0.74, average_reward: -0.5214220134143582
# episode: 611, total reward: -0.742, average_reward: -0.5217831252991031
# episode: 612, total reward: -0.769, average_reward: -0.5221860397205823
# episode: 613, total reward: -0.762, average_reward: -0.5225763367413656
# episode: 614, total reward: -0.77, average_reward: -0.5229779940129703
# episode: 615, total reward: -0.828, average_reward: -0.5234735497409174
# episode: 616, total reward: -0.807, average_reward: -0.5239337534982293
# episode: 617, total reward: -0.751, average_reward: -0.524300433456541
# episode: 618, total reward: -0.753, average_reward: -0.524670318824453
# episode: 619, total reward: -0.772, average_reward: -0.5250690201805681
# episode: 620, total reward: -0.782, average_reward: -0.5254824316795166
# episode: 621, total reward: -0.795, average_reward: -0.5259151675640604
# episode: 622, total reward: -0.8, average_reward: -0.5263556860692106
# episode: 623, total reward: -0.816, average_reward: -0.5268201689792027
# episode: 624, total reward: -0.801, average_reward: -0.5272585610821726
# episode: 625, total reward: -0.778, average_reward: -0.5276587278775209
# episode: 626, total reward: 1.265, average_reward: -0.5247989225412951
# episode: 627, total reward: -0.801, average_reward: -0.5252388053444104
# episode: 628, total reward: -0.758, average_reward: -0.5256090904009251
# episode: 629, total reward: -0.785, average_reward: -0.5260213658823959
# episode: 630, total reward: -0.833, average_reward: -0.5265077663525025
# episode: 631, total reward: -0.763, average_reward: -0.5268816162508676
# episode: 632, total reward: -0.804, average_reward: -0.5273192477224411
# episode: 633, total reward: -0.764, average_reward: -0.5276931719019179
# episode: 634, total reward: -0.809, average_reward: -0.5281363893816142
# episode: 635, total reward: -0.741, average_reward: -0.5284706412144896
# episode: 636, total reward: -0.773, average_reward: -0.528855237792443
# episode: 637, total reward: -0.767, average_reward: -0.5292281969937468
# episode: 638, total reward: -0.825, average_reward: -0.5296911154991454
# episode: 639, total reward: -0.767, average_reward: -0.5300620552147727
# episode: 640, total reward: -0.796, average_reward: -0.5304776333784238
# episode: 641, total reward: -0.823, average_reward: -0.5309329323016737
# episode: 642, total reward: -0.787, average_reward: -0.5313307799058108
# episode: 643, total reward: -0.852, average_reward: -0.531829419614946
# episode: 644, total reward: -0.831, average_reward: -0.5322926179751212
# episode: 645, total reward: -0.776, average_reward: -0.5326692871211732
# episode: 646, total reward: -0.736, average_reward: -0.5329831719844685
# episode: 647, total reward: -0.846, average_reward: -0.5334655883342185
# episode: 648, total reward: -0.78, average_reward: -0.5338447626201588
# episode: 649, total reward: -0.76, average_reward: -0.5341928733418704
# episode: 650, total reward: -0.758, average_reward: -0.5345359481381885
# episode: 651, total reward: 0.763, average_reward: -0.5325460924130899
# episode: 652, total reward: -0.766, average_reward: -0.5329028409355315
# episode: 653, total reward: -0.778, average_reward: -0.5332777801405244
# episode: 654, total reward: -0.784, average_reward: -0.5336602953248275
# episode: 655, total reward: -0.821, average_reward: -0.5340987678397592
# episode: 656, total reward: -0.826, average_reward: -0.5345426348589095
# episode: 657, total reward: -0.77, average_reward: -0.5349007902710158
# episode: 658, total reward: -0.855, average_reward: -0.5353866118263191
# episode: 659, total reward: -0.806, average_reward: -0.5357971281218659
# episode: 660, total reward: -0.764, average_reward: -0.5361429886051658
# episode: 661, total reward: -0.791, average_reward: -0.5365279964975266
# episode: 662, total reward: -0.773, average_reward: -0.5368841641697704
# episode: 663, total reward: -0.803, average_reward: -0.5372845075534531
# episode: 664, total reward: -0.726, average_reward: -0.5375683050658562
# episode: 665, total reward: -0.85, average_reward: -0.538037337633935
# episode: 666, total reward: -0.76, average_reward: -0.5383701247614026
# episode: 667, total reward: -0.788, average_reward: -0.538743593623304
# episode: 668, total reward: -0.777, average_reward: -0.5390999065543788
# ...
# episode: 3223, total reward: -0.806, average_reward: -0.7308673152118522
# episode: 3224, total reward: -0.784, average_reward: -0.7308836865578159
# episode: 3225, total reward: -0.768, average_reward: -0.7308952750773903
# episode: 3226, total reward: -0.763, average_reward: -0.7309052238426886
# episode: 3227, total reward: -0.799, average_reward: -0.7309262980087977
# episode: 3228, total reward: -0.848, average_reward: -0.7309626340518391
# episode: 3229, total reward: -0.78, average_reward: -0.7309778860103388
# episode: 3230, total reward: -0.788, average_reward: -0.7309955497792135
# episode: 3231, total reward: -0.795, average_reward: -0.7310152899073094
# episode: 3232, total reward: -0.838, average_reward: -0.7310484606015639
# episode: 3233, total reward: -0.817, average_reward: -0.7310750504777112
# episode: 3234, total reward: -0.775, average_reward: -0.7310886884111323
# episode: 3235, total reward: -0.847, average_reward: -0.7311244547698872
# episode: 3236, total reward: -0.764, average_reward: -0.7311345655732997
# episode: 3237, total reward: -0.796, average_reward: -0.731154618057007
# episode: 3238, total reward: -0.807, average_reward: -0.7311780813174997
# episode: 3239, total reward: -0.784, average_reward: -0.7311942809547305
# episode: 3240, total reward: -0.827, average_reward: -0.7312237059873463
# episode: 3241, total reward: -0.787, average_reward: -0.7312408831588573
# episode: 3242, total reward: -0.808, average_reward: -0.7312644314876249
# episode: 3243, total reward: -0.782, average_reward: -0.731280048872171
# episode: 3244, total reward: -0.821, average_reward: -0.7313077295296746
# episode: 3245, total reward: -0.781, average_reward: -0.7313231394817553
# episode: 3246, total reward: -0.816, average_reward: -0.7313491938742396
# episode: 3247, total reward: -0.799, average_reward: -0.7313700991653208
# episode: 3248, total reward: -0.799, average_reward: -0.7313908765686005
# episode: 3249, total reward: -0.772, average_reward: -0.7314035165613101
# episode: 3250, total reward: -0.824, average_reward: -0.7314318899931266
# episode: 3251, total reward: -0.752, average_reward: -0.7314382583332943
# episode: 3252, total reward: -0.783, average_reward: -0.7314540867636831
# episode: 3253, total reward: -0.792, average_reward: -0.7314726577925325
# episode: 3254, total reward: -0.789, average_reward: -0.7314904698966106
# episode: 3255, total reward: -0.808, average_reward: -0.7315138930862625
# episode: 3256, total reward: -0.823, average_reward: -0.731541977218799
# episode: 3257, total reward: -0.791, average_reward: -0.7315603750707872
# episode: 3258, total reward: -0.725, average_reward: -0.7315583269519383
# episode: 3259, total reward: -0.76, average_reward: -0.7315672042200815
# episode: 3260, total reward: -0.794, average_reward: -0.7315864839195285
# episode: 3261, total reward: -0.757, average_reward: -0.7315942988423091
# episode: 3262, total reward: -0.691, average_reward: -0.7315819780467226
# episode: 3263, total reward: -0.785, average_reward: -0.7315983083894781
# episode: 3264, total reward: -0.806, average_reward: -0.7316210021799021
# episode: 3265, total reward: -0.812, average_reward: -0.7316457512005794
# episode: 3266, total reward: -0.769, average_reward: -0.7316572874949756
# episode: 3267, total reward: -0.816, average_reward: -0.7316829635104505
# episode: 3268, total reward: -0.814, average_reward: -0.7317080872908881
# episode: 3269, total reward: -0.776, average_reward: -0.7317217372840447
# episode: 3270, total reward: -0.786, average_reward: -0.7317381837261968
# episode: 3271, total reward: -0.766, average_reward: -0.7317486510340402
# episode: 3272, total reward: -0.8, average_reward: -0.731769388615076
# episode: 3273, total reward: -0.867, average_reward: -0.7318105862407955
# episode: 3274, total reward: -0.824, average_reward: -0.7318388742012838
# episode: 3275, total reward: -0.778, average_reward: -0.7318529141523213
# episode: 3276, total reward: -0.768, average_reward: -0.7318638233564843
# episode: 3277, total reward: -0.792, average_reward: -0.7318820675195542
# episode: 3278, total reward: -0.792, average_reward: -0.7319003664360285
# episode: 3279, total reward: -0.838, average_reward: -0.731932612948314
# episode: 3280, total reward: -0.794, average_reward: -0.7319514648180632
# episode: 3281, total reward: -0.799, average_reward: -0.7319718495063628
# episode: 3282, total reward: -0.807, average_reward: -0.7319947772049435
# episode: 3283, total reward: -0.77, average_reward: -0.7320064136601263
# episode: 3284, total reward: -0.777, average_reward: -0.7320200167684594
# episode: 3285, total reward: -0.826, average_reward: -0.7320486774626754
# episode: 3286, total reward: -0.782, average_reward: -0.732063851952938
# episode: 3287, total reward: -0.786, average_reward: -0.7320803904179798
# episode: 3288, total reward: -0.806, average_reward: -0.7321027720366194
# episode: 3289, total reward: -0.833, average_reward: -0.7321334004971991
# episode: 3290, total reward: -0.808, average_reward: -0.7321563792194435
# episode: 3291, total reward: -0.765, average_reward: -0.7321663948692069
# episode: 3292, total reward: -0.802, average_reward: -0.7321876636054732
# episode: 3293, total reward: -0.786, average_reward: -0.7322039907601182
# episode: 3294, total reward: -0.786, average_reward: -0.7322201910480074
# episode: 3295, total reward: -0.818, average_reward: -0.7322461347521078
# episode: 3296, total reward: -0.825, average_reward: -0.7322741492321738
# episode: 3297, total reward: -0.78, average_reward: -0.7322886890474478
# episode: 3298, total reward: -0.776, average_reward: -0.7323020430565007
# episode: 3299, total reward: -0.767, average_reward: -0.732312576828194
# episode: 3300, total reward: -0.806, average_reward: -0.7323350398298791
# episode: 3301, total reward: -0.813, average_reward: -0.7323594598234076
# episode: 3302, total reward: -0.854, average_reward: -0.732396166002149
# episode: 3303, total reward: -0.813, average_reward: -0.7324204289801234
# episode: 3304, total reward: -0.776, average_reward: -0.732433610500386
# episode: 3305, total reward: -0.793, average_reward: -0.7324520528124514
# episode: 3306, total reward: -0.834, average_reward: -0.7324826599254832
# episode: 3307, total reward: -0.799, average_reward: -0.7325028901492112
# episode: 3308, total reward: -0.756, average_reward: -0.7325099009126904
# episode: 3309, total reward: -0.813, average_reward: -0.7325342636362209
# episode: 3310, total reward: -0.798, average_reward: -0.7325541279452409
# episode: 3311, total reward: -0.802, average_reward: -0.7325752356762573
# episode: 3312, total reward: -0.841, average_reward: -0.7326081088433107
# episode: 3313, total reward: -0.767, average_reward: -0.7326184795581306
# episode: 3314, total reward: -0.781, average_reward: -0.7326329878236448
# episode: 3315, total reward: -0.792, average_reward: -0.73265096929591
# episode: 3316, total reward: -0.848, average_reward: -0.7326858213947022
# episode: 3317, total reward: -0.676, average_reward: -0.7326688380147943
# episode: 3318, total reward: -0.775, average_reward: -0.7326817099497211
# episode: 3319, total reward: -0.798, average_reward: -0.7327014759981705
# episode: 3320, total reward: -0.808, average_reward: -0.7327242030390212
# episode: 3321, total reward: -0.777, average_reward: -0.7327375153865481
# episode: 3322, total reward: -0.76, average_reward: -0.7327455987588796
# episode: 3323, total reward: -0.787, average_reward: -0.7327620034165288
# episode: 3324, total reward: -0.782, average_reward: -0.7327767547696996
# episode: 3325, total reward: -0.813, average_reward: -0.7328007428305716
# episode: 3326, total reward: -0.825, average_reward: -0.7328283380012056
# episode: 3327, total reward: -0.816, average_reward: -0.7328534396698464
# episode: 3328, total reward: -0.758, average_reward: -0.7328611165740565
# episode: 3329, total reward: -0.759, average_reward: -0.7328690373237937
# episode: 3330, total reward: -0.788, average_reward: -0.7328855162896795
# episode: 3331, total reward: -0.788, average_reward: -0.7329019752168962
# episode: 3332, total reward: -0.791, average_reward: -0.7329194074875345
# episode: 3333, total reward: -0.86, average_reward: -0.7329574408880701
# episode: 3334, total reward: -0.794, average_reward: -0.7329756923048861
# episode: 3335, total reward: -0.754, average_reward: -0.7329818668135595
# episode: 3336, total reward: -0.767, average_reward: -0.7329920605118361
# episode: 3337, total reward: -0.822, average_reward: -0.7330186772221231
# episode: 3338, total reward: -0.772, average_reward: -0.7330304927883563
# episode: 3339, total reward: -0.767, average_reward: -0.7330405235291838
# episode: 3340, total reward: -0.729, average_reward: -0.733039207630568
# episode: 3341, total reward: 2.076, average_reward: -0.7321987429834363
# episode: 3342, total reward: -0.79, average_reward: -0.7322160323586719
# episode: 3343, total reward: -0.792, average_reward: -0.7322337863660362
# episode: 3344, total reward: -0.794, average_reward: -0.7322521925598249
# episode: 3345, total reward: -0.799, average_reward: -0.7322720807373573
# episode: 3346, total reward: -0.814, average_reward: -0.7322964605276308
# episode: 3347, total reward: -0.834, average_reward: -0.7323267392955761
# episode: 3348, total reward: -0.804, average_reward: -0.7323482169341616
# episode: 3349, total reward: -0.787, average_reward: -0.7323645046592636
# episode: 3350, total reward: -0.822, average_reward: -0.7323913543591359
# episode: 3351, total reward: -0.815, average_reward: -0.7324160980724267
# episode: 3352, total reward: -0.79, average_reward: -0.7324331421319055
# episode: 3353, total reward: -0.807, average_reward: -0.7324554197039572
# episode: 3354, total reward: -0.783, average_reward: -0.7324703993496695
# episode: 3355, total reward: -0.812, average_reward: -0.7324942290845607
# episode: 3356, total reward: -0.681, average_reward: -0.7324787629865378
# episode: 3357, total reward: -0.783, average_reward: -0.7324939411114685
# episode: 3358, total reward: -0.792, average_reward: -0.7325117854678955
# episode: 3359, total reward: -0.852, average_reward: -0.7325472202593928
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 env = DraftEnv(df_players)
# ----> 2 main(env)
#
# Cell In[8], line 24, in main(env)
#      22         action = env.reasonable_option()
#      23         # print(f'Action: {action}')
# ---> 24         env.step(action)
#      27 update_policy(policy_net, rewards, log_probs)
#      28 all_rewards.append(np.sum(rewards))
#
# File ~/files/fun_projects/fantasy_football_2024/rl_env.py:330, in DraftEnv.step(self, action)
#     328 # update the state
#     329 self.update_state()
# --> 330 reward = self.compute_reward(mgr_num)
#     332 self.cur_turn += 1
#     333 if self.cur_turn < len(self.turns):
#
# File ~/files/fun_projects/fantasy_football_2024/rl_env.py:254, in DraftEnv.compute_reward(self, mgr_num)
#     250 # print(f'recent_choice: {recent_choice}')
#     252 team = team.sort_values(by=self.objective, ascending=False).reset_index(drop=True)
# --> 254 starters = self.get_starters(mgr_num)
#     255 bench = self.get_bench(mgr_num)
#     257 starters_sum = starters[self.objective].sum()
#
# File ~/files/fun_projects/fantasy_football_2024/rl_env.py:228, in DraftEnv.get_starters(self, mgr_num)
#     226 starter_ids = []
#     227 for pos in STARTER_COMPOSITION.keys():
# --> 228     players_pos = team.loc[team["team_pos"] == pos]
#     229     players_pos = players_pos.sort_values(by=self.objective, ascending=False).reset_index(drop=True)
#     230     pos_starter_ids = players_pos.iloc[:STARTER_COMPOSITION[pos]]['sleeper_id'].values
#
# File ~/files/fun_projects/fantasy_football_2024/venv/lib/python3.9/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/files/fun_projects/fantasy_football_2024/venv/lib/python3.9/site-packages/pandas/core/indexing.py:1413, in _LocIndexer._getitem_axis(self, key, axis)
#    1411     return self._get_slice_axis(key, axis=axis)
#    1412 elif com.is_bool_indexer(key):
# -> 1413     return self._getbool_axis(key, axis=axis)
#    1414 elif is_list_like_indexer(key):
#    1415     # an iterable multi-selection
#    1416     if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#
# File ~/files/fun_projects/fantasy_football_2024/venv/lib/python3.9/site-packages/pandas/core/indexing.py:1209, in _LocationIndexer._getbool_axis(self, key, axis)
#    1205 @final
#    1206 def _getbool_axis(self, key, axis: AxisInt):
#    1207     # caller is responsible for ensuring non-None axis
#    1208     labels = self.obj._get_axis(axis)
# -> 1209     key = check_bool_indexer(labels, key)
#    1210     inds = key.nonzero()[0]
#    1211     return self.obj._take_with_is_copy(inds, axis=axis)
#
# File ~/files/fun_projects/fantasy_football_2024/venv/lib/python3.9/site-packages/pandas/core/indexing.py:2681, in check_bool_indexer(index, key)
#    2677 elif not is_array_like(result):
#    2678     # GH 33924
#    2679     # key may contain nan elements, check_array_indexer needs bool array
#    2680     result = pd_array(result, dtype=bool)
# -> 2681 return check_array_indexer(index, result)
#
# File ~/files/fun_projects/fantasy_football_2024/venv/lib/python3.9/site-packages/pandas/core/indexers/utils.py:535, in check_array_indexer(array, indexer)
#     533     indexer = indexer.to_numpy(dtype=bool, na_value=False)
#     534 else:
# --> 535     indexer = np.asarray(indexer, dtype=bool)
#     537 # GH26658
#     538 if len(indexer) != len(array):
#
# File ~/files/fun_projects/fantasy_football_2024/venv/lib/python3.9/site-packages/pandas/core/generic.py:6296, in NDFrame.__getattr__(self, name)
#    6286 """
#    6287 After regular attribute access, try looking up the name
#    6288 This allows simpler access to columns for interactive use.
#    6289 """
#    6290 # Note: obj.x will always call obj.__getattribute__('x') prior to
#    6291 # calling obj.__getattr__('x').
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
# -> 6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
#    6299 return object.__getattribute__(self, name)
#
# File ~/files/fun_projects/fantasy_football_2024/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:5449, in Index._can_hold_identifiers_and_holds_name(self, name)
#    5437 @final
#    5438 def _can_hold_identifiers_and_holds_name(self, name) -> bool:
#    5439     """
#    5440     Faster check for ``name in self`` when we know `name` is a Python
#    5441     identifier (e.g. in NDFrame.__getattr__, which hits this to support
#    (...)
#    5445     https://github.com/pandas-dev/pandas/issues/19764
#    5446     """
#    5447     if (
#    5448         is_object_dtype(self.dtype)
# -> 5449         or is_string_dtype(self.dtype)
#    5450         or isinstance(self.dtype, CategoricalDtype)
#    5451     ):
#    5452         return name in self
#    5453     return False
#
# File ~/files/fun_projects/fantasy_football_2024/venv/lib/python3.9/site-packages/pandas/core/dtypes/common.py:580, in is_string_dtype(arr_or_dtype)
#     577     except TypeError:
#     578         return False
# --> 580 return _is_dtype(arr_or_dtype, condition)
#
# File ~/files/fun_projects/fantasy_football_2024/venv/lib/python3.9/site-packages/pandas/core/dtypes/common.py:1396, in _is_dtype(arr_or_dtype, condition)
#    1394 except (TypeError, ValueError):
#    1395     return False
# -> 1396 return condition(dtype)
#
# File ~/files/fun_projects/fantasy_football_2024/venv/lib/python3.9/site-packages/pandas/core/dtypes/common.py:576, in is_string_dtype.<locals>.condition(dtype)
#     574     return True
#     575 try:
# --> 576     return dtype == "string"
#     577 except TypeError:
#     578     return False
#
# KeyboardInterrupt:

# %%
# show all rows of the dataframe
pd.set_option('display.max_rows', None)
env.draft
# Out:
#      round  mgr sleeper_id                 full_name  team position team_pos  \
# 0        0    0       9224               Chase Brown   CIN       RB     FLEX
# 1        0    1      11058               Blake Grupe    NO        K        K
# 2        0    2      11563                    Bo Nix   DEN       QB       QB
# 3        0    3       8121               Romeo Doubs    GB       WR     FLEX
# 4        0    4       6806              J.K. Dobbins   LAC       RB     FLEX
# 5        0    5       9228               Bryce Young   CAR       QB       QB
# 6        0    6       9753           Zach Charbonnet   SEA       RB     FLEX
# 7        0    7       8676            Rashid Shaheed    NO       WR     FLEX
# 8        0    8      11565             J.J. McCarthy   MIN       QB       QB
# 9        0    9      11604              Brock Bowers    LV       TE     FLEX
# 10       0   10       6011           Gardner Minshew    LV       QB       QB
# 11       0   11      11564                Drake Maye    NE       QB       QB
# 12       1   11         TB      Tampa Bay Buccaneers    TB      DEF      DEF
# 13       1   10        CIN        Cincinnati Bengals   CIN      DEF      DEF
# 14       1    9       7600            Pat Freiermuth   PIT       TE     FLEX
# 15       1    8        ATL           Atlanta Falcons   ATL      DEF      DEF
# 16       1    7       4082             Curtis Samuel   BUF       WR     FLEX
# 17       1    6       6945            Antonio Gibson    NE       RB     FLEX
# 18       1    5        MIN         Minnesota Vikings   MIN      DEF      DEF
# 19       1    4       7021               Rico Dowdle   DAL       RB     FLEX
# 20       1    3       6943                Gabe Davis   JAX       WR     FLEX
# 21       1    2        SEA          Seattle Seahawks   SEA      DEF      DEF
# 22       1    1       9501           DeMario Douglas    NE       WR       WR
# 23       1    0       4068             Mike Williams   NYJ       WR     FLEX
# 24       2    0       8119              Jahan Dotson   WAS       WR     FLEX
# 25       2    1       3257           Jacoby Brissett    NE       QB       QB
# 26       2    2        IND        Indianapolis Colts   IND      DEF      DEF
# 27       2    3       9500                Josh Downs   IND       WR     FLEX
# 28       2    4       7594             Chuba Hubbard   CAR       RB     FLEX
# 29       2    5       8126         Wan'Dale Robinson   NYG       WR     FLEX
# 30       2    6       8230               Ty Chandler   MIN       RB     FLEX
# 31       2    7      10232            Michael Wilson   ARI       WR     FLEX
# 32       2    8        CHI             Chicago Bears   CHI      DEF      DEF
# 33       2    9       9481             Luke Musgrave    GB       TE     FLEX
# 34       2   10        DET             Detroit Lions   DET      DEF      DEF
# 35       2   11         LV         Las Vegas Raiders    LV      DEF      DEF
# 36       3   11        JAX      Jacksonville Jaguars   JAX      DEF      DEF
# 37       3   10       4454           Kendrick Bourne    NE       WR     FLEX
# 38       3    9       3214              Hunter Henry    NE       TE     FLEX
# 39       3    8        NYG           New York Giants   NYG      DEF      DEF
# 40       3    7      11626            Xavier Legette   CAR       WR     FLEX
# 41       3    6       8132            Tyler Allgeier   ATL       RB     FLEX
# 42       3    5      11589               Trey Benson   ARI       RB       RB
# 43       3    4      11586               Blake Corum   LAR       RB     FLEX
# 44       3    3       9754          Quentin Johnston   LAC       WR     FLEX
# 45       3    2        CAR         Carolina Panthers   CAR      DEF      DEF
# 46       3    1       7591             Justin Fields   PIT       QB       QB
# 47       3    0       9494               Marvin Mims   DEN       WR     FLEX
# 48       4    0       9486          Dontayvion Wicks    GB       WR     FLEX
# 49       4    1      11439         Jaleel McLaughlin   DEN       RB       RB
# 50       4    2       2078             Odell Beckham   MIA       WR     FLEX
# 51       4    3       5323     Equanimeous St. Brown    NO       WR     FLEX
# 52       4    4      11581            MarShawn Lloyd    GB       RB     FLEX
# 53       4    5       7090            Darnell Mooney   ATL       WR     FLEX
# 54       4    6       4943               Sam Darnold   MIN       QB       QB
# 55       4    7       6149            Darius Slayton   NYG       WR     FLEX
# 56       4    8       6083                  Matt Gay   IND        K        K
# 57       4    9       5133             Tyler Conklin   NYJ       TE     FLEX
# 58       4   10       8210         Chigoziem Okonkwo   TEN       TE     FLEX
# 59       4   11      11625           Adonai Mitchell   IND       WR     FLEX
# 60       5   11       7571            Rashod Bateman   BAL       WR     FLEX
# 61       5   10       3286         Demarcus Robinson   LAR       WR     FLEX
# 62       5    9       7002             Juwan Johnson    NO       TE     FLEX
# 63       5    8        TEN          Tennessee Titans   TEN      DEF      DEF
# 64       5    7       9497               Jalin Hyatt   NYG       WR     FLEX
# 65       5    6       7608            Khalil Herbert   CHI       RB     FLEX
# 66       5    5       4951                  DJ Chark   LAC       WR     FLEX
# 67       5    4      10866           Aidan O'Connell    LV       QB       QB
# 68       5    3      11640           Jermaine Burton   CIN       WR     FLEX
# 69       5    2       8111                Cade Otton    TB       TE     FLEX
# 70       5    1       5857                 Noah Fant   SEA       TE       TE
# 71       5    0      11630              Roman Wilson   PIT       WR     FLEX
# 72       6    0       3225                Tyler Boyd   TEN       WR     FLEX
# 73       6    1       6650          Chase McLaughlin    TB        K        K
# 74       6    2      10235           Roschon Johnson   CHI       RB       RB
# 75       6    3        LAC      Los Angeles Chargers   LAC      DEF      DEF
# 76       6    4       9757             Kendre Miller    NO       RB     FLEX
# 77       6    5      11619              Ja'Lynn Polk    NE       WR     FLEX
# 78       6    6       7567          Kenneth Gainwell   PHI       RB     FLEX
# 79       6    7       4080                 Zay Jones   ARI       WR       WR
# 80       6    8       4144               Jonnu Smith   MIA       TE     FLEX
# 81       6    9       8131             Isaiah Likely   BAL       TE       TE
# 82       6   10       9492               Trey Palmer    TB       WR     FLEX
# 83       6   11       7596              Elijah Moore   CLE       WR       WR
# 84       7   11       4147             Samaje Perine   DEN       RB       RB
# 85       7   10      11650            Luke McCaffrey   WAS       WR       WR
# 86       7    9      11627             Troy Franklin   DEN       WR       WR
# 87       7    8       4381               Taysom Hill    NO       TE     FLEX
# 88       7    7       4993              Mike Gesicki   CIN       TE       TE
# 89       7    6       6820     Clyde Edwards-Helaire    KC       RB     FLEX
# 90       7    5       8117             Jalen Tolbert   DAL       WR       WR
# 91       7    4       4171             Josh Reynolds   DEN       WR       WR
# 92       7    3      11638            Ricky Pearsall    SF       WR     FLEX
# 93       7    2       8142               Alec Pierce   IND       WR     FLEX
# 94       7    1        DEN            Denver Broncos   DEN      DEF      DEF
# 95       7    0       7561           Elijah Mitchell    SF       RB     FLEX
# 96       8    0       7601             Rondale Moore   ATL       WR     FLEX
# 97       8    1       1348            Dustin Hopkins   CLE        K        K
# 98       8    2      10213                Tre Tucker    LV       WR     FLEX
# 99       8    3       5987        Alexander Mattison    LV       RB     FLEX
# 100      8    4      11584              Bucky Irving    TB       RB     FLEX
# 101      8    5      11617            Malachi Corley   NYJ       WR       WR
# 102      8    6         NE      New England Patriots    NE      DEF      DEF
# 103      8    7       4111            D'Onta Foreman   CLE       RB       RB
# 104      8    8      11596               Ben Sinnott   WAS       TE     FLEX
# 105      8    9       6151             Miles Sanders   CAR       RB       RB
# 106      8   10      10225            Jonathan Mingo   CAR       WR       WR
# 107      8   11       1339                 Zach Ertz   WAS       TE       TE
# 108      9   11       4351               Tim Patrick   DEN       WR     FLEX
# 109      9   10       4149           Jamaal Williams    NO       RB       RB
# 110      9    9       2325            Nelson Agholor   BAL       WR       WR
# 111      9    8       8172              Greg Dulcich   DEN       TE     FLEX
# 112      9    7        ARI         Arizona Cardinals   ARI      DEF      DEF
# 113      9    6       9511           Keaton Mitchell   BAL       RB     FLEX
# 114      9    5       5906               Dawson Knox   BUF       TE       TE
# 115      9    4        WAS     Washington Commanders   WAS      DEF      DEF
# 116      9    3       9484              Tucker Kraft    GB       TE       TE
# 117      9    2       4234                Noah Brown   HOU       WR       WR
# 118      9    1       5095            Daniel Carlson    LV        K        K
# 119      9    0       8225          Daniel Bellinger   NYG       TE       TE
# 120     10    0        LAR          Los Angeles Rams   LAR      DEF      DEF
# 121     10    1       None                      None  None     None     None
# 122     10    2       4973              Hayden Hurst   LAC       TE       TE
# 123     10    3       8135             Treylon Burks   TEN       WR     FLEX
# 124     10    4      10863                A.T. Perry    NO       WR       WR
# 125     10    5         17               Matt Prater   ARI        K        K
# 126     10    6      11618            Jalen McMillan    TB       WR       WR
# 127     10    7       5970               Greg Dortch   ARI       WR       WR
# 128     10    8       9482             Michael Mayer    LV       TE       TE
# 129     10    9      11575                 Ray Davis   BUF       RB       RB
# 130     10   10      11786                Cam Little   JAX        K        K
# 131     10   11       7066               K.J. Osborn    NE       WR       WR
# 132     11   11      11655              Tyrone Tracy   NYG       RB       RB
# 133     11   10      11600         Ja'Tavion Sanders   CAR       TE       TE
# 134     11    9      11789              Joshua Karty   LAR        K        K
# 135     11    8       6598             Trenton Irwin   CIN       WR       WR
# 136     11    7      11579             Audric Estime   DEN       RB       RB
# 137     11    6       4040       JuJu Smith-Schuster    NE       WR       WR
# 138     11    5      11576             Braelon Allen   NYJ       RB       RB
# 139     11    4       3678                  Wil Lutz   DEN        K        K
# 140     11    3       3634             Kalif Raymond   DET       WR     FLEX
# 141     11    2       8125             Calvin Austin   PIT       WR       WR
# 142     11    1       5113            Cedrick Wilson    NO       WR       WR
# 143     11    0       5995              Justice Hill   BAL       RB     FLEX
# 144     12    0       8129             Dameon Pierce   HOU       RB     FLEX
# 145     12    1       None                      None  None     None     None
# 146     12    2      11539                Jake Bates   DET        K        K
# 147     12    3       4098               Kareem Hunt   NaN       RB     FLEX
# 148     12    4       6865           Colby Parkinson   LAR       TE       TE
# 149     12    5       1945             Chris Boswell   PIT        K        K
# 150     12    6      11647              Kimani Vidal   LAC       RB     FLEX
# 151     12    7         19                Joe Flacco   IND       QB       QB
# 152     12    8       7562               Tutu Atwell   LAR       WR       WR
# 153     12    9       8162                Sam Howell   SEA       QB       QB
# 154     12   10      11643             Jaylen Wright   MIA       RB       RB
# 155     12   11        650                 Nick Folk   TEN        K        K
# 156     13   11      11792             Will Reichard   MIN        K        K
# 157     13   10       5189              Eddy Pineiro   CAR        K        K
# 158     13    9       7828                 Noah Gray    KC       TE     FLEX
# 159     13    8       9505              Deuce Vaughn   DAL       RB       RB
# 160     13    7       7496     Nick Westbrook-Ikhine   TEN       WR     FLEX
# 161     13    6       6074             Donald Parham   LAC       TE       TE
# 162     13    5       4892            Baker Mayfield    TB       QB       QB
# 163     13    4       7045             Joshua Kelley   NaN       RB     FLEX
# 164     13    3       5284               Jeff Wilson   MIA       RB     FLEX
# 165     13    2        421          Matthew Stafford   LAR       QB       QB
# 166     13    1       1992            Allen Robinson   NYG       WR     FLEX
# 167     13    0       2359            Ameer Abdullah    LV       RB     FLEX
# 168     14    0      11574               Dylan Laube    LV       RB     FLEX
# 169     14    1       6869             Adam Trautman   DEN       TE       TE
# 170     14    2       1373                Geno Smith   SEA       QB       QB
# 171     14    3      11651            Isaac Guerendo    SF       RB     FLEX
# 172     14    4      11570               Rasheen Ali   BAL       RB     FLEX
# 173     14    5       2028                Derek Carr    NO       QB       QB
# 174     14    6       8408              Jordan Mason    SF       RB     FLEX
# 175     14    7       5086  Marquez Valdes-Scantling   BUF       WR     FLEX
# 176     14    8       5870              Daniel Jones   NYG       QB       QB
# 177     14    9       7568             Brevin Jordan   HOU       TE     FLEX
# 178     14   10       9999                Will Levis   TEN       QB       QB
# 179     14   11       1234            Russell Wilson   PIT       QB       QB
#
#       fp_mean     fp_std
# 0     0.33311  25.849831
# 1    0.335265  14.885174
# 2    0.597119  34.232958
# 3    0.332166  19.742277
# 4    0.306463  30.171801
# 5    0.587099  26.063127
# 6    0.298373  25.826435
# 7    0.332103  14.852612
# 8    0.564614   49.52782
# 9    0.327779  36.361816
# 10   0.437381  46.772538
# 11   0.372855  58.320433
# 12   0.365625  35.218317
# 13   0.363136  32.017314
# 14   0.322528   27.11583
# 15   0.362933  33.850784
# 16    0.32863   25.61218
# 17   0.295633   7.320697
# 18   0.362599  35.942233
# 19   0.288441  15.050666
# 20   0.328405  29.454063
# 21   0.351803  33.257923
# 22   0.314924   8.161835
# 23   0.314883  44.674388
# 24   0.303648  25.744084
# 25   0.277234  72.485507
# 26   0.351075  46.417797
# 27   0.297307  21.898468
# 28   0.285456  26.232865
# 29   0.292968  17.702274
# 30   0.284567  12.850552
# 31   0.290611  34.358059
# 32   0.349296  29.199685
# 33   0.279722  32.055136
# 34   0.347182  27.857169
# 35   0.346173  30.288957
# 36   0.342639  35.195451
# 37   0.285149   23.16617
# 38   0.271685  14.065655
# 39   0.338722  34.934844
# 40    0.28305  27.769969
# 41   0.284008   22.43101
# 42   0.278916  28.584129
# 43   0.262415  30.533539
# 44   0.277558  25.256892
# 45   0.337947   33.56718
# 46   0.216969  67.272707
# 47   0.274268   12.46731
# 48   0.273502  12.771425
# 49   0.247626   16.56252
# 50   0.272805  24.250803
# 51   0.271145   83.40033
# 52   0.232743   9.557951
# 53   0.270301  37.841478
# 54   0.213707  33.368795
# 55   0.264883  21.771656
# 56   0.332814    9.97152
# 57   0.267453  13.807741
# 58   0.266339  12.928474
# 59   0.261427  32.056159
# 60   0.258967   9.745772
# 61   0.255525  16.922221
# 62   0.257504   5.609361
# 63   0.331135  31.181847
# 64   0.231545  32.187136
# 65   0.209462  14.503415
# 66   0.231208  21.516498
# 67   0.206579  29.189347
# 68   0.228656  44.702659
# 69   0.252507  17.373978
# 70   0.239189  11.669964
# 71    0.22809  24.058309
# 72   0.224886  12.964465
# 73   0.326619   9.882227
# 74   0.198787  15.087122
# 75   0.329912   42.26572
# 76    0.19689  28.946155
# 77   0.217149  26.363178
# 78   0.191029  21.834335
# 79   0.212171  25.355221
# 80    0.22966   18.91588
# 81   0.220945  22.517016
# 82   0.206108   1.298846
# 83   0.202831  14.068944
# 84   0.190887  60.181062
# 85     0.2022  11.909776
# 86   0.196478  64.224466
# 87   0.211409  31.965183
# 88   0.190661  13.632972
# 89   0.188578  28.928952
# 90   0.195408  23.154212
# 91   0.193076  18.216886
# 92   0.191479  24.840307
# 93   0.185992  33.656222
# 94   0.326623  31.432187
# 95   0.186906  10.199013
# 96   0.184862  11.624389
# 97   0.325304  13.052428
# 98   0.183031  20.177297
# 99   0.184481   10.25504
# 100  0.183134  13.172826
# 101  0.182393   27.43716
# 102  0.325733  42.069756
# 103  0.180514  30.276311
# 104  0.188371  33.194215
# 105  0.172617  16.621151
# 106   0.18233  29.353962
# 107  0.186934  19.267954
# 108  0.181893  39.335037
# 109  0.169989  12.853667
# 110  0.178028  16.049535
# 111  0.183397  21.979124
# 112  0.309747   23.94441
# 113  0.169413  13.571037
# 114  0.182818   12.42891
# 115  0.299882  16.155037
# 116  0.182594  19.994194
# 117  0.172061   46.16832
# 118  0.316049  10.684731
# 119  0.181009  21.588779
# 120  0.296823  35.143005
# 121         0          0
# 122  0.166208  20.431836
# 123  0.170677  28.412079
# 124  0.168856  42.979248
# 125  0.312361   15.28182
# 126  0.168327  25.387439
# 127  0.165269  21.160755
# 128  0.165613  12.286954
# 129  0.162015   19.35312
# 130  0.311817  14.720734
# 131  0.163747  36.460021
# 132  0.161984  34.349999
# 133  0.160845  36.456288
# 134  0.310685  16.105837
# 135  0.162973  23.503659
# 136  0.160146  13.086104
# 137  0.162005  27.170607
# 138  0.159374  27.392794
# 139  0.308629   5.089597
# 140  0.156613  27.862705
# 141  0.155347   45.07128
# 142  0.150194  20.671624
# 143  0.154805  33.845591
# 144  0.154058  14.602925
# 145         0          0
# 146  0.307618   4.041452
# 147  0.147811  52.325902
# 148  0.155176  22.877799
# 149  0.307031    9.11173
# 150  0.142878  44.029573
# 151  0.101547  40.194194
# 152  0.146986   23.73416
# 153  0.091459   29.37935
# 154  0.141846  34.447449
# 155  0.305501  20.858074
# 156  0.295116  16.903445
# 157   0.28608  17.271306
# 158      None       None
# 159      None       None
# 160      None       None
# 161      None       None
# 162      None       None
# 163      None       None
# 164      None       None
# 165      None       None
# 166      None       None
# 167      None       None
# 168      None       None
# 169      None       None
# 170      None       None
# 171      None       None
# 172      None       None
# 173      None       None
# 174      None       None
# 175      None       None
# 176      None       None
# 177      None       None
# 178      None       None
# 179      None       None

# %%
import torch

policy_net.eval()  # Set the model to evaluation mode

with torch.no_grad():
    predictions = model(input_data)
    
policy_net.train()

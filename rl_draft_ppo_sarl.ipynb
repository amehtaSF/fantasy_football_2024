# %%
import sys
import os

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

import tqdm

import torch
import torch.optim as optim
from torch.autograd import Variable
import torch.nn.functional as F
import torch.nn as nn

from IPython.display import clear_output
from IPython import display

from rl_env import (
    DraftEnv, ACTION_SPACE_DIM,
    STATE_SCHEMA, STARTER_COMPOSITION,
    STATE_SPACE_DIM, NUM_DRAFT_ROUNDS,
    NUM_MGRS
)

# %matplotlib inline

# %% [markdown]
# https://medium.com/@ym1942/policy-gradient-methods-from-reinforce-to-actor-critic-d56ff0f0af0a
#
# https://medium.com/@ym1942/proximal-policy-optimization-tutorial-f722f23beb83

# %% [markdown]
# # Init players

# %%
df_sleeper = pd.read_csv("data/sleeper/all_players.csv")
# df_sleeper = df_sleeper.loc[df_sleeper["rank_int"] < 50]
print(df_sleeper.shape)
df_sleeper.columns
# Out:
# (3670, 56)
# Index(['sleeper_id', 'injury_notes', 'oddsjam_id', 'search_last_name',
#        'college', 'team_abbr', 'birth_state', 'yahoo_id', 'search_first_name',
#        'pandascore_id', 'years_exp', 'fantasy_positions', 'injury_status',
#        'active', 'team', 'competitions', 'high_school', 'number', 'birth_city',
#        'search_full_name', 'last_name', 'birth_country',
#        'practice_description', 'depth_chart_order', 'fantasy_data_id',
#        'status', 'injury_start_date', 'news_updated', 'age', 'search_rank',
#        'practice_participation', 'opta_id', 'full_name', 'swish_id',
#        'birth_date', 'rotowire_id', 'weight', 'height', 'stats_id', 'espn_id',
#        'metadata', 'player_id', 'first_name', 'sport', 'injury_body_part',
#        'position', 'gsis_id', 'sportradar_id', 'hashtag',
#        'depth_chart_position', 'rotoworld_id', 'Player Id', 'positional_rank',
#        'adp', 'adp_date', 'rank_int'],
#       dtype='object')

# %%
df_qb_proj = pd.read_csv("data/projections/QB_projections.csv")
df_rb_proj = pd.read_csv("data/projections/RB_projections.csv")
df_wr_proj = pd.read_csv("data/projections/WR_projections.csv")
df_te_proj = pd.read_csv("data/projections/TE_projections.csv")
df_k_proj = pd.read_csv("data/projections/K_projections.csv")
df_def_proj = pd.read_csv("data/projections/DEF_projections.csv")

df_qb_proj = df_qb_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)
df_rb_proj = df_rb_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)
df_wr_proj = df_wr_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)
df_te_proj = df_te_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)
df_k_proj = df_k_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)
df_def_proj = df_def_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)

df_proj = pd.concat([df_qb_proj, df_rb_proj, df_wr_proj, df_te_proj, df_k_proj, df_def_proj])
df_proj = pd.concat([df_qb_proj, df_rb_proj, df_wr_proj, df_te_proj, df_k_proj, df_def_proj])
df_proj.columns

df_proj_agg = df_proj.groupby('sleeper_id')['fpts'].agg(['mean', 'std']).reset_index()
df_proj_agg['sleeper_id'] = df_proj_agg['sleeper_id'].astype(str)


df_players = df_proj_agg.merge(df_sleeper.loc[:, ['sleeper_id', 'full_name', 'position', 'team']], 
                                on='sleeper_id', 
                                how='left')
print(df_players.shape)
df_players = df_players.dropna(subset=['mean', 'std'])
print(df_players.shape)
# Out:
# (796, 6)
# (647, 6)

# %% [markdown]
# # Constants

# %%
SCORING = {
    'pass_yd': .04,
    'pass_td': 4,
    'pass_2pt': 2,
    'pass_int': -1,
    'rush_yd': .1,
    'rush_td': 6,
    'rush_2pt': 2,
    'rec_rcpt': .5,
    'rec_yd': .1,
    'rec_td': 6,
    'rec_2pt': 2,
    'fg_1_39_made': 3,
    'fg_40_49_made': 4,
    'fg_50_made': 5,
    'xp_missed': -1,
    'xp_made': 1,
    'def_td': 6,
    'def_int': 2,
    'def_sck': 1,
    'def_fum_rec': 2,
    'def_fum_forced': 1,
    'def_sfty': 2,
    'remainder': 1
}

POSITIONS = ['QB', 'RB', 'WR', 'TE', 'K', 'DEF']
STARTER_COMPOSITION = {'QB': 1, 'RB': 2, 'WR': 2, 'FLEX': 2, 'TE': 1, 'K': 1, 'DEF': 1}
TEAM_SIZE = 15

# %% [markdown]
# # Init plotting and compute

# %%
# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display
plt.ion()

# if GPU is to be used
device = torch.device(
    "cuda" if torch.cuda.is_available() else
    "mps" if torch.backends.mps.is_available() else
    "cpu"
)

# %% [markdown]
# # Init network

# %%
class RNN(nn.Module):
    """
    Basic RNN block. This represents a single layer of RNN
    https://solardevs.com/blog/rnn-from-scratch-pytorch/
    """
    def __init__(self, input_size: int, hidden_size: int, output_size: int, batch_size: int) -> None:
        """
        input_size: Number of features of your input vector
        hidden_size: Number of hidden neurons
        output_size: Number of features of your output vector
        """
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.batch_size = batch_size
        self.i2h = nn.Linear(input_size, hidden_size, bias=False)
        self.h2h = nn.Linear(hidden_size, hidden_size)
        self.h2o = nn.Linear(hidden_size, output_size)
    
    def forward(self, x, hidden_state) -> tuple[torch.Tensor, torch.Tensor]:
        """
        Returns computed output and tanh(i2h + h2h)
        Inputs
        ------
        x: Input vector
        hidden_state: Previous hidden state
        Outputs
        -------
        out: Linear output (without activation because of how pytorch works)
        hidden_state: New hidden state matrix
        """
        x = self.i2h(x)
        hidden_state = self.h2h(hidden_state)
        hidden_state = torch.tanh(x + hidden_state)
        out = self.h2o(hidden_state)
        return out, hidden_state
        
    def init_zero_hidden(self, batch_size=1) -> torch.Tensor:
        """
				Helper function.
        Returns a hidden state with specified batch size. Defaults to 1
        """
        return torch.zeros(batch_size, self.hidden_size, requires_grad=False)

# %%
class NeuralNet(torch.nn.Module):
    def __init__(self, input_size, output_size, activation, layers=[32,32,16]):
        super().__init__()

        # Define layers with ReLU activation
        self.linear1 = torch.nn.Linear(input_size, layers[0])
        self.activation1 = torch.nn.ReLU()
        self.linear2 = torch.nn.Linear(layers[0], layers[1])
        self.activation2 = torch.nn.ReLU()
        self.linear3 = torch.nn.Linear(layers[1], layers[2])
        self.activation3 = torch.nn.ReLU()

        self.output_layer = torch.nn.Linear(layers[2], output_size)
        self.output_activation = activation

        # Initialization using Xavier normal (a popular technique for initializing weights in NNs)
        torch.nn.init.xavier_normal_(self.linear1.weight)
        torch.nn.init.xavier_normal_(self.linear2.weight)
        torch.nn.init.xavier_normal_(self.linear3.weight)
        torch.nn.init.xavier_normal_(self.output_layer.weight)

    def forward(self, inputs):
        # Forward pass through the layers
        x = self.activation1(self.linear1(inputs))
        x = self.activation2(self.linear2(x))
        x = self.activation3(self.linear3(x))
        x = self.output_activation(self.output_layer(x))
        return x

# %% [markdown]
# # Generate episode function

# %%
def generate_single_episode(env, policy_net, rl_mgr: int=1):
    """
    Generates an episode by executing the current policy in the given env
    """

    states = []
    actions = []
    rewards = []
    log_probs = []
        
    state, _ = env.reset()
    
    for _, row in env.draft.iterrows():
    
        if row['mgr'] != rl_mgr:
            env.step(env.reasonable_option())
            continue
        
        state = torch.from_numpy(state).float().unsqueeze(0)
        state = state.to(device)
        probs = policy_net.forward(state) # get each action choice probability with the current policy network
        action = np.random.choice(env.action_space.n, p=np.squeeze(probs.detach().cpu().numpy())) # probablistic
        # action = np.argmax(probs.detach().numpy()) # greedy
        
        # compute the log_prob to use this in parameter update
        log_prob = torch.log(probs.squeeze(0)[action])
        
        # append values
        states.append(state)
        actions.append(action)
        log_probs.append(log_prob)
        
        # take a selected action
        state, reward, terminated, _ = env.step(action)
        rewards.append(reward)

        # Never terminate early because we always have full draft
        # if terminated | truncated:
        #     break
    
            
    return states, actions, rewards, log_probs

# %% [markdown]
# # Evaluate policy function

# %%
def evaluate_policy(env, policy_net):
    """
    Compute accumulative trajectory reward
    """
    states, actions, rewards, log_probs = generate_single_episode(env, policy_net)
    return np.sum(rewards)

# %% [markdown]
# # Train function

# %%
def train_PPO(env, episode, policy_net, policy_optimizer, value_net, value_optimizer, num_epochs, clip_val=0.2, gamma=0.99):
    """
    Trains the policy network using PPO
    """

    # Generate an episode with the current policy network
    # states, actions, rewards, log_probs = generate_single_episode(env, policy_net)
    # episode = generate_single_episode(env, policy_net) 
    
    states, actions, rewards, log_probs = episode
    
    T = len(states)
        
    # Create tensors
    # states = np.vstack(states).astype(float)
    # states = np.vstack([s.cpu().numpy() for s in states]).astype(float)
    # states = torch.FloatTensor(states).to(device)
    # states = torch.vstack([s.float() for s in states]).to(device)
    states = torch.vstack(states).to(device)
    actions = torch.LongTensor(actions).to(device).view(-1,1)
    rewards = torch.FloatTensor(rewards).to(device).view(-1,1)
    log_probs = torch.FloatTensor(log_probs).to(device).view(-1,1)

    # Compute total discounted return at each time step
    Gs = []
    G = 0
    for t in range(T-1,-1,-1): # iterate in backward order to make the computation easier
        G = rewards[t] + gamma*G
        Gs.insert(0,G)
    Gs = torch.tensor(Gs).view(-1,1)
    Gs = Gs.to(device)
    
    # Compute the advantage
    state_vals = value_net(states).to(device)
    with torch.no_grad():
        A_k = Gs - state_vals
        
    for _ in range(num_epochs):
        V = value_net(states).to(device)
        
        # Calculate probability of each action under the updated policy
        probs = policy_net.forward(states).to(device)
                
        # compute the log_prob to use it in parameter update
        curr_log_probs = torch.log(torch.gather(probs, 1, actions)) # Use torch.gather(A,1,B) to select columns from A based on indices in B
        
        # Calculate ratios r(theta)
        ratios = torch.exp(curr_log_probs - log_probs)
        
        # Calculate two surrogate loss terms in cliped loss
        surr1 = ratios * A_k
        surr2 = torch.clamp(ratios, 1-clip_val, 1+clip_val) * A_k
        
        # Calculate clipped loss value
        actor_loss = (-torch.min(surr1, surr2)).mean() # Need negative sign to run Gradient Ascent
        
        # Update policy network
        policy_optimizer.zero_grad()
        actor_loss.backward(retain_graph=True)
        policy_optimizer.step()
        
        # Update value net
        critic_loss = nn.MSELoss()(V, Gs)
        value_optimizer.zero_grad()
        critic_loss.backward()
        value_optimizer.step()
        
    return policy_net, value_net

# %% [markdown]
# # Run training

# %%
# Define parameter values
env_name = 'DraftEnv'
num_train_ite = 50000
num_seeds = 5 # fit model with 5 different seeds and plot average performance of 5 seeds
num_epochs = 30 # how many times we iterate the entire training dataset passing through the training
eval_freq = 50 # run evaluation of policy at each eval_freq trials
eval_epi_index = num_train_ite//eval_freq # use to create x label for plot
returns = np.zeros((num_seeds, eval_epi_index))
gamma = 0.99 # discount factor
clip_val = 0.2 # hyperparameter epsilon in clip objective

# Create the environment.
env = DraftEnv(df_players)
nA = env.action_space.n
nS = env.observation_space.shape[0]

policy_lr = 5e-4 # policy network's learning rate 
baseline_lr = 1e-4 # value network's learning rate
 
for i in tqdm.tqdm(range(num_seeds)):
    reward_means = []

    # Define policy and value networks
    # policy_net_dict = {i: NeuralNet(nS, nA, torch.nn.Softmax(dim=1)).to(device) for i in range(NUM_MGRS)}
    # policy_optimizer_dict = {i: optim.Adam(policy_net_dict[i].parameters(), lr=policy_lr) for i in range(NUM_MGRS)}
    # value_net_dict = {i: NeuralNet(nS, 1, torch.nn.ReLU()).to(device) for i in range(NUM_MGRS)}
    # value_optimizer_dict = {i: optim.Adam(value_net_dict[i].parameters(), lr=baseline_lr) for i in range(NUM_MGRS)}
    
    # policy_net = NeuralNet(nS, nA, torch.nn.Softmax(dim=1)).to(device)
    # policy_optimizer = optim.Adam(policy_net.parameters(), lr=policy_lr)
    # value_net = NeuralNet(nS, 1, torch.nn.ReLU()).to(device)
    # value_optimizer = optim.Adam(value_net.parameters(), lr=baseline_lr)
    
    policy_net = NeuralNet(nS, nA, torch.nn.Softmax(dim=1)).to(device)
    policy_optimizer = optim.Adam(policy_net.parameters(), lr=policy_lr)
    value_net = NeuralNet(nS, 1, torch.nn.ReLU()).to(device)
    value_optimizer = optim.Adam(value_net.parameters(), lr=baseline_lr)
    
    
    
    for m in range(num_train_ite):
        # Train networks with PPO
        episode = generate_single_episode(env, policy_net) 

        policy_net, value_net = train_PPO(env, episode, policy_net, policy_optimizer, value_net, value_optimizer, num_epochs, clip_val=clip_val, gamma=gamma)
            
            
        # policy_net, value_net = train_PPO(env, episode, policy_net, policy_net_optimizer, value_net, value_net_optimizer, num_epochs, clip_val=clip_val, gamma=gamma)
        if m % eval_freq == 0:
            print("Episode: {}".format(m))
            G = np.zeros(20)
            for k in range(20): # run 20 evaluations
                g = evaluate_policy(env, policy_net) # dict of rewards instead of scalar reward
                g = np.array(g)
                g = np.mean(g)
                G[k] = g 

            reward_mean = G.mean()
            reward_sd = G.std()
            print("The avg. test reward for episode {0} is {1} with std of {2}.".format(m, reward_mean, reward_sd))
            reward_means.append(reward_mean)
    returns[i] = np.array(reward_means)

# Plot the performance over iterations
x = np.arange(eval_epi_index)*eval_freq
avg_returns = np.mean(returns, axis=0)
max_returns = np.max(returns, axis=0)
min_returns = np.min(returns, axis=0)

plt.fill_between(x, min_returns, max_returns, alpha=0.1)
plt.plot(x, avg_returns, '-o', markersize=1)

plt.xlabel('Episode', fontsize = 15)
plt.ylabel('Return', fontsize = 15)

plt.title("PPO Learning Curve", fontsize = 24)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Episode: 0
# The avg. test reward for episode 0 is -0.596167754861776 with std of 0.4430571207041121.
# Episode: 50
# The avg. test reward for episode 50 is -0.7925413004195118 with std of 0.040880256397991706.
# Episode: 100
# The avg. test reward for episode 100 is -0.46210725866398816 with std of 0.7168886013785585.
# Episode: 150
# The avg. test reward for episode 150 is -0.806185917790636 with std of 0.04299164254360711.
# Episode: 200
# The avg. test reward for episode 200 is -0.5358177015252259 with std of 0.6229484865424101.
# Episode: 250
# The avg. test reward for episode 250 is -0.4359980086924762 with std of 0.7316084469010925.
# Episode: 300
# The avg. test reward for episode 300 is -0.7629762060067348 with std of 0.04007349015204623.
# Episode: 350
# The avg. test reward for episode 350 is -0.7626415035777104 with std of 0.02815498570115171.
# Episode: 400
# The avg. test reward for episode 400 is -0.5720819986668948 with std of 0.5471928037123865.
# Episode: 450
# The avg. test reward for episode 450 is -0.29906422391711907 with std of 0.7499158149128403.
# Episode: 500
# The avg. test reward for episode 500 is -0.40730208344830493 with std of 0.834837578340042.
# Episode: 550
# The avg. test reward for episode 550 is -0.3095231025642894 with std of 0.9247012413916942.
# Episode: 600
# The avg. test reward for episode 600 is -0.06049294060568455 with std of 1.2057057391750154.
# Episode: 650
# The avg. test reward for episode 650 is -0.47809968836037936 with std of 0.8651440354423198.
# Episode: 700
# The avg. test reward for episode 700 is -0.1255076656569701 with std of 0.9911912767293585.
# Episode: 750
# The avg. test reward for episode 750 is -0.04190658453574192 with std of 1.0715682299210256.
# Episode: 800
# The avg. test reward for episode 800 is 0.21219211294062484 with std of 1.2221630684680163.
# Episode: 850
# The avg. test reward for episode 850 is 0.07600660683627393 with std of 1.2728382730224952.
# Episode: 900
# The avg. test reward for episode 900 is -0.13542748958076797 with std of 0.9531638990561152.
# Episode: 950
# The avg. test reward for episode 950 is -0.706830888612 with std of 0.3356615529523781.
# Episode: 1000
# The avg. test reward for episode 1000 is -0.2242383225040147 with std of 1.0002068381249831.
# Episode: 1050
# The avg. test reward for episode 1050 is -0.28214192102587543 with std of 0.9018563717511882.
# Episode: 1100
# The avg. test reward for episode 1100 is -0.06289417604195494 with std of 0.9410828274705039.
# Episode: 1150
# The avg. test reward for episode 1150 is -0.5857104047548017 with std of 0.622688068897405.
# Episode: 1200
# The avg. test reward for episode 1200 is -0.602826029183189 with std of 0.4383354398050218.
# Episode: 1250
# The avg. test reward for episode 1250 is -0.7017871243669618 with std of 0.04319744325979319.
# Episode: 1300
# The avg. test reward for episode 1300 is -0.4975875937829774 with std of 0.6158667162219189.
# Episode: 1350
# The avg. test reward for episode 1350 is -0.1777028897841769 with std of 0.9896407105238999.
# Episode: 1400
# The avg. test reward for episode 1400 is -0.03835661903115084 with std of 1.1710559404453094.
# Episode: 1450
# The avg. test reward for episode 1450 is -0.22004859615868644 with std of 0.8443613642636754.
# Episode: 1500
# The avg. test reward for episode 1500 is -0.5386562547420752 with std of 0.6570512622213275.
# Episode: 1550
# The avg. test reward for episode 1550 is 0.12356790847493322 with std of 1.1273379814288103.
# Episode: 1600
# The avg. test reward for episode 1600 is -0.7284147042604953 with std of 0.03508861639327822.
# Episode: 1650
# The avg. test reward for episode 1650 is -0.25155995598572867 with std of 0.8575959132185257.
# Episode: 1700
# The avg. test reward for episode 1700 is -0.08010228501267787 with std of 1.0690555785435503.
# Episode: 1750
# The avg. test reward for episode 1750 is -0.5273116591302761 with std of 0.7411806806875821.
# Episode: 1800
# The avg. test reward for episode 1800 is -0.4415436588818692 with std of 0.8341279132874969.
# Episode: 1850
# The avg. test reward for episode 1850 is -0.6470855135822361 with std of 0.6188050414693496.
# Episode: 1900
# The avg. test reward for episode 1900 is -0.14359060046720587 with std of 0.9182988383009671.
# Episode: 1950
# The avg. test reward for episode 1950 is -0.07710105675152637 with std of 1.0158962651724044.
# Episode: 2000
# The avg. test reward for episode 2000 is -0.24270291662036128 with std of 0.8753450502722893.
# Episode: 2050
# The avg. test reward for episode 2050 is -0.6013098675258418 with std of 0.7301608136088595.
# Episode: 2100
# The avg. test reward for episode 2100 is -0.772148407719927 with std of 0.04803905561662941.
# Episode: 2150
# The avg. test reward for episode 2150 is -0.33215506925078314 with std of 0.8018270641357784.
# Episode: 2200
# The avg. test reward for episode 2200 is -0.03772099961649638 with std of 1.0860889125916418.
# Episode: 2250
# The avg. test reward for episode 2250 is -0.17564960050209916 with std of 1.204474913756082.
# Episode: 2300
# The avg. test reward for episode 2300 is -0.5613022442186292 with std of 0.6101278668398109.
# Episode: 2350
# The avg. test reward for episode 2350 is -0.40013919274173065 with std of 0.7046347584357212.
# Episode: 2400
# The avg. test reward for episode 2400 is -0.38125417923157345 with std of 0.9179755453789018.
# Episode: 2450
# The avg. test reward for episode 2450 is -0.5101300553385885 with std of 0.7225802190690677.
# Episode: 2500
# The avg. test reward for episode 2500 is -0.06265447603454403 with std of 1.0672859339817147.
# Episode: 2550
# The avg. test reward for episode 2550 is -0.5875283609674683 with std of 0.4398292488066674.
# Episode: 2600
# The avg. test reward for episode 2600 is -0.36475570248337863 with std of 0.7605688571510577.
# Episode: 2650
# The avg. test reward for episode 2650 is -0.7788020525014652 with std of 0.052282747028728566.
# Episode: 2700
# The avg. test reward for episode 2700 is 0.3155287150363252 with std of 1.2553925341334151.
# Episode: 2750
# The avg. test reward for episode 2750 is 0.23516847584816775 with std of 1.2558585339432198.
# Episode: 2800
# The avg. test reward for episode 2800 is -0.7827372903307566 with std of 0.04790767071207213.
# Episode: 2850
# The avg. test reward for episode 2850 is -0.6608406210409233 with std of 0.4543242163725989.
# Episode: 2900
# The avg. test reward for episode 2900 is -0.5924939698829448 with std of 0.5596230323799529.
# Episode: 2950
# The avg. test reward for episode 2950 is -0.07110478716120358 with std of 1.081940939968007.
# Episode: 3000
# The avg. test reward for episode 3000 is -0.49481952382659855 with std of 0.728366557051675.
# Episode: 3050
# The avg. test reward for episode 3050 is -0.30283411118506265 with std of 0.9000172753693377.
# Episode: 3100
# The avg. test reward for episode 3100 is -0.3831872522882628 with std of 0.8821751295951638.
# Episode: 3150
# The avg. test reward for episode 3150 is -0.11843050545112681 with std of 0.964201556613532.
# Episode: 3200
# The avg. test reward for episode 3200 is 0.048931149913895064 with std of 1.0671910369424396.
# Episode: 3250
# The avg. test reward for episode 3250 is -0.5513526565772808 with std of 0.5889750342329566.
# Episode: 3300
# The avg. test reward for episode 3300 is 0.05500851469161326 with std of 1.1046799537219303.
# Episode: 3350
# The avg. test reward for episode 3350 is -0.08564068988691491 with std of 1.0544251737780195.
# Episode: 3400
# The avg. test reward for episode 3400 is -0.30456485294761204 with std of 0.9329732608200392.
# Episode: 3450
# The avg. test reward for episode 3450 is -0.3370669153298644 with std of 0.8534871665921304.
# Episode: 3500
# The avg. test reward for episode 3500 is -0.5569385585064911 with std of 0.7390055026247399.
# Episode: 3550
# The avg. test reward for episode 3550 is -0.5537243634443482 with std of 0.514390755003001.
# Episode: 3600
# The avg. test reward for episode 3600 is -0.40581998612081466 with std of 0.7903097657981567.
# Episode: 3650
# The avg. test reward for episode 3650 is -0.3645659885263508 with std of 0.9436733502319857.
# Episode: 3700
# The avg. test reward for episode 3700 is -0.39578063802561175 with std of 0.8480498618972475.
# Episode: 3750
# The avg. test reward for episode 3750 is -0.05462650458021591 with std of 1.0962638680476535.
# Episode: 3800
# The avg. test reward for episode 3800 is -0.03435145553322696 with std of 1.149650195726297.
# Episode: 3850
# The avg. test reward for episode 3850 is 0.07666798971853606 with std of 1.2204898800716333.
# Episode: 3900
# The avg. test reward for episode 3900 is -0.05531343384042753 with std of 1.2413042523963569.
# Episode: 3950
# The avg. test reward for episode 3950 is -0.24457176352437432 with std of 0.8642424138589584.
# Episode: 4000
# The avg. test reward for episode 4000 is -0.24948601797455075 with std of 0.8727870894145412.
# Episode: 4050
# The avg. test reward for episode 4050 is -0.4199916518397447 with std of 0.7565857697891268.
# Episode: 4100
# The avg. test reward for episode 4100 is 0.05644318844701708 with std of 1.088176154764532.
# Episode: 4150
# The avg. test reward for episode 4150 is -0.27741343031711674 with std of 0.92941397492898.
# Episode: 4200
# The avg. test reward for episode 4200 is -0.15017697033004107 with std of 1.065142597873889.
# Episode: 4250
# The avg. test reward for episode 4250 is -0.2896750555252156 with std of 0.8978220219346957.
# Episode: 4300
# The avg. test reward for episode 4300 is 0.21987395965095366 with std of 1.2024349180260157.
# Episode: 4350
# The avg. test reward for episode 4350 is -0.15833368206347062 with std of 1.0171425744908413.
# Episode: 4400
# The avg. test reward for episode 4400 is -0.12381893996416679 with std of 0.9240313801579016.
# Episode: 4450
# The avg. test reward for episode 4450 is -0.45727994552374385 with std of 0.6642344264389948.
# Episode: 4500
# The avg. test reward for episode 4500 is 0.0035432998913392023 with std of 1.1255026238301389.
# Episode: 4550
# The avg. test reward for episode 4550 is -0.07171423587343759 with std of 1.0444521803210478.
# Episode: 4600
# The avg. test reward for episode 4600 is -0.14489556392622185 with std of 1.0704618539070547.
# Episode: 4650
# The avg. test reward for episode 4650 is 0.03625613544889453 with std of 1.1057297081459048.
# Episode: 4700
# The avg. test reward for episode 4700 is -0.07680558997277002 with std of 1.180359632522067.
# Episode: 4750
# The avg. test reward for episode 4750 is -0.024109611186101398 with std of 1.137496917811541.
# Episode: 4800
# The avg. test reward for episode 4800 is -0.16354136950445802 with std of 1.0286565743838694.
# Episode: 4850
# The avg. test reward for episode 4850 is -0.1423724082068273 with std of 1.0427601387868308.
# Episode: 4900
# The avg. test reward for episode 4900 is -0.1583702141705527 with std of 1.0618847500732234.
# Episode: 4950
# The avg. test reward for episode 4950 is -0.05309550234195513 with std of 1.0630023285896206.
# Episode: 5000
# The avg. test reward for episode 5000 is -0.5354338973535528 with std of 0.6262030589107894.
# Episode: 5050
# The avg. test reward for episode 5050 is -0.09421618989064279 with std of 0.9890675558661163.
# Episode: 5100
# The avg. test reward for episode 5100 is -0.7336553341788612 with std of 0.035134105493213705.
# Episode: 5150
# The avg. test reward for episode 5150 is -0.2123773787377458 with std of 0.9552951376344891.
# Episode: 5200
# The avg. test reward for episode 5200 is -0.12338996613407338 with std of 0.9354343068135093.
# Episode: 5250
# The avg. test reward for episode 5250 is -0.32409697965627043 with std of 0.7909634218102581.
# Episode: 5300
# The avg. test reward for episode 5300 is -0.6533365812425157 with std of 0.4308271293349378.
# Episode: 5350
# The avg. test reward for episode 5350 is -0.35221710130204026 with std of 0.922466314773727.
# Episode: 5400
# The avg. test reward for episode 5400 is -0.04153273610743123 with std of 1.034208962168592.
# Episode: 5450
# The avg. test reward for episode 5450 is 0.04260758783609194 with std of 1.1434065605947323.
# Episode: 5500
# The avg. test reward for episode 5500 is -0.10309465420941603 with std of 1.0224665221244864.
# Episode: 5550
# The avg. test reward for episode 5550 is 0.0814823039678948 with std of 1.1705196017595285.
# Episode: 5600
# The avg. test reward for episode 5600 is -0.1496319149670607 with std of 1.0400052505788169.
# Episode: 5650
# The avg. test reward for episode 5650 is -0.20227480963183816 with std of 1.0098460851519944.
# Episode: 5700
# The avg. test reward for episode 5700 is -0.028941975391122043 with std of 1.1184884945798004.
# Episode: 5750
# The avg. test reward for episode 5750 is -0.37179625352249646 with std of 0.8254717937068496.
# Episode: 5800
# The avg. test reward for episode 5800 is -0.06275327956453347 with std of 1.0732291843289137.
# Episode: 5850
# The avg. test reward for episode 5850 is -0.023735700112898904 with std of 1.1121908527603956.
# Episode: 5900
# The avg. test reward for episode 5900 is -0.10196415871719519 with std of 1.1327229248059023.
# Episode: 5950
# The avg. test reward for episode 5950 is -0.41024354241632954 with std of 0.8530725641133723.
# Episode: 6000
# The avg. test reward for episode 6000 is -0.4227717955175187 with std of 0.8128085778155505.
# Episode: 6050
# The avg. test reward for episode 6050 is -0.535812119639571 with std of 0.6043282577616953.
# Episode: 6100
# The avg. test reward for episode 6100 is -0.5542158476654426 with std of 0.5105216279699654.
# Episode: 6150
# The avg. test reward for episode 6150 is -0.27402684226384266 with std of 0.9427428815075775.
# Episode: 6200
# The avg. test reward for episode 6200 is -0.3629103483853917 with std of 0.7067154050498949.
# Episode: 6250
# The avg. test reward for episode 6250 is 0.03784095839291111 with std of 0.9568486419591441.
# Episode: 6300
# The avg. test reward for episode 6300 is -0.32304146704882764 with std of 0.984221326233513.
# Episode: 6350
# The avg. test reward for episode 6350 is 0.21221235057795523 with std of 1.329664609100659.
# Episode: 6400
# The avg. test reward for episode 6400 is -0.428704665941686 with std of 0.8964653387943794.
# Episode: 6450
# The avg. test reward for episode 6450 is 0.19106354188341504 with std of 1.1064491707880562.
# Episode: 6500
# The avg. test reward for episode 6500 is 0.03138398616444703 with std of 0.9564898060853022.
# Episode: 6550
# The avg. test reward for episode 6550 is -0.041096515539258596 with std of 1.1428009367894472.
# Episode: 6600
# The avg. test reward for episode 6600 is -0.06970218747832282 with std of 1.1615363382216393.
# Episode: 6650
# The avg. test reward for episode 6650 is -0.35994257217211817 with std of 0.7859547198732796.
# Episode: 6700
# The avg. test reward for episode 6700 is -0.20923743607974804 with std of 1.0670015787719669.
# Episode: 6750
# The avg. test reward for episode 6750 is -0.5754978935671964 with std of 0.6887226119655775.
# Episode: 6800
# The avg. test reward for episode 6800 is -0.36809327025830363 with std of 0.6932391459486662.
# Episode: 6850
# The avg. test reward for episode 6850 is -0.1498807473509285 with std of 1.0829666434620373.
# Episode: 6900
# The avg. test reward for episode 6900 is -0.531291062106483 with std of 0.6074403873977491.
# Episode: 6950
# The avg. test reward for episode 6950 is 0.25837368641353375 with std of 1.1719341417408233.
# Episode: 7000
# The avg. test reward for episode 7000 is -0.22133177317452252 with std of 1.013025378314558.
# Episode: 7050
# The avg. test reward for episode 7050 is 0.08504409987808086 with std of 1.3014988417993347.
# Episode: 7100
# The avg. test reward for episode 7100 is 0.06264208289965531 with std of 1.080281277867377.
# Episode: 7150
# The avg. test reward for episode 7150 is -0.38811848907458124 with std of 0.7368459952913982.
# Episode: 7200
# The avg. test reward for episode 7200 is -0.040762252095306165 with std of 1.0985944901772666.
# Episode: 7250
# The avg. test reward for episode 7250 is -0.22733706792367198 with std of 0.9042086542898713.
# Episode: 7300
# The avg. test reward for episode 7300 is -0.37229962531313754 with std of 0.7340739396095229.
# Episode: 7350
# The avg. test reward for episode 7350 is -0.5084931500240436 with std of 0.6607100064301229.
# Episode: 7400
# The avg. test reward for episode 7400 is -0.5044417271908725 with std of 0.5463991411386937.
# Episode: 7450
# The avg. test reward for episode 7450 is -0.2633233567328861 with std of 0.9699745009976177.
# Episode: 7500
# The avg. test reward for episode 7500 is -0.16084646618261714 with std of 0.9026685480836512.
# Episode: 7550
# The avg. test reward for episode 7550 is -0.22275319340395697 with std of 0.9208554166924007.
# Episode: 7600
# The avg. test reward for episode 7600 is 0.15849129225109432 with std of 1.224919426317232.
# Episode: 7650
# The avg. test reward for episode 7650 is 0.15830045764939876 with std of 1.1631388744818763.
# Episode: 7700
# The avg. test reward for episode 7700 is -0.11340695202690787 with std of 1.07788914803904.
# Episode: 7750
# The avg. test reward for episode 7750 is 0.0038909424368051503 with std of 0.960291447006807.
# Episode: 7800
# The avg. test reward for episode 7800 is -0.11315551330762492 with std of 1.1231158870970575.
# Episode: 7850
# The avg. test reward for episode 7850 is -0.3526720916679613 with std of 0.7620689924410332.
# Episode: 7900
# The avg. test reward for episode 7900 is -0.2117052975763971 with std of 1.0646291845000613.
# Episode: 7950
# The avg. test reward for episode 7950 is -0.2168540498056101 with std of 0.8974725378341615.
# Episode: 8000
# The avg. test reward for episode 8000 is -0.018972651143744024 with std of 1.1217405935621962.
# Episode: 8050
# The avg. test reward for episode 8050 is -0.3330298234651902 with std of 0.7833801478527176.
# Episode: 8100
# The avg. test reward for episode 8100 is -0.023380307477951508 with std of 0.9947883397874188.
# Episode: 8150
# The avg. test reward for episode 8150 is -0.2461988227217183 with std of 0.9960110413892473.
# Episode: 8200
# The avg. test reward for episode 8200 is -0.06064731772187304 with std of 0.9503463574026909.
# Episode: 8250
# The avg. test reward for episode 8250 is -0.5006630986590629 with std of 0.7204838896599087.
# Episode: 8300
# The avg. test reward for episode 8300 is -0.37575959586100977 with std of 0.8851621294048423.
# Episode: 8350
# The avg. test reward for episode 8350 is -0.22505664376018125 with std of 0.9141300863647082.
# Episode: 8400
# The avg. test reward for episode 8400 is 0.21668374189486853 with std of 1.106023240272232.
# Episode: 8450
# The avg. test reward for episode 8450 is 0.22455819261553592 with std of 1.3164790606806644.
# Episode: 8500
# The avg. test reward for episode 8500 is -0.48520946415173877 with std of 0.5728988505215772.
# Episode: 8550
# The avg. test reward for episode 8550 is -0.4358367215662976 with std of 0.7438256403141051.
# Episode: 8600
# The avg. test reward for episode 8600 is -0.2960874119943428 with std of 0.9523541322103934.
# Episode: 8650
# The avg. test reward for episode 8650 is -0.10332027202427248 with std of 1.17456567656667.
# Episode: 8700
# The avg. test reward for episode 8700 is -0.014025774600595542 with std of 1.192794815905766.
# Episode: 8750
# The avg. test reward for episode 8750 is -0.45490610196174386 with std of 0.6595040148767696.
# Episode: 8800
# The avg. test reward for episode 8800 is -0.04766628412128711 with std of 1.1197346580405572.
# Episode: 8850
# The avg. test reward for episode 8850 is -0.22607597426081413 with std of 1.055519865420198.
# Episode: 8900
# The avg. test reward for episode 8900 is -0.3093425600157749 with std of 0.944898432970309.
# Episode: 8950
# The avg. test reward for episode 8950 is -0.1721007833843174 with std of 1.0008560979288834.
# Episode: 9000
# The avg. test reward for episode 9000 is -0.502302694816337 with std of 0.7135459957910115.
# Episode: 9050
# The avg. test reward for episode 9050 is -0.39958031168435604 with std of 0.8225501102468681.
# Episode: 9100
# The avg. test reward for episode 9100 is -0.2807704495360917 with std of 0.8097804227866967.
# Episode: 9150
# The avg. test reward for episode 9150 is -0.2185504680938221 with std of 0.9315925661436587.
# Episode: 9200
# The avg. test reward for episode 9200 is -0.6102820698605724 with std of 0.5298643543206248.
# Episode: 9250
# The avg. test reward for episode 9250 is -0.15690165010077944 with std of 1.0553031995008062.
# Episode: 9300
# The avg. test reward for episode 9300 is -0.2145310493092519 with std of 1.126722693882694.
# Episode: 9350
# The avg. test reward for episode 9350 is -0.19880968470733512 with std of 1.023874693276537.
# Episode: 9400
# The avg. test reward for episode 9400 is -0.09787644069495999 with std of 1.035869259236572.
# Episode: 9450
# The avg. test reward for episode 9450 is -0.21004398220054338 with std of 0.9240662902026061.
# Episode: 9500
# The avg. test reward for episode 9500 is -0.1729936453985602 with std of 1.0157613809346069.
# Episode: 9550
# The avg. test reward for episode 9550 is -0.46202317917192703 with std of 0.8000941073678647.
# Episode: 9600
# The avg. test reward for episode 9600 is 0.08516742389395607 with std of 1.2056117330031484.
# Episode: 9650
# The avg. test reward for episode 9650 is -0.03636926821204685 with std of 1.113546933910156.
# Episode: 9700
# The avg. test reward for episode 9700 is 0.015716311226439694 with std of 1.125780188915312.
# Episode: 9750
# The avg. test reward for episode 9750 is 0.32943296451460885 with std of 1.2747746108841949.
# Episode: 9800
# The avg. test reward for episode 9800 is 0.06549029165889479 with std of 1.0968976001166482.
# Episode: 9850
# The avg. test reward for episode 9850 is 0.004091080321494689 with std of 1.0564231944151186.
# Episode: 9900
# The avg. test reward for episode 9900 is 0.0109844468093506 with std of 1.1783548650986313.
# Episode: 9950
# The avg. test reward for episode 9950 is -0.36342228293772466 with std of 0.7543179100358203.
# Episode: 10000
# The avg. test reward for episode 10000 is 0.3418281416773145 with std of 1.1154810820546133.
# Episode: 10050
# The avg. test reward for episode 10050 is -0.26098822395508137 with std of 0.9630538915863956.
# Episode: 10100
# The avg. test reward for episode 10100 is -0.11426941237759314 with std of 0.988309406096876.
# Episode: 10150
# The avg. test reward for episode 10150 is -0.6449449372847419 with std of 0.4078437480614949.
# Episode: 10200
# The avg. test reward for episode 10200 is 0.05222487580298927 with std of 1.0310798957030811.
# Episode: 10250
# The avg. test reward for episode 10250 is 0.37084223429378244 with std of 1.2803624080338618.
# Episode: 10300
# The avg. test reward for episode 10300 is 0.0191105502561555 with std of 1.0632900460250305.
# Episode: 10350
# The avg. test reward for episode 10350 is -0.17035824628748003 with std of 0.9545209347072557.
# Episode: 10400
# The avg. test reward for episode 10400 is -0.25974070087666773 with std of 0.8451568563529229.
# Episode: 10450
# The avg. test reward for episode 10450 is -0.28315041475110986 with std of 1.0671762131365372.
# Episode: 10500
# The avg. test reward for episode 10500 is -0.009266573339352968 with std of 1.0601732277308187.
# Episode: 10550
# The avg. test reward for episode 10550 is -0.22304115847302625 with std of 0.8789089531548937.
# Episode: 10600
# The avg. test reward for episode 10600 is -0.3184600522833944 with std of 0.8291482070806789.
# Episode: 10650
# The avg. test reward for episode 10650 is -0.08544272366996553 with std of 1.0505228561637798.
# Episode: 10700
# The avg. test reward for episode 10700 is -0.31598996747560837 with std of 1.0167781045785231.
# Episode: 10750
# The avg. test reward for episode 10750 is -0.08174676865366862 with std of 0.8207305890083366.
# Episode: 10800
# The avg. test reward for episode 10800 is -0.03608300194125831 with std of 0.9855495431402778.
# Episode: 10850
# The avg. test reward for episode 10850 is -0.282308277007339 with std of 0.9223821736275554.
# Episode: 10900
# The avg. test reward for episode 10900 is -0.15188684728305563 with std of 1.0572398169988892.
# Episode: 10950
# The avg. test reward for episode 10950 is 0.16691217104518263 with std of 1.290027574041819.
# Episode: 11000
# The avg. test reward for episode 11000 is 0.0661305198429388 with std of 1.120400909611754.
# Episode: 11050
# The avg. test reward for episode 11050 is -0.21400276153581643 with std of 0.9923145423685509.
# Episode: 11100
# The avg. test reward for episode 11100 is -0.382229406165902 with std of 0.8778968903357389.
# Episode: 11150
# The avg. test reward for episode 11150 is -0.20321139423767343 with std of 0.8218018234327982.
# Episode: 11200
# The avg. test reward for episode 11200 is -0.08602057898559685 with std of 1.0191926864172127.
# Episode: 11250
# The avg. test reward for episode 11250 is 0.08101110623920316 with std of 1.0538481847822387.
# Episode: 11300
# The avg. test reward for episode 11300 is -0.06684656382234991 with std of 1.0721750488401312.
# Episode: 11350
# The avg. test reward for episode 11350 is -0.36604077804361024 with std of 0.7821061739841403.
# Episode: 11400
# The avg. test reward for episode 11400 is -0.05419461320764359 with std of 1.1917187892083774.
# Episode: 11450
# The avg. test reward for episode 11450 is -0.04352209869228077 with std of 1.136658430661782.
# Episode: 11500
# The avg. test reward for episode 11500 is 0.39996923031243437 with std of 1.3084063548940528.
# Episode: 11550
# The avg. test reward for episode 11550 is -0.06530622944207501 with std of 1.0606279506668155.
# Episode: 11600
# The avg. test reward for episode 11600 is 0.17448326741521955 with std of 1.3082169807751167.
# Episode: 11650
# The avg. test reward for episode 11650 is -0.37449666187603053 with std of 0.8561718521150491.
# Episode: 11700
# The avg. test reward for episode 11700 is -0.06175882789724152 with std of 1.2209451689034496.
# Episode: 11750
# The avg. test reward for episode 11750 is -0.328236382405941 with std of 0.8102334784451373.
# Episode: 11800
# The avg. test reward for episode 11800 is -0.04932319177848606 with std of 1.0671439485798297.
# Episode: 11850
# The avg. test reward for episode 11850 is -0.2541397525275992 with std of 1.0154265099710045.
# Episode: 11900
# The avg. test reward for episode 11900 is -0.17088239558866133 with std of 1.0307568037047128.
# Episode: 11950
# The avg. test reward for episode 11950 is -0.19408227189292632 with std of 0.8539813809320498.
# Episode: 12000
# The avg. test reward for episode 12000 is -0.4148250978304729 with std of 0.8324656801322331.
# Episode: 12050
# The avg. test reward for episode 12050 is -0.10746849048030835 with std of 1.0296376815938322.
# Episode: 12100
# The avg. test reward for episode 12100 is -0.02574480001730356 with std of 1.1576135243247772.
# Episode: 12150
# The avg. test reward for episode 12150 is -0.2065648099519652 with std of 0.8253833003102319.
# Episode: 12200
# The avg. test reward for episode 12200 is -0.48290910705208934 with std of 0.6059813392118779.
# Episode: 12250
# The avg. test reward for episode 12250 is -0.22986287022604435 with std of 1.0372709754823182.
# Episode: 12300
# The avg. test reward for episode 12300 is 0.033912222495807685 with std of 1.064317452989506.
# Episode: 12350
# The avg. test reward for episode 12350 is 0.05994299489385526 with std of 1.1286586338174798.
# Episode: 12400
# The avg. test reward for episode 12400 is -0.3977483561094512 with std of 0.6539861323568706.
# Episode: 12450
# The avg. test reward for episode 12450 is -0.002757086570139283 with std of 1.0549658318236856.
# Episode: 12500
# The avg. test reward for episode 12500 is -0.713519332718347 with std of 0.04303203787157779.
# Episode: 12550
# The avg. test reward for episode 12550 is 0.23790289300609496 with std of 1.2248534235114712.
# Episode: 12600
# The avg. test reward for episode 12600 is -0.10683428586389934 with std of 0.9948850716691064.
# Episode: 12650
# The avg. test reward for episode 12650 is -0.20950928757466541 with std of 0.9430811921713181.
# Episode: 12700
# The avg. test reward for episode 12700 is -0.4222313415965376 with std of 0.7559863112547083.
# Episode: 12750
# The avg. test reward for episode 12750 is 0.5418739542736783 with std of 1.3250923107205634.
# Episode: 12800
# The avg. test reward for episode 12800 is -0.15674658513310855 with std of 0.9715592734690911.
# Episode: 12850
# The avg. test reward for episode 12850 is -0.1305079907101438 with std of 0.9838192847591828.
# Episode: 12900
# The avg. test reward for episode 12900 is 0.03926212376180184 with std of 1.085914533649554.
# Episode: 12950
#   0%|          | 0/5 [9:15:54<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 53
#      51 G = np.zeros(20)
#      52 for k in range(20): # run 20 evaluations
# ---> 53     g = evaluate_policy(env, policy_net) # dict of rewards instead of scalar reward
#      54     g = np.array(g)
#      55     g = np.mean(g)
#
# Cell In[21], line 5, in evaluate_policy(env, policy_net)
#       1 def evaluate_policy(env, policy_net):
#       2     """
#       3     Compute accumulative trajectory reward
#       4     """
# ----> 5     states, actions, rewards, log_probs = generate_single_episode(env, policy_net)
#       6     return np.sum(rewards)
#
# Cell In[20], line 16, in generate_single_episode(env, policy_net, rl_mgr)
#      13 for _, row in env.draft.iterrows():
#      15     if row['mgr'] != rl_mgr:
# ---> 16         env.step(env.reasonable_option())
#      17         continue
#      19     state = torch.from_numpy(state).float().unsqueeze(0)
#
# File ~/files/fun_projects/fantasy_football_2024/rl_env.py:330, in DraftEnv.step(self, action)
#     328 # update the state
#     329 self.update_state()
# --> 330 reward = self.compute_reward(mgr_num)
#     332 self.cur_turn += 1
#     333 if self.cur_turn < len(self.turns):
#
# File ~/files/fun_projects/fantasy_football_2024/rl_env.py:264, in DraftEnv.compute_reward(self, mgr_num)
#     261 recent_choice_id = recent_choice["sleeper_id"].values[0]
#     262 chose_starter = recent_choice_id in starter_ids
# --> 264 if self.is_starters_filled(mgr_num):
#     265     reward = starters_sum + bench_sum
#     266     # reward = starters_sum
#     267
#     268 # give a small reward if they draft a starter
#
# File ~/files/fun_projects/fantasy_football_2024/rl_env.py:217, in DraftEnv.is_starters_filled(self, mgr_num)
#     216 def is_starters_filled(self, mgr_num: int) -> bool:
# --> 217     filled = [x >= STARTER_COMPOSITION[pos] for pos, x in self.get_team_comp(mgr_num, flex=True).items()]
#     218     if all(filled):
#     219         return True
#
# File ~/files/fun_projects/fantasy_football_2024/rl_env.py:183, in DraftEnv.get_team_comp(self, mgr_num, flex)
#     180 ''' Get the team composition for a manager.
#     181 If flex is True, then the FLEX position is included in the count'''
#     182 if flex:
# --> 183     team_comp = self.draft.loc[(self.draft["mgr"] == mgr_num)].groupby("team_pos").size().to_dict()
#     184     team_comp["FLEX"] = team_comp.get("FLEX", 0)
#     185 else:
#
# File ~/files/fun_projects/fantasy_football_2024/venv/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:3043, in GroupBy.size(self)
#    2985 @final
#    2986 @Substitution(name="groupby")
#    2987 @Substitution(see_also=_common_see_also)
#    2988 def size(self) -> DataFrame | Series:
#    2989     """
#    2990     Compute group sizes.
#    2991
#    (...)
#    3041     Freq: MS, dtype: int64
#    3042     """
# -> 3043     result = self._grouper.size()
#    3044     dtype_backend: None | Literal["pyarrow", "numpy_nullable"] = None
#    3045     if isinstance(self.obj, Series):
#
# File ~/files/fun_projects/fantasy_football_2024/venv/lib/python3.9/site-packages/pandas/core/groupby/ops.py:705, in BaseGrouper.size(self)
#     700 @final
#     701 def size(self) -> Series:
#     702     """
#     703     Compute group sizes.
#     704     """
# --> 705     ids, _, ngroups = self.group_info
#     706     out: np.ndarray | list
#     707     if ngroups:
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/files/fun_projects/fantasy_football_2024/venv/lib/python3.9/site-packages/pandas/core/groupby/ops.py:745, in BaseGrouper.group_info(self)
#     743 @cache_readonly
#     744 def group_info(self) -> tuple[npt.NDArray[np.intp], npt.NDArray[np.intp], int]:
# --> 745     comp_ids, obs_group_ids = self._get_compressed_codes()
#     747     ngroups = len(obs_group_ids)
#     748     comp_ids = ensure_platform_int(comp_ids)
#
# File ~/files/fun_projects/fantasy_football_2024/venv/lib/python3.9/site-packages/pandas/core/groupby/ops.py:769, in BaseGrouper._get_compressed_codes(self)
#     766     # FIXME: compress_group_index's second return value is int64, not intp
#     768 ping = self.groupings[0]
# --> 769 return ping.codes, np.arange(len(ping._group_index), dtype=np.intp)
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/files/fun_projects/fantasy_football_2024/venv/lib/python3.9/site-packages/pandas/core/groupby/grouper.py:765, in Grouping._group_index(self)
#     761             new_codes = np.insert(uniques.codes, na_unique_idx, -1)
#     762             uniques = Categorical.from_codes(
#     763                 new_codes, uniques.categories, validate=False
#     764             )
# --> 765 return Index._with_infer(uniques, name=self.name)
#
# File ~/files/fun_projects/fantasy_football_2024/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:680, in Index._with_infer(cls, *args, **kwargs)
#     674 @classmethod
#     675 def _with_infer(cls, *args, **kwargs):
#     676     """
#     677     Constructor that uses the 1.0.x behavior inferring numeric dtypes
#     678     for ndarray[object] inputs.
#     679     """
# --> 680     result = cls(*args, **kwargs)
#     682     if result.dtype == _dtype_obj and not result._is_multi:
#     683         # error: Argument 1 to "maybe_convert_objects" has incompatible type
#     684         # "Union[ExtensionArray, ndarray[Any, Any]]"; expected
#     685         # "ndarray[Any, Any]"
#     686         values = lib.maybe_convert_objects(result._values)  # type: ignore[arg-type]
#
# File ~/files/fun_projects/fantasy_football_2024/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:574, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols)
#     571     raise
#     572 arr = ensure_wrapped_if_datetimelike(arr)
# --> 574 klass = cls._dtype_to_subclass(arr.dtype)
#     576 arr = klass._ensure_array(arr, arr.dtype, copy=False)
#     577 result = klass._simple_new(arr, name, refs=refs)
#
# KeyboardInterrupt:

# %%
env.draft
# Out:
#      round  mgr sleeper_id       full_name  team position team_pos   fp_mean  \
# 0        0    0       3678        Wil Lutz   DEN        K        K  0.308629
# 1        0    1       6786     CeeDee Lamb   DAL       WR       WR  0.780495
# 2        0    2      11539      Jake Bates   DET        K        K  0.307618
# 3        0    3        HOU  Houston Texans   HOU      DEF      DEF  0.381082
# 4        0    4       2133   Davante Adams    LV       WR       WR      None
# ..     ...  ...        ...             ...   ...      ...      ...       ...
# 175     14    7       None            None  None     None     None      None
# 176     14    8       None            None  None     None     None      None
# 177     14    9      11604    Brock Bowers    LV       TE       TE      None
# 178     14   10       9508    Tyjae Spears   TEN       RB       RB      None
# 179     14   11       None            None  None     None     None      None
#
#         fp_std
# 0     5.089597
# 1    43.238199
# 2     4.041452
# 3    35.696201
# 4         None
# ..         ...
# 175       None
# 176       None
# 177       None
# 178       None
# 179       None
#
# [180 rows x 9 columns]

# %%
episode = generate_single_episode(env, policy_net_dict) 
episode
# Out:
# {0: {'states': [tensor([[1.0000, 0.9844, 0.9274, 0.9037, 0.8586, 0.8530, 0.8528, 0.8524, 0.8345,
#             0.8215, 0.8625, 0.7142, 0.6961, 0.6692, 0.6482, 0.6251, 0.6169, 0.5975,
#             0.5917, 0.5848, 0.7805, 0.7493, 0.7015, 0.6882, 0.6809, 0.6473, 0.6441,
#             0.6075, 0.5852, 0.5668, 0.5168, 0.5098, 0.4764, 0.4509, 0.4355, 0.4319,
#             0.4218, 0.4213, 0.3993, 0.3949, 0.3752, 0.3704, 0.3684, 0.3683, 0.3582,
#             0.3542, 0.3527, 0.3517, 0.3432, 0.3405, 0.4764, 0.4286, 0.4237, 0.4155,
#             0.4106, 0.4071, 0.4060, 0.3965, 0.3874, 0.3811, 0.0000, 1.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000]]),
#    tensor([[0.8528, 0.8524, 0.8345, 0.8215, 0.8085, 0.7886, 0.7872, 0.7783, 0.7751,
#             0.7652, 0.6692, 0.6482, 0.6251, 0.6169, 0.5975, 0.5917, 0.5848, 0.5806,
#             0.5797, 0.5784, 0.6882, 0.6809, 0.6473, 0.6441, 0.6075, 0.5852, 0.5668,
#             0.5632, 0.5559, 0.5559, 0.4509, 0.4355, 0.4319, 0.4218, 0.4213, 0.3993,
#             0.3949, 0.3670, 0.3388, 0.3371, 0.3683, 0.3582, 0.3542, 0.3527, 0.3517,
#             0.3432, 0.3405, 0.3392, 0.3376, 0.3367, 0.4071, 0.4060, 0.3965, 0.3874,
#             0.3811, 0.3733, 0.3718, 0.3674, 0.3656, 0.3631, 1.0000, 0.1304, 0.0000,
#             0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 1.0000, 0.0000, 1.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 1.0000, 1.0000,
#             0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 1.0000,
#             0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000,
#             1.0000, 0.0000, 0.0000, 0.0000, 1.0000, 1.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 1.0000, 1.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 1.0000,
#             0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             1.0000, 1.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000]]),
#    tensor([[0.8528, 0.8524, 0.8345, 0.8215, 0.8085, 0.7886, 0.7872, 0.7783, 0.7751,
#             0.7652, 0.6482, 0.6251, 0.6169, 0.5975, 0.5917, 0.5848, 0.5806, 0.5797,
#             0.5784, 0.5525, 0.6882, 0.6809, 0.6473, 0.6441, 0.6075, 0.5852, 0.5668,
#             0.5632, 0.5559, 0.5559, 0.4509, 0.4355, 0.4319, 0.4218, 0.4213, 0.3993,
#             0.3949, 0.3670, 0.3388, 0.3371, 0.3683, 0.3582, 0.3542, 0.3527, 0.3517,
#             0.3432, 0.3405, 0.3392, 0.3376, 0.3367, 0.4071, 0.4060, 0.3965, 0.3874,
#             0.3811, 0.3733, 0.3718, 0.3674, 0.3656, 0.3631, 1.0000, 0.0435, 0.0000,
#             1.0000, 0.0000, 1.0000, 0.0000, 0.0000, 1.0000, 0.0000, 1.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 1.0000, 1.0000,
#             0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 1.0000,
#             0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000,
#             1.0000, 0.0000, 0.0000, 0.0000, 1.0000, 1.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 1.0000, 1.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 1.0000,
#             0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             1.0000, 1.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000]]),
#    tensor([[0.8085, 0.7886, 0.7872, 0.7783, 0.7751, 0.7652, 0.7639, 0.7487, 0.7420,
#             0.7368, 0.6169, 0.5975, 0.5917, 0.5848, 0.5806, 0.5797, 0.5784, 0.5525,
#             0.5464, 0.5449, 0.6473, 0.6441, 0.6075, 0.5852, 0.5668, 0.5632, 0.5559,
#             0.5559, 0.5543, 0.5478, 0.3993, 0.3949, 0.3670, 0.3388, 0.3371, 0.3346,
#             0.3278, 0.3225, 0.2797, 0.2717, 0.3376, 0.3367, 0.3366, 0.3353, 0.3328,
#             0.3266, 0.3253, 0.3160, 0.3124, 0.3118, 0.3965, 0.3874, 0.3811, 0.3733,
#             0.3718, 0.3674, 0.3656, 0.3631, 0.3629, 0.3626, 3.0000, 0.1304, 0.0000,
#             1.0000, 1.0000, 1.0000, 0.0000, 0.0000, 2.0000, 0.0000, 1.0000, 0.0000,
#             0.0000, 1.0000, 0.0000, 1.0000, 0.0000, 1.0000, 1.0000, 1.0000, 1.0000,
#             1.0000, 2.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 2.0000,
#             1.0000, 0.0000, 1.0000, 1.0000, 0.0000, 0.0000, 2.0000, 0.0000, 1.0000,
#             1.0000, 0.0000, 0.0000, 1.0000, 1.0000, 2.0000, 0.0000, 0.0000, 0.0000,
#             1.0000, 1.0000, 1.0000, 0.0000, 0.0000, 2.0000, 1.0000, 0.0000, 1.0000,
#             0.0000, 0.0000, 1.0000, 2.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000,
#             1.0000, 2.0000, 1.0000, 1.0000, 0.0000, 0.0000, 1.0000, 1.0000]]),
#    tensor([[0.7886, 0.7872, 0.7783, 0.7751, 0.7652, 0.7639, 0.7487, 0.7420, 0.7368,
#             0.7367, 0.6169, 0.5975, 0.5917, 0.5848, 0.5806, 0.5797, 0.5784, 0.5525,
#             0.5464, 0.5449, 0.6473, 0.6441, 0.6075, 0.5852, 0.5668, 0.5632, 0.5559,
#             0.5559, 0.5543, 0.5478, 0.3993, 0.3949, 0.3670, 0.3388, 0.3371, 0.3346,
#             0.3278, 0.3225, 0.2797, 0.2717, 0.3376, 0.3367, 0.3366, 0.3353, 0.3328,
#             0.3266, 0.3253, 0.3160, 0.3124, 0.3118, 0.3965, 0.3874, 0.3811, 0.3733,
#             0.3718, 0.3674, 0.3656, 0.3631, 0.3629, 0.3626, 3.0000, 0.0435, 1.0000,
#             1.0000, 1.0000, 1.0000, 0.0000, 0.0000, 2.0000, 0.0000, 1.0000, 0.0000,
#             0.0000, 1.0000, 0.0000, 1.0000, 0.0000, 1.0000, 1.0000, 1.0000, 1.0000,
#             1.0000, 2.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 2.0000,
#             1.0000, 0.0000, 1.0000, 1.0000, 0.0000, 0.0000, 2.0000, 0.0000, 1.0000,
#             1.0000, 0.0000, 0.0000, 1.0000, 1.0000, 2.0000, 0.0000, 0.0000, 0.0000,
#             1.0000, 1.0000, 1.0000, 0.0000, 0.0000, 2.0000, 1.0000, 0.0000, 1.0000,
#             0.0000, 0.0000, 1.0000, 2.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000,
#             1.0000, 2.0000, 1.0000, 1.0000, 0.0000, 0.0000, 1.0000, 1.0000]]),
#    tensor([[0.7639, 0.7487, 0.7420, 0.7368, 0.7367, 0.7300, 0.7118, 0.6947, 0.6922,
#             0.6498, 0.5797, 0.5784, 0.5525, 0.5464, 0.5449, 0.5442, 0.4877, 0.4867,
#             0.4816, 0.4805, 0.5632, 0.5559, 0.5559, 0.5543, 0.5478, 0.5472, 0.5457,
#             0.5453, 0.5436, 0.5380, 0.3670, 0.3388, 0.3371, 0.3346, 0.3278, 0.3225,
#             0.2797, 0.2717, 0.2675, 0.2663, 0.3353, 0.3328, 0.3266, 0.3253, 0.3160,
#             0.3124, 0.3118, 0.3107, 0.3086, 0.3076, 0.3733, 0.3718, 0.3674, 0.3656,
#             0.3631, 0.3629, 0.3626, 0.3518, 0.3511, 0.3493, 5.0000, 0.1304, 1.0000,
#             1.0000, 1.0000, 2.0000, 0.0000, 0.0000, 2.0000, 1.0000, 2.0000, 0.0000,
#             0.0000, 1.0000, 0.0000, 3.0000, 0.0000, 1.0000, 1.0000, 1.0000, 1.0000,
#             1.0000, 3.0000, 0.0000, 0.0000, 1.0000, 2.0000, 0.0000, 1.0000, 2.0000,
#             1.0000, 0.0000, 1.0000, 2.0000, 0.0000, 0.0000, 3.0000, 0.0000, 1.0000,
#             1.0000, 2.0000, 0.0000, 1.0000, 1.0000, 3.0000, 0.0000, 1.0000, 0.0000,
#             1.0000, 1.0000, 2.0000, 0.0000, 0.0000, 3.0000, 1.0000, 0.0000, 1.0000,
#             0.0000, 0.0000, 1.0000, 3.0000, 1.0000, 0.0000, 1.0000, 0.0000, 1.0000,
#             1.0000, 3.0000, 2.0000, 1.0000, 0.0000, 0.0000, 2.0000, 1.0000]]),
#    tensor([[0.7639, 0.7487, 0.7420, 0.7368, 0.7367, 0.7300, 0.7118, 0.6947, 0.6922,
#             0.6498, 0.5797, 0.5784, 0.5525, 0.5464, 0.5449, 0.5442, 0.4877, 0.4867,
#             0.4816, 0.4805, 0.5559, 0.5559, 0.5543, 0.5478, 0.5472, 0.5457, 0.5453,
#             0.5436, 0.5380, 0.5293, 0.3670, 0.3388, 0.3371, 0.3346, 0.3278, 0.3225,
#             0.2797, 0.2717, 0.2675, 0.2663, 0.3353, 0.3328, 0.3266, 0.3253, 0.3160,
#             0.3124, 0.3118, 0.3107, 0.3086, 0.3076, 0.3733, 0.3718, 0.3674, 0.3656,
#             0.3631, 0.3629, 0.3626, 0.3518, 0.3511, 0.3493, 5.0000, 0.0435, 1.0000,
#             1.0000, 2.0000, 2.0000, 0.0000, 0.0000, 2.0000, 1.0000, 2.0000, 0.0000,
#             0.0000, 1.0000, 0.0000, 3.0000, 0.0000, 1.0000, 1.0000, 1.0000, 1.0000,
#             1.0000, 3.0000, 0.0000, 0.0000, 1.0000, 2.0000, 0.0000, 1.0000, 2.0000,
#             1.0000, 0.0000, 1.0000, 2.0000, 0.0000, 0.0000, 3.0000, 0.0000, 1.0000,
#             1.0000, 2.0000, 0.0000, 1.0000, 1.0000, 3.0000, 0.0000, 1.0000, 0.0000,
#             1.0000, 1.0000, 2.0000, 0.0000, 0.0000, 3.0000, 1.0000, 0.0000, 1.0000,
#             0.0000, 0.0000, 1.0000, 3.0000, 1.0000, 0.0000, 1.0000, 0.0000, 1.0000,
#             1.0000, 3.0000, 2.0000, 1.0000, 0.0000, 0.0000, 2.0000, 1.0000]]),
#    tensor([[0.7300, 0.7118, 0.6947, 0.6922, 0.6498, 0.6007, 0.5971, 0.5871, 0.5646,
#             0.4374, 0.5525, 0.5464, 0.5449, 0.5442, 0.4877, 0.4867, 0.4816, 0.4805,
#             0.4788, 0.4702, 0.5472, 0.5457, 0.5453, 0.5436, 0.5380, 0.5293, 0.5290,
#             0.5281, 0.5266, 0.5182, 0.3371, 0.3346, 0.3278, 0.3225, 0.2797, 0.2717,
#             0.2675, 0.2663, 0.2575, 0.2525, 0.3124, 0.3118, 0.3107, 0.3086, 0.3076,
#             0.3070, 0.3055, 0.2951, 0.2861, 0.2745, 0.3629, 0.3626, 0.3518, 0.3511,
#             0.3493, 0.3472, 0.3462, 0.3426, 0.3387, 0.3379, 7.0000, 0.1304, 1.0000,
#             1.0000, 2.0000, 2.0000, 1.0000, 0.0000, 3.0000, 1.0000, 2.0000, 1.0000,
#             0.0000, 1.0000, 0.0000, 3.0000, 1.0000, 1.0000, 1.0000, 2.0000, 1.0000,
#             1.0000, 5.0000, 0.0000, 0.0000, 1.0000, 3.0000, 0.0000, 1.0000, 2.0000,
#             2.0000, 0.0000, 2.0000, 2.0000, 0.0000, 0.0000, 4.0000, 0.0000, 1.0000,
#             1.0000, 3.0000, 0.0000, 1.0000, 2.0000, 3.0000, 0.0000, 1.0000, 0.0000,
#             1.0000, 3.0000, 3.0000, 0.0000, 0.0000, 4.0000, 1.0000, 0.0000, 2.0000,
#             1.0000, 0.0000, 1.0000, 3.0000, 1.0000, 0.0000, 1.0000, 0.0000, 1.0000,
#             2.0000, 4.0000, 2.0000, 2.0000, 0.0000, 0.0000, 3.0000, 1.0000]]),
#    tensor([[0.7118, 0.6947, 0.6922, 0.6498, 0.6007, 0.5971, 0.5871, 0.5646, 0.4374,
#             0.3729, 0.5525, 0.5464, 0.5449, 0.5442, 0.4877, 0.4867, 0.4816, 0.4805,
#             0.4788, 0.4702, 0.5472, 0.5457, 0.5453, 0.5436, 0.5380, 0.5293, 0.5290,
#             0.5281, 0.5266, 0.5182, 0.3371, 0.3346, 0.3278, 0.3225, 0.2797, 0.2717,
#             0.2675, 0.2663, 0.2575, 0.2525, 0.3124, 0.3118, 0.3107, 0.3086, 0.3076,
#             0.3070, 0.3055, 0.2951, 0.2861, 0.2745, 0.3629, 0.3626, 0.3518, 0.3511,
#             0.3493, 0.3472, 0.3462, 0.3426, 0.3387, 0.3379, 7.0000, 0.0435, 2.0000,
#             1.0000, 2.0000, 2.0000, 1.0000, 0.0000, 3.0000, 1.0000, 2.0000, 1.0000,
#             0.0000, 1.0000, 0.0000, 3.0000, 1.0000, 1.0000, 1.0000, 2.0000, 1.0000,
#             1.0000, 5.0000, 0.0000, 0.0000, 1.0000, 3.0000, 0.0000, 1.0000, 2.0000,
#             2.0000, 0.0000, 2.0000, 2.0000, 0.0000, 0.0000, 4.0000, 0.0000, 1.0000,
#             1.0000, 3.0000, 0.0000, 1.0000, 2.0000, 3.0000, 0.0000, 1.0000, 0.0000,
#             1.0000, 3.0000, 3.0000, 0.0000, 0.0000, 4.0000, 1.0000, 0.0000, 2.0000,
#             1.0000, 0.0000, 1.0000, 3.0000, 1.0000, 0.0000, 1.0000, 0.0000, 1.0000,
#             2.0000, 4.0000, 2.0000, 2.0000, 0.0000, 0.0000, 3.0000, 1.0000]]),
#    tensor([[0.6007, 0.5971, 0.5871, 0.5646, 0.4374, 0.3729, 0.2772, 0.2170, 0.2137,
#             0.2066, 0.5464, 0.5449, 0.5442, 0.4877, 0.4867, 0.4816, 0.4805, 0.4788,
#             0.4702, 0.4694, 0.5293, 0.5290, 0.5281, 0.5266, 0.5182, 0.5126, 0.5090,
#             0.4976, 0.4963, 0.4918, 0.2797, 0.2717, 0.2675, 0.2663, 0.2575, 0.2525,
#             0.2392, 0.2297, 0.2209, 0.2114, 0.3070, 0.3055, 0.2951, 0.2861, 0.2745,
#             0.2475, 0.2232, 0.2145, 0.2091, 0.2075, 0.3493, 0.3472, 0.3462, 0.3426,
#             0.3387, 0.3379, 0.3311, 0.3299, 0.3266, 0.3257, 9.0000, 0.1304, 2.0000,
#             1.0000, 2.0000, 3.0000, 1.0000, 0.0000, 3.0000, 1.0000, 4.0000, 1.0000,
#             0.0000, 1.0000, 0.0000, 3.0000, 2.0000, 1.0000, 1.0000, 2.0000, 2.0000,
#             1.0000, 6.0000, 0.0000, 0.0000, 1.0000, 4.0000, 0.0000, 1.0000, 2.0000,
#             3.0000, 0.0000, 2.0000, 2.0000, 0.0000, 0.0000, 5.0000, 1.0000, 1.0000,
#             1.0000, 3.0000, 1.0000, 1.0000, 3.0000, 3.0000, 0.0000, 1.0000, 0.0000,
#             2.0000, 4.0000, 3.0000, 0.0000, 0.0000, 5.0000, 1.0000, 1.0000, 3.0000,
#             1.0000, 0.0000, 1.0000, 4.0000, 1.0000, 0.0000, 1.0000, 1.0000, 2.0000,
#             2.0000, 4.0000, 3.0000, 2.0000, 0.0000, 0.0000, 4.0000, 1.0000]]),
#    tensor([[0.5971, 0.5871, 0.5646, 0.4374, 0.3729, 0.2772, 0.2170, 0.2137, 0.2066,
#             0.1015, 0.5464, 0.5449, 0.5442, 0.4877, 0.4867, 0.4816, 0.4805, 0.4788,
#             0.4702, 0.4694, 0.5293, 0.5290, 0.5281, 0.5266, 0.5182, 0.5126, 0.5090,
#             0.4976, 0.4963, 0.4918, 0.2797, 0.2717, 0.2675, 0.2663, 0.2575, 0.2525,
#             0.2392, 0.2297, 0.2209, 0.2114, 0.3070, 0.3055, 0.2951, 0.2861, 0.2745,
#             0.2475, 0.2232, 0.2145, 0.2091, 0.2075, 0.3493, 0.3472, 0.3462, 0.3426,
#             0.3387, 0.3379, 0.3311, 0.3299, 0.3266, 0.3257, 9.0000, 0.0435, 3.0000,
#             1.0000, 2.0000, 3.0000, 1.0000, 0.0000, 3.0000, 1.0000, 4.0000, 1.0000,
#             0.0000, 1.0000, 0.0000, 3.0000, 2.0000, 1.0000, 1.0000, 2.0000, 2.0000,
#             1.0000, 6.0000, 0.0000, 0.0000, 1.0000, 4.0000, 0.0000, 1.0000, 2.0000,
#             3.0000, 0.0000, 2.0000, 2.0000, 0.0000, 0.0000, 5.0000, 1.0000, 1.0000,
#             1.0000, 3.0000, 1.0000, 1.0000, 3.0000, 3.0000, 0.0000, 1.0000, 0.0000,
#             2.0000, 4.0000, 3.0000, 0.0000, 0.0000, 5.0000, 1.0000, 1.0000, 3.0000,
#             1.0000, 0.0000, 1.0000, 4.0000, 1.0000, 0.0000, 1.0000, 1.0000, 2.0000,
#             2.0000, 4.0000, 3.0000, 2.0000, 0.0000, 0.0000, 4.0000, 1.0000]]),
#    tensor([[ 0.3729,  0.2772,  0.2170,  0.2137,  0.2066,  0.1015,  0.0915,  0.0864,
#              0.0781,  0.0739,  0.5464,  0.5449,  0.5442,  0.4877,  0.4867,  0.4816,
#              0.4805,  0.4788,  0.4702,  0.4694,  0.5126,  0.5090,  0.4976,  0.4963,
#              0.4918,  0.4851,  0.4800,  0.4790,  0.4692,  0.4621,  0.2525,  0.2392,
#              0.2297,  0.2209,  0.2114,  0.1907,  0.1884,  0.1869,  0.1834,  0.1828,
#              0.2475,  0.2232,  0.2145,  0.2091,  0.2075,  0.2016,  0.1957,  0.1422,
#              0.1157,  0.0947,  0.3387,  0.3379,  0.3311,  0.3299,  0.3266,  0.3257,
#              0.3097,  0.2999,  0.2968,  0.0000, 11.0000,  0.1304,  3.0000,  1.0000,
#              2.0000,  4.0000,  1.0000,  0.0000,  3.0000,  1.0000,  5.0000,  2.0000,
#              0.0000,  1.0000,  0.0000,  3.0000,  2.0000,  1.0000,  1.0000,  3.0000,
#              2.0000,  1.0000,  8.0000,  0.0000,  0.0000,  1.0000,  5.0000,  0.0000,
#              1.0000,  2.0000,  4.0000,  0.0000,  2.0000,  2.0000,  0.0000,  0.0000,
#              7.0000,  1.0000,  1.0000,  1.0000,  4.0000,  1.0000,  1.0000,  4.0000,
#              4.0000,  0.0000,  1.0000,  1.0000,  2.0000,  4.0000,  3.0000,  0.0000,
#              0.0000,  6.0000,  2.0000,  1.0000,  4.0000,  1.0000,  0.0000,  2.0000,
#              4.0000,  1.0000,  0.0000,  1.0000,  1.0000,  2.0000,  3.0000,  5.0000,
#              4.0000,  2.0000,  0.0000,  0.0000,  4.0000,  2.0000]]),
#    tensor([[ 0.3729,  0.2772,  0.2170,  0.2137,  0.2066,  0.1015,  0.0915,  0.0864,
#              0.0781,  0.0739,  0.5464,  0.5449,  0.5442,  0.4877,  0.4867,  0.4816,
#              0.4805,  0.4788,  0.4702,  0.4694,  0.5090,  0.4976,  0.4963,  0.4918,
#              0.4851,  0.4800,  0.4790,  0.4692,  0.4621,  0.4606,  0.2525,  0.2392,
#              0.2297,  0.2209,  0.2114,  0.1907,  0.1884,  0.1869,  0.1834,  0.1828,
#              0.2475,  0.2232,  0.2145,  0.2091,  0.2075,  0.2016,  0.1957,  0.1422,
#              0.1157,  0.0947,  0.3387,  0.3379,  0.3311,  0.3299,  0.3266,  0.3257,
#              0.3097,  0.2999,  0.2968,  0.0000, 11.0000,  0.0435,  3.0000,  1.0000,
#              3.0000,  4.0000,  1.0000,  0.0000,  3.0000,  1.0000,  5.0000,  2.0000,
#              0.0000,  1.0000,  0.0000,  3.0000,  2.0000,  1.0000,  1.0000,  3.0000,
#              2.0000,  1.0000,  8.0000,  0.0000,  0.0000,  1.0000,  5.0000,  0.0000,
#              1.0000,  2.0000,  4.0000,  0.0000,  2.0000,  2.0000,  0.0000,  0.0000,
#              7.0000,  1.0000,  1.0000,  1.0000,  4.0000,  1.0000,  1.0000,  4.0000,
#              4.0000,  0.0000,  1.0000,  1.0000,  2.0000,  4.0000,  3.0000,  0.0000,
#              0.0000,  6.0000,  2.0000,  1.0000,  4.0000,  1.0000,  0.0000,  2.0000,
#              4.0000,  1.0000,  0.0000,  1.0000,  1.0000,  2.0000,  3.0000,  5.0000,
#              4.0000,  2.0000,  0.0000,  0.0000,  4.0000,  2.0000]]),
#    tensor([[ 0.0864,  0.0781,  0.0739,  0.0707,  0.0678,  0.0658,  0.0657,  0.0632,
#              0.0592,  0.0568,  0.5449,  0.5442,  0.4877,  0.4867,  0.4816,  0.4805,
#              0.4788,  0.4702,  0.4694,  0.4509,  0.4800,  0.4790,  0.4692,  0.4621,
#              0.4606,  0.4578,  0.4570,  0.4410,  0.4353,  0.3888,  0.2392,  0.2297,
#              0.2209,  0.2114,  0.1907,  0.1884,  0.1869,  0.1834,  0.1828,  0.1826,
#              0.2091,  0.2075,  0.2016,  0.1957,  0.1422,  0.1157,  0.0947,  0.0707,
#              0.0517,  0.0454,  0.3097,  0.2999,  0.2968,  0.0000,  0.0000,  0.0000,
#              0.0000,  0.0000,  0.0000,  0.0000, 13.0000,  0.1304,  4.0000,  1.0000,
#              3.0000,  4.0000,  1.0000,  0.0000,  4.0000,  1.0000,  6.0000,  2.0000,
#              0.0000,  1.0000,  0.0000,  3.0000,  2.0000,  1.0000,  1.0000,  4.0000,
#              2.0000,  1.0000, 10.0000,  0.0000,  0.0000,  1.0000,  6.0000,  0.0000,
#              1.0000,  2.0000,  5.0000,  0.0000,  2.0000,  2.0000,  0.0000,  0.0000,
#              9.0000,  1.0000,  1.0000,  2.0000,  4.0000,  2.0000,  1.0000,  4.0000,
#              5.0000,  0.0000,  1.0000,  1.0000,  2.0000,  5.0000,  3.0000,  0.0000,
#              0.0000,  6.0000,  2.0000,  3.0000,  5.0000,  1.0000,  1.0000,  2.0000,
#              4.0000,  1.0000,  0.0000,  1.0000,  1.0000,  2.0000,  3.0000,  7.0000,
#              6.0000,  2.0000,  0.0000,  0.0000,  4.0000,  2.0000]]),
#    tensor([[ 0.0781,  0.0739,  0.0707,  0.0678,  0.0658,  0.0657,  0.0632,  0.0592,
#              0.0568,  0.0567,  0.5449,  0.5442,  0.4877,  0.4867,  0.4816,  0.4805,
#              0.4788,  0.4702,  0.4694,  0.4509,  0.4800,  0.4790,  0.4692,  0.4621,
#              0.4606,  0.4578,  0.4570,  0.4410,  0.4353,  0.3888,  0.2392,  0.2297,
#              0.2209,  0.2114,  0.1907,  0.1884,  0.1869,  0.1834,  0.1828,  0.1826,
#              0.2091,  0.2075,  0.2016,  0.1957,  0.1422,  0.1157,  0.0947,  0.0707,
#              0.0517,  0.0454,  0.3097,  0.2999,  0.2968,  0.0000,  0.0000,  0.0000,
#              0.0000,  0.0000,  0.0000,  0.0000, 13.0000,  0.0435,  5.0000,  1.0000,
#              3.0000,  4.0000,  1.0000,  0.0000,  4.0000,  1.0000,  6.0000,  2.0000,
#              0.0000,  1.0000,  0.0000,  3.0000,  2.0000,  1.0000,  1.0000,  4.0000,
#              2.0000,  1.0000, 10.0000,  0.0000,  0.0000,  1.0000,  6.0000,  0.0000,
#              1.0000,  2.0000,  5.0000,  0.0000,  2.0000,  2.0000,  0.0000,  0.0000,
#              9.0000,  1.0000,  1.0000,  2.0000,  4.0000,  2.0000,  1.0000,  4.0000,
#              5.0000,  0.0000,  1.0000,  1.0000,  2.0000,  5.0000,  3.0000,  0.0000,
#              0.0000,  6.0000,  2.0000,  3.0000,  5.0000,  1.0000,  1.0000,  2.0000,
#              4.0000,  1.0000,  0.0000,  1.0000,  1.0000,  2.0000,  3.0000,  7.0000,
#              6.0000,  2.0000,  0.0000,  0.0000,  4.0000,  2.0000]])],
#   'actions': [3, 1, 2, 0, 3, 2, 4, 0, 3, 0, 3, 2, 0, 0, 2],
#   'rewards': [np.float64(0.0344518653862523),
#    np.float64(0.07906649254323819),
#    np.float64(0.12494790095389861),
#    np.float64(0.17884842874998994),
#    np.float64(0.18550379933758088),
#    np.float64(0.2230487033395397),
#    np.float64(0.24539969645741266),
#    np.float64(0.2575665965384211),
#    np.float64(0.2631843168939646),
#    np.float64(0.27319541686579),
#    np.float64(0.27785745182193367),
#    np.float64(0.28640003719122603),
#    np.float64(0.29261428918813015),
#    np.float64(0.2940544523309145),
#    np.float64(0.3020546552959412)],
#   'log_probs': [tensor(-1.4219, grad_fn=<LogBackward0>),
#    tensor(-1.7752, grad_fn=<LogBackward0>),
#    tensor(-1.3816, grad_fn=<LogBackward0>),
#    tensor(-1.8334, grad_fn=<LogBackward0>),
#    tensor(-1.6513, grad_fn=<LogBackward0>),
#    tensor(-1.1903, grad_fn=<LogBackward0>),
#    tensor(-1.7687, grad_fn=<LogBackward0>),
#    tensor(-1.7806, grad_fn=<LogBackward0>),
#    tensor(-1.9591, grad_fn=<LogBackward0>),
#    tensor(-1.6823, grad_fn=<LogBackward0>),
#    tensor(-1.9808, grad_fn=<LogBackward0>),
#    tensor(-0.7604, grad_fn=<LogBackward0>),
#    tensor(-1.7957, grad_fn=<LogBackward0>),
#    tensor(-1.8151, grad_fn=<LogBackward0>),
#    tensor(-0.6729, grad_fn=<LogBackward0>)]},
#  1: {'states': [tensor([[1.0000, 0.9844, 0.9274, 0.9037, 0.8586, 0.8530, 0.8528, 0.8524, 0.8345,
#             0.8215, 0.8625, 0.7142, 0.6961, 0.6692, 0.6482, 0.6251, 0.6169, 0.5975,
#             0.5917, 0.5848, 0.7805, 0.7493, 0.7015, 0.6882, 0.6809, 0.6473, 0.6441,
#             0.6075, 0.5852, 0.5668, 0.5098, 0.4764, 0.4509, 0.4355, 0.4319, 0.4218,
#             0.4213, 0.3993, 0.3949, 0.3670, 0.3752, 0.3704, 0.3684, 0.3683, 0.3582,
#             0.3542, 0.3527, 0.3517, 0.3432, 0.3405, 0.4764, 0.4286, 0.4237, 0.4155,
#             0.4106, 0.4071, 0.4060, 0.3965, 0.3874, 0.3811, 0.0000, 1.0000, 0.0000,
#             0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000]]),
#    tensor([[0.8528, 0.8524, 0.8345, 0.8215, 0.8085, 0.7886, 0.7872, 0.7783, 0.7751,
#             0.7652, 0.6692, 0.6482, 0.6251, 0.6169, 0.5975, 0.5917, 0.5848, 0.5806,
#             0.5797, 0.5784, 0.7015, 0.6882, 0.6809, 0.6473, 0.6441, 0.6075, 0.5852,
#             0.5668, 0.5632, 0.5559, 0.4509, 0.4355, 0.4319, 0.4218, 0.4213, 0.3993,
#             0.3949, 0.3670, 0.3388, 0.3371, 0.3683, 0.3582, 0.3542, 0.3527, 0.3517,
#             0.3432, 0.3405, 0.3392, 0.3376, 0.3367, 0.4071, 0.4060, 0.3965, 0.3874,
#             0.3811, 0.3733, 0.3718, 0.3674, 0.3656, 0.3631, 1.0000, 0.2174, 0.0000,
#             0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 1.0000, 1.0000,
#             0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 1.0000,
#             0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000,
#             1.0000, 0.0000, 0.0000, 0.0000, 1.0000, 1.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 1.0000, 1.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 1.0000,
#             0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             1.0000, 1.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000]]),
#    tensor([[0.8528, 0.8524, 0.8345, 0.8215, 0.8085, 0.7886, 0.7872, 0.7783, 0.7751,
#             0.7652, 0.6482, 0.6251, 0.6169, 0.5975, 0.5917, 0.5848, 0.5806, 0.5797,
#             0.5784, 0.5525, 0.6809, 0.6473, 0.6441, 0.6075, 0.5852, 0.5668, 0.5632,
#             0.5559, 0.5559, 0.5543, 0.4509, 0.4355, 0.4319, 0.4218, 0.4213, 0.3993,
#             0.3949, 0.3670, 0.3388, 0.3371, 0.3683, 0.3582, 0.3542, 0.3527, 0.3517,
#             0.3432, 0.3405, 0.3392, 0.3376, 0.3367, 0.4071, 0.4060, 0.3965, 0.3874,
#             0.3811, 0.3733, 0.3718, 0.3674, 0.3656, 0.3631, 2.0000, 1.0000, 0.0000,
#             1.0000, 1.0000, 1.0000, 0.0000, 0.0000, 1.0000, 0.0000, 1.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 1.0000, 1.0000,
#             0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 1.0000,
#             0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000,
#             1.0000, 0.0000, 0.0000, 0.0000, 1.0000, 1.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 1.0000, 1.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 1.0000,
#             0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             1.0000, 1.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000]]),
#    tensor([[0.8215, 0.8085, 0.7886, 0.7872, 0.7783, 0.7751, 0.7652, 0.7639, 0.7487,
#             0.7420, 0.6169, 0.5975, 0.5917, 0.5848, 0.5806, 0.5797, 0.5784, 0.5525,
#             0.5464, 0.5449, 0.6473, 0.6441, 0.6075, 0.5852, 0.5668, 0.5632, 0.5559,
#             0.5559, 0.5543, 0.5478, 0.3993, 0.3949, 0.3670, 0.3388, 0.3371, 0.3346,
#             0.3278, 0.3225, 0.2797, 0.2717, 0.3376, 0.3367, 0.3366, 0.3353, 0.3328,
#             0.3266, 0.3253, 0.3160, 0.3124, 0.3118, 0.3965, 0.3874, 0.3811, 0.3733,
#             0.3718, 0.3674, 0.3656, 0.3631, 0.3629, 0.3626, 3.0000, 0.2174, 0.0000,
#             1.0000, 1.0000, 1.0000, 0.0000, 0.0000, 1.0000, 0.0000, 1.0000, 0.0000,
#             0.0000, 1.0000, 0.0000, 1.0000, 0.0000, 1.0000, 1.0000, 1.0000, 1.0000,
#             1.0000, 2.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 2.0000,
#             1.0000, 0.0000, 1.0000, 1.0000, 0.0000, 0.0000, 2.0000, 0.0000, 1.0000,
#             1.0000, 0.0000, 0.0000, 1.0000, 1.0000, 2.0000, 0.0000, 0.0000, 0.0000,
#             1.0000, 1.0000, 1.0000, 0.0000, 0.0000, 2.0000, 1.0000, 0.0000, 1.0000,
#             0.0000, 0.0000, 1.0000, 2.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000,
#             1.0000, 2.0000, 1.0000, 1.0000, 0.0000, 0.0000, 1.0000, 1.0000]]),
#    tensor([[0.7886, 0.7872, 0.7783, 0.7751, 0.7652, 0.7639, 0.7487, 0.7420, 0.7368,
#             0.7367, 0.6169, 0.5975, 0.5917, 0.5848, 0.5806, 0.5797, 0.5784, 0.5525,
#             0.5464, 0.5449, 0.6473, 0.6441, 0.6075, 0.5852, 0.5668, 0.5632, 0.5559,
#             0.5559, 0.5543, 0.5478, 0.3949, 0.3670, 0.3388, 0.3371, 0.3346, 0.3278,
#             0.3225, 0.2797, 0.2717, 0.2675, 0.3376, 0.3367, 0.3366, 0.3353, 0.3328,
#             0.3266, 0.3253, 0.3160, 0.3124, 0.3118, 0.3965, 0.3874, 0.3811, 0.3733,
#             0.3718, 0.3674, 0.3656, 0.3631, 0.3629, 0.3626, 4.0000, 1.0000, 1.0000,
#             1.0000, 1.0000, 2.0000, 0.0000, 0.0000, 2.0000, 0.0000, 1.0000, 0.0000,
#             0.0000, 1.0000, 0.0000, 1.0000, 0.0000, 1.0000, 1.0000, 1.0000, 1.0000,
#             1.0000, 2.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 2.0000,
#             1.0000, 0.0000, 1.0000, 1.0000, 0.0000, 0.0000, 2.0000, 0.0000, 1.0000,
#             1.0000, 0.0000, 0.0000, 1.0000, 1.0000, 2.0000, 0.0000, 0.0000, 0.0000,
#             1.0000, 1.0000, 1.0000, 0.0000, 0.0000, 2.0000, 1.0000, 0.0000, 1.0000,
#             0.0000, 0.0000, 1.0000, 2.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000,
#             1.0000, 2.0000, 1.0000, 1.0000, 0.0000, 0.0000, 1.0000, 1.0000]]),
#    tensor([[0.7639, 0.7487, 0.7420, 0.7368, 0.7367, 0.7300, 0.7118, 0.6947, 0.6922,
#             0.6498, 0.5806, 0.5797, 0.5784, 0.5525, 0.5464, 0.5449, 0.5442, 0.4877,
#             0.4867, 0.4816, 0.5632, 0.5559, 0.5559, 0.5543, 0.5478, 0.5472, 0.5457,
#             0.5453, 0.5436, 0.5380, 0.3670, 0.3388, 0.3371, 0.3346, 0.3278, 0.3225,
#             0.2797, 0.2717, 0.2675, 0.2663, 0.3353, 0.3328, 0.3266, 0.3253, 0.3160,
#             0.3124, 0.3118, 0.3107, 0.3086, 0.3076, 0.3733, 0.3718, 0.3674, 0.3656,
#             0.3631, 0.3629, 0.3626, 0.3518, 0.3511, 0.3493, 5.0000, 0.2174, 1.0000,
#             1.0000, 1.0000, 2.0000, 0.0000, 0.0000, 2.0000, 0.0000, 2.0000, 0.0000,
#             0.0000, 1.0000, 0.0000, 3.0000, 0.0000, 1.0000, 1.0000, 1.0000, 1.0000,
#             1.0000, 3.0000, 0.0000, 0.0000, 1.0000, 2.0000, 0.0000, 1.0000, 2.0000,
#             1.0000, 0.0000, 1.0000, 2.0000, 0.0000, 0.0000, 3.0000, 0.0000, 1.0000,
#             1.0000, 2.0000, 0.0000, 1.0000, 1.0000, 3.0000, 0.0000, 1.0000, 0.0000,
#             1.0000, 1.0000, 2.0000, 0.0000, 0.0000, 3.0000, 1.0000, 0.0000, 1.0000,
#             0.0000, 0.0000, 1.0000, 3.0000, 1.0000, 0.0000, 1.0000, 0.0000, 1.0000,
#             1.0000, 3.0000, 2.0000, 1.0000, 0.0000, 0.0000, 2.0000, 1.0000]]),
#    tensor([[0.7639, 0.7487, 0.7420, 0.7368, 0.7367, 0.7300, 0.7118, 0.6947, 0.6922,
#             0.6498, 0.5797, 0.5784, 0.5525, 0.5464, 0.5449, 0.5442, 0.4877, 0.4867,
#             0.4816, 0.4805, 0.5559, 0.5559, 0.5543, 0.5478, 0.5472, 0.5457, 0.5453,
#             0.5436, 0.5380, 0.5293, 0.3670, 0.3388, 0.3371, 0.3346, 0.3278, 0.3225,
#             0.2797, 0.2717, 0.2675, 0.2663, 0.3328, 0.3266, 0.3253, 0.3160, 0.3124,
#             0.3118, 0.3107, 0.3086, 0.3076, 0.3070, 0.3733, 0.3718, 0.3674, 0.3656,
#             0.3631, 0.3629, 0.3626, 0.3518, 0.3511, 0.3493, 6.0000, 1.0000, 1.0000,
#             1.0000, 2.0000, 2.0000, 1.0000, 0.0000, 2.0000, 1.0000, 2.0000, 0.0000,
#             0.0000, 1.0000, 0.0000, 3.0000, 0.0000, 1.0000, 1.0000, 1.0000, 1.0000,
#             1.0000, 3.0000, 0.0000, 0.0000, 1.0000, 2.0000, 0.0000, 1.0000, 2.0000,
#             1.0000, 0.0000, 1.0000, 2.0000, 0.0000, 0.0000, 3.0000, 0.0000, 1.0000,
#             1.0000, 2.0000, 0.0000, 1.0000, 1.0000, 3.0000, 0.0000, 1.0000, 0.0000,
#             1.0000, 1.0000, 2.0000, 0.0000, 0.0000, 3.0000, 1.0000, 0.0000, 1.0000,
#             0.0000, 0.0000, 1.0000, 3.0000, 1.0000, 0.0000, 1.0000, 0.0000, 1.0000,
#             1.0000, 3.0000, 2.0000, 1.0000, 0.0000, 0.0000, 2.0000, 1.0000]]),
#    tensor([[0.7300, 0.7118, 0.6947, 0.6922, 0.6498, 0.6007, 0.5971, 0.5871, 0.5646,
#             0.4374, 0.5525, 0.5464, 0.5449, 0.5442, 0.4877, 0.4867, 0.4816, 0.4805,
#             0.4788, 0.4702, 0.5472, 0.5457, 0.5453, 0.5436, 0.5380, 0.5293, 0.5290,
#             0.5281, 0.5266, 0.5182, 0.3388, 0.3371, 0.3346, 0.3278, 0.3225, 0.2797,
#             0.2717, 0.2675, 0.2663, 0.2575, 0.3124, 0.3118, 0.3107, 0.3086, 0.3076,
#             0.3070, 0.3055, 0.2951, 0.2861, 0.2745, 0.3629, 0.3626, 0.3518, 0.3511,
#             0.3493, 0.3472, 0.3462, 0.3426, 0.3387, 0.3379, 7.0000, 0.2174, 1.0000,
#             1.0000, 2.0000, 2.0000, 1.0000, 0.0000, 3.0000, 1.0000, 2.0000, 0.0000,
#             0.0000, 1.0000, 0.0000, 3.0000, 1.0000, 1.0000, 1.0000, 2.0000, 1.0000,
#             1.0000, 5.0000, 0.0000, 0.0000, 1.0000, 3.0000, 0.0000, 1.0000, 2.0000,
#             2.0000, 0.0000, 2.0000, 2.0000, 0.0000, 0.0000, 4.0000, 0.0000, 1.0000,
#             1.0000, 3.0000, 0.0000, 1.0000, 2.0000, 3.0000, 0.0000, 1.0000, 0.0000,
#             1.0000, 3.0000, 3.0000, 0.0000, 0.0000, 4.0000, 1.0000, 0.0000, 2.0000,
#             1.0000, 0.0000, 1.0000, 3.0000, 1.0000, 0.0000, 1.0000, 0.0000, 1.0000,
#             2.0000, 4.0000, 2.0000, 2.0000, 0.0000, 0.0000, 3.0000, 1.0000]]),
#    tensor([[0.7118, 0.6947, 0.6922, 0.6498, 0.6007, 0.5971, 0.5871, 0.5646, 0.4374,
#             0.3729, 0.5525, 0.5464, 0.5449, 0.5442, 0.4877, 0.4867, 0.4816, 0.4805,
#             0.4788, 0.4702, 0.5472, 0.5457, 0.5453, 0.5436, 0.5380, 0.5293, 0.5290,
#             0.5281, 0.5266, 0.5182, 0.3346, 0.3278, 0.3225, 0.2797, 0.2717, 0.2675,
#             0.2663, 0.2575, 0.2525, 0.2392, 0.3124, 0.3118, 0.3107, 0.3086, 0.3076,
#             0.3070, 0.3055, 0.2951, 0.2861, 0.2745, 0.3629, 0.3626, 0.3518, 0.3511,
#             0.3493, 0.3472, 0.3462, 0.3426, 0.3387, 0.3379, 8.0000, 1.0000, 2.0000,
#             1.0000, 2.0000, 3.0000, 1.0000, 0.0000, 3.0000, 1.0000, 2.0000, 1.0000,
#             0.0000, 1.0000, 0.0000, 3.0000, 1.0000, 1.0000, 1.0000, 2.0000, 1.0000,
#             1.0000, 5.0000, 0.0000, 0.0000, 1.0000, 3.0000, 0.0000, 1.0000, 2.0000,
#             2.0000, 0.0000, 2.0000, 2.0000, 0.0000, 0.0000, 4.0000, 0.0000, 1.0000,
#             1.0000, 3.0000, 0.0000, 1.0000, 2.0000, 3.0000, 0.0000, 1.0000, 0.0000,
#             1.0000, 3.0000, 3.0000, 0.0000, 0.0000, 4.0000, 1.0000, 0.0000, 2.0000,
#             1.0000, 0.0000, 1.0000, 3.0000, 1.0000, 0.0000, 1.0000, 0.0000, 1.0000,
#             2.0000, 4.0000, 2.0000, 2.0000, 0.0000, 0.0000, 3.0000, 1.0000]]),
#    tensor([[0.6007, 0.5971, 0.5871, 0.5646, 0.4374, 0.3729, 0.2772, 0.2170, 0.2137,
#             0.2066, 0.5464, 0.5449, 0.5442, 0.4877, 0.4867, 0.4816, 0.4805, 0.4788,
#             0.4702, 0.4694, 0.5380, 0.5293, 0.5290, 0.5281, 0.5266, 0.5182, 0.5126,
#             0.5090, 0.4976, 0.4963, 0.2797, 0.2717, 0.2675, 0.2663, 0.2575, 0.2525,
#             0.2392, 0.2297, 0.2209, 0.2114, 0.3070, 0.3055, 0.2951, 0.2861, 0.2745,
#             0.2475, 0.2232, 0.2145, 0.2091, 0.2075, 0.3493, 0.3472, 0.3462, 0.3426,
#             0.3387, 0.3379, 0.3311, 0.3299, 0.3266, 0.3257, 9.0000, 0.2174, 2.0000,
#             1.0000, 2.0000, 3.0000, 1.0000, 0.0000, 3.0000, 1.0000, 3.0000, 1.0000,
#             0.0000, 1.0000, 0.0000, 3.0000, 2.0000, 1.0000, 1.0000, 2.0000, 2.0000,
#             1.0000, 6.0000, 0.0000, 0.0000, 1.0000, 4.0000, 0.0000, 1.0000, 2.0000,
#             3.0000, 0.0000, 2.0000, 2.0000, 0.0000, 0.0000, 5.0000, 1.0000, 1.0000,
#             1.0000, 3.0000, 1.0000, 1.0000, 3.0000, 3.0000, 0.0000, 1.0000, 0.0000,
#             2.0000, 4.0000, 3.0000, 0.0000, 0.0000, 5.0000, 1.0000, 1.0000, 3.0000,
#             1.0000, 0.0000, 1.0000, 4.0000, 1.0000, 0.0000, 1.0000, 1.0000, 2.0000,
#             2.0000, 4.0000, 3.0000, 2.0000, 0.0000, 0.0000, 4.0000, 1.0000]]),
#    tensor([[ 0.5971,  0.5871,  0.5646,  0.4374,  0.3729,  0.2772,  0.2170,  0.2137,
#              0.2066,  0.1015,  0.5464,  0.5449,  0.5442,  0.4877,  0.4867,  0.4816,
#              0.4805,  0.4788,  0.4702,  0.4694,  0.5293,  0.5290,  0.5281,  0.5266,
#              0.5182,  0.5126,  0.5090,  0.4976,  0.4963,  0.4918,  0.2717,  0.2675,
#              0.2663,  0.2575,  0.2525,  0.2392,  0.2297,  0.2209,  0.2114,  0.1907,
#              0.3070,  0.3055,  0.2951,  0.2861,  0.2745,  0.2475,  0.2232,  0.2145,
#              0.2091,  0.2075,  0.3493,  0.3472,  0.3462,  0.3426,  0.3387,  0.3379,
#              0.3311,  0.3299,  0.3266,  0.3257, 10.0000,  1.0000,  3.0000,  1.0000,
#              2.0000,  4.0000,  1.0000,  0.0000,  3.0000,  1.0000,  4.0000,  1.0000,
#              0.0000,  1.0000,  0.0000,  3.0000,  2.0000,  1.0000,  1.0000,  2.0000,
#              2.0000,  1.0000,  6.0000,  0.0000,  0.0000,  1.0000,  4.0000,  0.0000,
#              1.0000,  2.0000,  3.0000,  0.0000,  2.0000,  2.0000,  0.0000,  0.0000,
#              5.0000,  1.0000,  1.0000,  1.0000,  3.0000,  1.0000,  1.0000,  3.0000,
#              3.0000,  0.0000,  1.0000,  0.0000,  2.0000,  4.0000,  3.0000,  0.0000,
#              0.0000,  5.0000,  1.0000,  1.0000,  3.0000,  1.0000,  0.0000,  1.0000,
#              4.0000,  1.0000,  0.0000,  1.0000,  1.0000,  2.0000,  2.0000,  4.0000,
#              3.0000,  2.0000,  0.0000,  0.0000,  4.0000,  1.0000]]),
#    tensor([[ 0.3729,  0.2772,  0.2170,  0.2137,  0.2066,  0.1015,  0.0915,  0.0864,
#              0.0781,  0.0739,  0.5464,  0.5449,  0.5442,  0.4877,  0.4867,  0.4816,
#              0.4805,  0.4788,  0.4702,  0.4694,  0.5182,  0.5126,  0.5090,  0.4976,
#              0.4963,  0.4918,  0.4851,  0.4800,  0.4790,  0.4692,  0.2525,  0.2392,
#              0.2297,  0.2209,  0.2114,  0.1907,  0.1884,  0.1869,  0.1834,  0.1828,
#              0.2475,  0.2232,  0.2145,  0.2091,  0.2075,  0.2016,  0.1957,  0.1422,
#              0.1157,  0.0947,  0.3387,  0.3379,  0.3311,  0.3299,  0.3266,  0.3257,
#              0.3097,  0.2999,  0.2968,  0.0000, 11.0000,  0.2174,  3.0000,  1.0000,
#              2.0000,  4.0000,  1.0000,  0.0000,  3.0000,  1.0000,  4.0000,  2.0000,
#              0.0000,  1.0000,  0.0000,  3.0000,  2.0000,  1.0000,  1.0000,  3.0000,
#              2.0000,  1.0000,  8.0000,  0.0000,  0.0000,  1.0000,  5.0000,  0.0000,
#              1.0000,  2.0000,  4.0000,  0.0000,  2.0000,  2.0000,  0.0000,  0.0000,
#              7.0000,  1.0000,  1.0000,  1.0000,  4.0000,  1.0000,  1.0000,  4.0000,
#              4.0000,  0.0000,  1.0000,  1.0000,  2.0000,  4.0000,  3.0000,  0.0000,
#              0.0000,  6.0000,  2.0000,  1.0000,  4.0000,  1.0000,  0.0000,  2.0000,
#              4.0000,  1.0000,  0.0000,  1.0000,  1.0000,  2.0000,  3.0000,  5.0000,
#              4.0000,  2.0000,  0.0000,  0.0000,  4.0000,  2.0000]]),
#    tensor([[ 0.2772,  0.2170,  0.2137,  0.2066,  0.1015,  0.0915,  0.0864,  0.0781,
#              0.0739,  0.0707,  0.5464,  0.5449,  0.5442,  0.4877,  0.4867,  0.4816,
#              0.4805,  0.4788,  0.4702,  0.4694,  0.5090,  0.4976,  0.4963,  0.4918,
#              0.4851,  0.4800,  0.4790,  0.4692,  0.4621,  0.4606,  0.2525,  0.2392,
#              0.2297,  0.2209,  0.2114,  0.1907,  0.1884,  0.1869,  0.1834,  0.1828,
#              0.2475,  0.2232,  0.2145,  0.2091,  0.2075,  0.2016,  0.1957,  0.1422,
#              0.1157,  0.0947,  0.3387,  0.3379,  0.3311,  0.3299,  0.3266,  0.3257,
#              0.3097,  0.2999,  0.2968,  0.0000, 12.0000,  1.0000,  4.0000,  1.0000,
#              3.0000,  4.0000,  1.0000,  0.0000,  3.0000,  1.0000,  5.0000,  2.0000,
#              0.0000,  1.0000,  0.0000,  3.0000,  2.0000,  1.0000,  1.0000,  3.0000,
#              2.0000,  1.0000,  8.0000,  0.0000,  0.0000,  1.0000,  5.0000,  0.0000,
#              1.0000,  2.0000,  4.0000,  0.0000,  2.0000,  2.0000,  0.0000,  0.0000,
#              7.0000,  1.0000,  1.0000,  1.0000,  4.0000,  1.0000,  1.0000,  4.0000,
#              4.0000,  0.0000,  1.0000,  1.0000,  2.0000,  4.0000,  3.0000,  0.0000,
#              0.0000,  6.0000,  2.0000,  1.0000,  4.0000,  1.0000,  0.0000,  2.0000,
#              4.0000,  1.0000,  0.0000,  1.0000,  1.0000,  2.0000,  3.0000,  5.0000,
#              4.0000,  2.0000,  0.0000,  0.0000,  4.0000,  2.0000]]),
#    tensor([[ 0.0864,  0.0781,  0.0739,  0.0707,  0.0678,  0.0658,  0.0657,  0.0632,
#              0.0592,  0.0568,  0.5449,  0.5442,  0.4877,  0.4867,  0.4816,  0.4805,
#              0.4788,  0.4702,  0.4694,  0.4509,  0.4851,  0.4800,  0.4790,  0.4692,
#              0.4621,  0.4606,  0.4578,  0.4570,  0.4410,  0.4353,  0.2392,  0.2297,
#              0.2209,  0.2114,  0.1907,  0.1884,  0.1869,  0.1834,  0.1828,  0.1826,
#              0.2091,  0.2075,  0.2016,  0.1957,  0.1422,  0.1157,  0.0947,  0.0707,
#              0.0517,  0.0454,  0.3097,  0.2999,  0.2968,  0.0000,  0.0000,  0.0000,
#              0.0000,  0.0000,  0.0000,  0.0000, 13.0000,  0.2174,  4.0000,  1.0000,
#              3.0000,  4.0000,  1.0000,  0.0000,  4.0000,  1.0000,  5.0000,  2.0000,
#              0.0000,  1.0000,  0.0000,  3.0000,  2.0000,  1.0000,  1.0000,  4.0000,
#              2.0000,  1.0000, 10.0000,  0.0000,  0.0000,  1.0000,  6.0000,  0.0000,
#              1.0000,  2.0000,  5.0000,  0.0000,  2.0000,  2.0000,  0.0000,  0.0000,
#              9.0000,  1.0000,  1.0000,  2.0000,  4.0000,  2.0000,  1.0000,  4.0000,
#              5.0000,  0.0000,  1.0000,  1.0000,  2.0000,  5.0000,  3.0000,  0.0000,
#              0.0000,  6.0000,  2.0000,  3.0000,  5.0000,  1.0000,  1.0000,  2.0000,
#              4.0000,  1.0000,  0.0000,  1.0000,  1.0000,  2.0000,  3.0000,  7.0000,
#              6.0000,  2.0000,  0.0000,  0.0000,  4.0000,  2.0000]]),
#    tensor([[ 0.0781,  0.0739,  0.0707,  0.0678,  0.0658,  0.0657,  0.0632,  0.0592,
#              0.0568,  0.0567,  0.5449,  0.5442,  0.4877,  0.4867,  0.4816,  0.4805,
#              0.4788,  0.4702,  0.4694,  0.4509,  0.4790,  0.4692,  0.4621,  0.4606,
#              0.4578,  0.4570,  0.4410,  0.4353,  0.3888,  0.3867,  0.2392,  0.2297,
#              0.2209,  0.2114,  0.1907,  0.1884,  0.1869,  0.1834,  0.1828,  0.1826,
#              0.2091,  0.2075,  0.2016,  0.1957,  0.1422,  0.1157,  0.0947,  0.0707,
#              0.0517,  0.0454,  0.3097,  0.2999,  0.2968,  0.0000,  0.0000,  0.0000,
#              0.0000,  0.0000,  0.0000,  0.0000, 14.0000,  0.0000,  5.0000,  1.0000,
#              4.0000,  4.0000,  1.0000,  0.0000,  4.0000,  1.0000,  6.0000,  2.0000,
#              0.0000,  1.0000,  0.0000,  3.0000,  2.0000,  1.0000,  1.0000,  4.0000,
#              2.0000,  1.0000, 10.0000,  0.0000,  0.0000,  1.0000,  6.0000,  0.0000,
#              1.0000,  2.0000,  5.0000,  0.0000,  2.0000,  2.0000,  0.0000,  0.0000,
#              9.0000,  1.0000,  1.0000,  2.0000,  4.0000,  2.0000,  1.0000,  4.0000,
#              5.0000,  0.0000,  1.0000,  1.0000,  2.0000,  5.0000,  3.0000,  0.0000,
#              0.0000,  6.0000,  2.0000,  3.0000,  5.0000,  1.0000,  1.0000,  2.0000,
#              4.0000,  1.0000,  0.0000,  1.0000,  1.0000,  2.0000,  3.0000,  7.0000,
#              6.0000,  2.0000,  0.0000,  0.0000,  4.0000,  2.0000]])],
#   'actions': [0, 2, 5, 0, 2, 1, 0, 3, 2, 2, 3, 2, 0, 2, 2],
#   'rewards': [np.float64(0.06666666666666667),
#    np.float64(0.11343563207607475),
#    np.float64(0.14057691235881892),
#    np.float64(0.15426806702578158),
#    np.float64(0.19742229055871297),
#    np.float64(0.23613104080816052),
#    np.float64(0.248862037174697),
#    np.float64(0.2714510973185428),
#    np.float64(0.280570625795216),
#    np.float64(0.2895379579060927),
#    np.float64(0.2940660377617862),
#    np.float64(0.3027027530975407),
#    np.float64(0.3073233199526622),
#    np.float64(0.31540874084105075),
#    np.float64(0.32339245263328925)],
#   'log_probs': [tensor(-1.8268, grad_fn=<LogBackward0>),
#    tensor(-1.5684, grad_fn=<LogBackward0>),
#    tensor(-1.5219, grad_fn=<LogBackward0>),
#    tensor(-1.8243, grad_fn=<LogBackward0>),
#    tensor(-1.5183, grad_fn=<LogBackward0>),
#    tensor(-1.8971, grad_fn=<LogBackward0>),
#    tensor(-1.7901, grad_fn=<LogBackward0>),
#    tensor(-2.4000, grad_fn=<LogBackward0>),
#    tensor(-1.0533, grad_fn=<LogBackward0>),
#    tensor(-0.9966, grad_fn=<LogBackward0>),
#    tensor(-2.6654, grad_fn=<LogBackward0>),
#    tensor(-1.0161, grad_fn=<LogBackward0>),
#    tensor(-1.8560, grad_fn=<LogBackward0>),
#    tensor(-0.8936, grad_fn=<LogBackward0>),
#    tensor(-0.7871, grad_fn=<LogBackward0>)]},
#  2: {'states': [tensor([[0.9844, 0.9274, 0.9037, 0.8586, 0.8530, 0.8528, 0.8524, 0.8345, 0.8215,
#             0.8085, 0.8625, 0.7142, 0.6961, 0.6692, 0.6482, 0.6251, 0.6169, 0.5975,
#             0.5917, 0.5848, 0.7805, 0.7493, 0.7015, 0.6882, 0.6809, 0.6473, 0.6441,
#             0.6075, 0.5852, 0.5668, 0.5098, 0.4764, 0.4509, 0.4355, 0.4319, 0.4218,
#             0.4213, 0.3993, 0.3949, 0.3670, 0.3752, 0.3704, 0.3684, 0.3683, 0.3582,
#             0.3542, 0.3527, 0.3517, 0.3432, 0.3405, 0.4764, 0.4286, 0.4237, 0.4155,
#             0.4106, 0.4071, 0.4060, 0.3965, 0.3874, 0.3811, 0.0000, 0.9130, 0.0000,
#             0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000]]),
#    tensor([[0.8528, 0.8524, 0.8345, 0.8215, 0.8085, 0.7886, 0.7872, 0.7783, 0.7751,
#             0.7652, 0.6692, 0.6482, 0.6251, 0.6169, 0.5975, 0.5917, 0.5848, 0.5806,
#             0.5797, 0.5784, 0.7015, 0.6882, 0.6809, 0.6473, 0.6441, 0.6075, 0.5852,
#             0.5668, 0.5632, 0.5559, 0.4509, 0.4355, 0.4319, 0.4218, 0.4213, 0.3993,
#             0.3949, 0.3670, 0.3388, 0.3371, 0.3683, 0.3582, 0.3542, 0.3527, 0.3517,
#             0.3432, 0.3405, 0.3392, 0.3376, 0.3367, 0.4106, 0.4071, 0.4060, 0.3965,
#             0.3874, 0.3811, 0.3733, 0.3718, 0.3674, 0.3656, 1.0000, 0.3043, 0.0000,
#             0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000,
#             0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 1.0000,
#             0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000,
#             1.0000, 0.0000, 0.0000, 0.0000, 1.0000, 1.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 1.0000, 1.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 1.0000,
#             0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             1.0000, 1.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000]]),
#    tensor([[0.8528, 0.8524, 0.8345, 0.8215, 0.8085, 0.7886, 0.7872, 0.7783, 0.7751,
#             0.7652, 0.6482, 0.6251, 0.6169, 0.5975, 0.5917, 0.5848, 0.5806, 0.5797,
#             0.5784, 0.5525, 0.6809, 0.6473, 0.6441, 0.6075, 0.5852, 0.5668, 0.5632,
#             0.5559, 0.5559, 0.5543, 0.4509, 0.4355, 0.4319, 0.4218, 0.4213, 0.3993,
#             0.3949, 0.3670, 0.3388, 0.3371, 0.3683, 0.3582, 0.3542, 0.3527, 0.3517,
#             0.3432, 0.3405, 0.3392, 0.3376, 0.3367, 0.4060, 0.3965, 0.3874, 0.3811,
#             0.3733, 0.3718, 0.3674, 0.3656, 0.3631, 0.3629, 2.0000, 0.9130, 0.0000,
#             1.0000, 1.0000, 1.0000, 0.0000, 0.0000, 1.0000, 0.0000, 1.0000, 0.0000,
#             0.0000, 1.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 1.0000, 1.0000,
#             0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 1.0000,
#             0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000,
#             1.0000, 0.0000, 0.0000, 0.0000, 1.0000, 1.0000, 0.0000, 0.0000, 0.0000,
#             0.0000, 1.0000, 1.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 1.0000,
#             0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#             1.0000, 1.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000]]),
#    tensor([[0.8215, 0.8085, 0.7886, 0.7872, 0.7783, 0.7751, 0.7652, 0.7639, 0.7487,
#             0.7420, 0.6169, 0.5975, 0.5917, 0.5848, 0.5806, 0.5797, 0.5784, 0.5525,
#             0.5464, 0.5449, 0.6473, 0.6441, 0.6075, 0.5852, 0.5668, 0.5632, 0.5559,
#             0.5559, 0.5543, 0.5478, 0.3993, 0.3949, 0.3670, 0.3388, 0.3371, 0.3346,
#             0.3278, 0.3225, 0.2797, 0.2717, 0.3392, 0.3376, 0.3367, 0.3366, 0.3353,
#             0.3328, 0.3266, 0.3253, 0.3160, 0.3124, 0.3965, 0.3874, 0.3811, 0.3733,
#             0.3718, 0.3674, 0.3656, 0.3631, 0.3629, 0.3626, 3.0000, 0.3043, 0.0000,
#             1.0000, 1.0000, 1.0000, 0.0000, 0.0000, 1.0000, 0.0000, 1.0000, 0.0000,
#             0.0000, 1.0000, 0.0000, 1.0000, 0.0000, 1.0000, 0.0000, 1.0000, 1.0000,
#             1.0000, 2.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 2.0000,
#             1.0000, 0.0000, 1.0000, 1.0000, 0.0000, 0.0000, 2.0000, 0.0000, 1.0000,
#             1.0000, 0.0000, 0.0000, 1.0000, 1.0000, 2.0000, 0.0000, 0.0000, 0.0000,
#             1.0000, 1.0000, 1.0000, 0.0000, 0.0000, 2.0000, 1.0000, 0.0000, 1.0000,
#             0.0000, 0.0000, 1.0000, 2.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000,
#             1.0000, 2.0000, 1.0000, 1.0000, 0.0000, 0.0000, 1.0000, 1.0000]]),
#    tensor([[0.7886, 0.7872, 0.7783, 0.7751, 0.7652, 0.7639, 0.7487, 0.7420, 0.7368,
#             0.7367, 0.6169, 0.5975, 0.5917, 0.5848, 0.5806, 0.5797, 0.5784, 0.5525,
#             0.5464, 0.5449, 0.6441, 0.6075, 0.5852, 0.5668, 0.5632, 0.5559, 0.5559,
#             0.5543, 0.5478, 0.5472, 0.3949, 0.3670, 0.3388, 0.3371, 0.3346, 0.3278,
#             0.3225, 0.2797, 0.2717, 0.2675, 0.3376, 0.3367, 0.3366, 0.3353, 0.3328,
#             0.3266, 0.3253, 0.3160, 0.3124, 0.3118, 0.3965, 0.3874, 0.3811, 0.3733,
#             0.3718, 0.3674, 0.3656, 0.3631, 0.3629, 0.3626, 4.0000, 0.9130, 1.0000,
#             1.0000, 1.0000, 2.0000, 0.0000, 0.0000, 2.0000, 0.0000, 2.0000, 0.0000,
#             0.0000, 1.0000, 0.0000, 1.0000, 0.0000, 1.0000, 1.0000, 1.0000, 1.0000,
#             1.0000, 2.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 2.0000,
#             1.0000, 0.0000, 1.0000, 1.0000, 0.0000, 0.0000, 2.0000, 0.0000, 1.0000,
#             1.0000, 0.0000, 0.0000, 1.0000, 1.0000, 2.0000, 0.0000, 0.0000, 0.0000,
#             1.0000, 1.0000, 1.0000, 0.0000, 0.0000, 2.0000, 1.0000, 0.0000, 1.0000,
#             0.0000, 0.0000, 1.0000, 2.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000,
#             1.0000, 2.0000, 1.0000, 1.0000, 0.0000, 0.0000, 1.0000, 1.0000]]),
# ...
#             1.0000, 1.0000, 1.0000, 0.0000, 0.0000, 0.0000, 1.0000, 1.0000]]),
#    tensor([[0.7783, 0.7751, 0.7652, 0.7639, 0.7487, 0.7420, 0.7368, 0.7367, 0.7300,
#             0.7118, 0.5917, 0.5848, 0.5806, 0.5797, 0.5784, 0.5525, 0.5464, 0.5449,
#             0.5442, 0.4877, 0.6075, 0.5852, 0.5668, 0.5632, 0.5559, 0.5559, 0.5543,
#             0.5478, 0.5472, 0.5457, 0.3670, 0.3388, 0.3371, 0.3346, 0.3278, 0.3225,
#             0.2797, 0.2717, 0.2675, 0.2663, 0.3367, 0.3366, 0.3353, 0.3328, 0.3266,
#             0.3253, 0.3160, 0.3124, 0.3118, 0.3107, 0.3811, 0.3733, 0.3718, 0.3674,
#             0.3656, 0.3631, 0.3629, 0.3626, 0.3518, 0.3511, 4.0000, 0.1304, 1.0000,
#             1.0000, 1.0000, 2.0000, 0.0000, 0.0000, 2.0000, 0.0000, 2.0000, 0.0000,
#             0.0000, 1.0000, 0.0000, 2.0000, 0.0000, 1.0000, 1.0000, 1.0000, 1.0000,
#             1.0000, 2.0000, 0.0000, 0.0000, 1.0000, 1.0000, 0.0000, 1.0000, 2.0000,
#             1.0000, 0.0000, 1.0000, 2.0000, 0.0000, 0.0000, 2.0000, 0.0000, 1.0000,
#             1.0000, 1.0000, 0.0000, 1.0000, 1.0000, 3.0000, 0.0000, 0.0000, 0.0000,
#             1.0000, 1.0000, 1.0000, 0.0000, 0.0000, 3.0000, 1.0000, 0.0000, 1.0000,
#             0.0000, 0.0000, 1.0000, 3.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000,
#             1.0000, 3.0000, 1.0000, 1.0000, 0.0000, 0.0000, 1.0000, 1.0000]]),
#    tensor([[0.7783, 0.7751, 0.7652, 0.7639, 0.7487, 0.7420, 0.7368, 0.7367, 0.7300,
#             0.7118, 0.5917, 0.5848, 0.5806, 0.5797, 0.5784, 0.5525, 0.5464, 0.5449,
#             0.5442, 0.4877, 0.6075, 0.5852, 0.5668, 0.5632, 0.5559, 0.5559, 0.5543,
#             0.5478, 0.5472, 0.5457, 0.3670, 0.3388, 0.3371, 0.3346, 0.3278, 0.3225,
#             0.2797, 0.2717, 0.2675, 0.2663, 0.3366, 0.3353, 0.3328, 0.3266, 0.3253,
#             0.3160, 0.3124, 0.3118, 0.3107, 0.3086, 0.3811, 0.3733, 0.3718, 0.3674,
#             0.3656, 0.3631, 0.3629, 0.3626, 0.3518, 0.3511, 4.0000, 0.0435, 1.0000,
#             1.0000, 1.0000, 2.0000, 0.0000, 0.0000, 2.0000, 0.0000, 2.0000, 0.0000,
#             0.0000, 1.0000, 0.0000, 2.0000, 0.0000, 1.0000, 1.0000, 1.0000, 1.0000,
#             1.0000, 2.0000, 0.0000, 0.0000, 1.0000, 1.0000, 0.0000, 1.0000, 2.0000,
#             1.0000, 0.0000, 1.0000, 2.0000, 0.0000, 0.0000, 2.0000, 0.0000, 1.0000,
#             1.0000, 1.0000, 0.0000, 1.0000, 1.0000, 3.0000, 0.0000, 0.0000, 0.0000,
#             1.0000, 1.0000, 1.0000, 0.0000, 0.0000, 3.0000, 1.0000, 0.0000, 1.0000,
#             0.0000, 0.0000, 1.0000, 3.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000,
#             1.0000, 3.0000, 1.0000, 1.0000, 0.0000, 0.0000, 2.0000, 1.0000]]),
#    tensor([[0.7368, 0.7367, 0.7300, 0.7118, 0.6947, 0.6922, 0.6498, 0.6007, 0.5971,
#             0.5871, 0.5797, 0.5784, 0.5525, 0.5464, 0.5449, 0.5442, 0.4877, 0.4867,
#             0.4816, 0.4805, 0.5543, 0.5478, 0.5472, 0.5457, 0.5453, 0.5436, 0.5380,
#             0.5293, 0.5290, 0.5281, 0.3670, 0.3388, 0.3371, 0.3346, 0.3278, 0.3225,
#             0.2797, 0.2717, 0.2675, 0.2663, 0.3160, 0.3124, 0.3118, 0.3107, 0.3086,
#             0.3076, 0.3070, 0.3055, 0.2951, 0.2861, 0.3674, 0.3656, 0.3631, 0.3629,
#             0.3626, 0.3518, 0.3511, 0.3493, 0.3472, 0.3462, 6.0000, 0.1304, 1.0000,
#             1.0000, 2.0000, 2.0000, 1.0000, 0.0000, 3.0000, 1.0000, 2.0000, 0.0000,
#             0.0000, 1.0000, 0.0000, 3.0000, 0.0000, 1.0000, 1.0000, 2.0000, 1.0000,
#             1.0000, 4.0000, 0.0000, 0.0000, 1.0000, 2.0000, 0.0000, 1.0000, 2.0000,
#             2.0000, 0.0000, 1.0000, 2.0000, 0.0000, 0.0000, 4.0000, 0.0000, 1.0000,
#             1.0000, 3.0000, 0.0000, 1.0000, 1.0000, 3.0000, 0.0000, 1.0000, 0.0000,
#             1.0000, 2.0000, 3.0000, 0.0000, 0.0000, 3.0000, 1.0000, 0.0000, 2.0000,
#             0.0000, 0.0000, 1.0000, 3.0000, 1.0000, 0.0000, 1.0000, 0.0000, 1.0000,
#             2.0000, 3.0000, 2.0000, 1.0000, 0.0000, 0.0000, 2.0000, 1.0000]]),
#    tensor([[0.7368, 0.7367, 0.7300, 0.7118, 0.6947, 0.6922, 0.6498, 0.6007, 0.5971,
#             0.5871, 0.5797, 0.5784, 0.5525, 0.5464, 0.5449, 0.5442, 0.4877, 0.4867,
#             0.4816, 0.4805, 0.5543, 0.5478, 0.5472, 0.5457, 0.5453, 0.5436, 0.5380,
#             0.5293, 0.5290, 0.5281, 0.3670, 0.3388, 0.3371, 0.3346, 0.3278, 0.3225,
#             0.2797, 0.2717, 0.2675, 0.2663, 0.3124, 0.3118, 0.3107, 0.3086, 0.3076,
#             0.3070, 0.3055, 0.2951, 0.2861, 0.2745, 0.3674, 0.3656, 0.3631, 0.3629,
#             0.3626, 0.3518, 0.3511, 0.3493, 0.3472, 0.3462, 6.0000, 0.0435, 1.0000,
#             1.0000, 2.0000, 2.0000, 1.0000, 0.0000, 3.0000, 1.0000, 2.0000, 0.0000,
#             0.0000, 1.0000, 0.0000, 3.0000, 0.0000, 1.0000, 1.0000, 2.0000, 1.0000,
#             1.0000, 4.0000, 0.0000, 0.0000, 1.0000, 2.0000, 0.0000, 1.0000, 2.0000,
#             2.0000, 0.0000, 1.0000, 2.0000, 0.0000, 0.0000, 4.0000, 0.0000, 1.0000,
#             1.0000, 3.0000, 0.0000, 1.0000, 1.0000, 3.0000, 0.0000, 1.0000, 0.0000,
#             1.0000, 2.0000, 3.0000, 0.0000, 0.0000, 3.0000, 1.0000, 0.0000, 2.0000,
#             0.0000, 0.0000, 1.0000, 3.0000, 1.0000, 0.0000, 1.0000, 0.0000, 1.0000,
#             2.0000, 3.0000, 2.0000, 1.0000, 0.0000, 0.0000, 3.0000, 1.0000]]),
#    tensor([[0.6922, 0.6498, 0.6007, 0.5971, 0.5871, 0.5646, 0.4374, 0.3729, 0.2772,
#             0.2170, 0.5525, 0.5464, 0.5449, 0.5442, 0.4877, 0.4867, 0.4816, 0.4805,
#             0.4788, 0.4702, 0.5436, 0.5380, 0.5293, 0.5290, 0.5281, 0.5266, 0.5182,
#             0.5126, 0.5090, 0.4976, 0.3278, 0.3225, 0.2797, 0.2717, 0.2675, 0.2663,
#             0.2575, 0.2525, 0.2392, 0.2297, 0.3107, 0.3086, 0.3076, 0.3070, 0.3055,
#             0.2951, 0.2861, 0.2745, 0.2475, 0.2232, 0.3518, 0.3511, 0.3493, 0.3472,
#             0.3462, 0.3426, 0.3387, 0.3379, 0.3311, 0.3299, 8.0000, 0.1304, 2.0000,
#             1.0000, 2.0000, 3.0000, 1.0000, 0.0000, 3.0000, 1.0000, 3.0000, 1.0000,
#             0.0000, 1.0000, 0.0000, 3.0000, 2.0000, 1.0000, 1.0000, 2.0000, 2.0000,
#             1.0000, 5.0000, 0.0000, 0.0000, 1.0000, 3.0000, 0.0000, 1.0000, 2.0000,
#             3.0000, 0.0000, 2.0000, 2.0000, 0.0000, 0.0000, 4.0000, 1.0000, 1.0000,
#             1.0000, 3.0000, 0.0000, 1.0000, 3.0000, 3.0000, 0.0000, 1.0000, 0.0000,
#             2.0000, 3.0000, 3.0000, 0.0000, 0.0000, 5.0000, 1.0000, 0.0000, 3.0000,
#             1.0000, 0.0000, 1.0000, 3.0000, 1.0000, 0.0000, 1.0000, 1.0000, 1.0000,
#             2.0000, 4.0000, 2.0000, 2.0000, 0.0000, 0.0000, 3.0000, 1.0000]]),
#    tensor([[0.6498, 0.6007, 0.5971, 0.5871, 0.5646, 0.4374, 0.3729, 0.2772, 0.2170,
#             0.2137, 0.5525, 0.5464, 0.5449, 0.5442, 0.4877, 0.4867, 0.4816, 0.4805,
#             0.4788, 0.4702, 0.5436, 0.5380, 0.5293, 0.5290, 0.5281, 0.5266, 0.5182,
#             0.5126, 0.5090, 0.4976, 0.3278, 0.3225, 0.2797, 0.2717, 0.2675, 0.2663,
#             0.2575, 0.2525, 0.2392, 0.2297, 0.3107, 0.3086, 0.3076, 0.3070, 0.3055,
#             0.2951, 0.2861, 0.2745, 0.2475, 0.2232, 0.3518, 0.3511, 0.3493, 0.3472,
#             0.3462, 0.3426, 0.3387, 0.3379, 0.3311, 0.3299, 8.0000, 0.0435, 2.0000,
#             1.0000, 2.0000, 3.0000, 1.0000, 0.0000, 3.0000, 1.0000, 3.0000, 1.0000,
#             0.0000, 1.0000, 0.0000, 3.0000, 2.0000, 1.0000, 1.0000, 2.0000, 2.0000,
#             1.0000, 5.0000, 0.0000, 0.0000, 1.0000, 3.0000, 0.0000, 1.0000, 2.0000,
#             3.0000, 0.0000, 2.0000, 2.0000, 0.0000, 0.0000, 4.0000, 1.0000, 1.0000,
#             1.0000, 3.0000, 0.0000, 1.0000, 3.0000, 3.0000, 0.0000, 1.0000, 0.0000,
#             2.0000, 3.0000, 3.0000, 0.0000, 0.0000, 5.0000, 1.0000, 0.0000, 3.0000,
#             1.0000, 0.0000, 1.0000, 3.0000, 1.0000, 0.0000, 1.0000, 1.0000, 1.0000,
#             2.0000, 4.0000, 3.0000, 2.0000, 0.0000, 0.0000, 3.0000, 1.0000]]),
#    tensor([[ 0.4374,  0.3729,  0.2772,  0.2170,  0.2137,  0.2066,  0.1015,  0.0915,
#              0.0864,  0.0781,  0.5464,  0.5449,  0.5442,  0.4877,  0.4867,  0.4816,
#              0.4805,  0.4788,  0.4702,  0.4694,  0.5281,  0.5266,  0.5182,  0.5126,
#              0.5090,  0.4976,  0.4963,  0.4918,  0.4851,  0.4800,  0.2675,  0.2663,
#              0.2575,  0.2525,  0.2392,  0.2297,  0.2209,  0.2114,  0.1907,  0.1884,
#              0.2861,  0.2745,  0.2475,  0.2232,  0.2145,  0.2091,  0.2075,  0.2016,
#              0.1957,  0.1422,  0.3472,  0.3462,  0.3426,  0.3387,  0.3379,  0.3311,
#              0.3299,  0.3266,  0.3257,  0.3097, 10.0000,  0.1304,  3.0000,  1.0000,
#              2.0000,  4.0000,  1.0000,  0.0000,  3.0000,  1.0000,  4.0000,  2.0000,
#              0.0000,  1.0000,  0.0000,  3.0000,  2.0000,  1.0000,  1.0000,  2.0000,
#              2.0000,  1.0000,  7.0000,  0.0000,  0.0000,  1.0000,  5.0000,  0.0000,
#              1.0000,  2.0000,  3.0000,  0.0000,  2.0000,  2.0000,  0.0000,  0.0000,
#              6.0000,  1.0000,  1.0000,  1.0000,  3.0000,  1.0000,  1.0000,  4.0000,
#              4.0000,  0.0000,  1.0000,  0.0000,  2.0000,  4.0000,  3.0000,  0.0000,
#              0.0000,  5.0000,  2.0000,  1.0000,  4.0000,  1.0000,  0.0000,  1.0000,
#              4.0000,  1.0000,  0.0000,  1.0000,  1.0000,  2.0000,  3.0000,  4.0000,
#              3.0000,  2.0000,  0.0000,  0.0000,  4.0000,  1.0000]]),
#    tensor([[ 0.4374,  0.3729,  0.2772,  0.2170,  0.2137,  0.2066,  0.1015,  0.0915,
#              0.0864,  0.0781,  0.5464,  0.5449,  0.5442,  0.4877,  0.4867,  0.4816,
#              0.4805,  0.4788,  0.4702,  0.4694,  0.5281,  0.5266,  0.5182,  0.5126,
#              0.5090,  0.4976,  0.4963,  0.4918,  0.4851,  0.4800,  0.2675,  0.2663,
#              0.2575,  0.2525,  0.2392,  0.2297,  0.2209,  0.2114,  0.1907,  0.1884,
#              0.2861,  0.2745,  0.2475,  0.2232,  0.2145,  0.2091,  0.2075,  0.2016,
#              0.1957,  0.1422,  0.3462,  0.3426,  0.3387,  0.3379,  0.3311,  0.3299,
#              0.3266,  0.3257,  0.3097,  0.2999, 10.0000,  0.0435,  3.0000,  1.0000,
#              2.0000,  4.0000,  1.0000,  0.0000,  3.0000,  1.0000,  4.0000,  2.0000,
#              0.0000,  1.0000,  0.0000,  3.0000,  2.0000,  1.0000,  1.0000,  2.0000,
#              2.0000,  1.0000,  7.0000,  0.0000,  0.0000,  1.0000,  5.0000,  0.0000,
#              1.0000,  2.0000,  3.0000,  0.0000,  2.0000,  2.0000,  0.0000,  0.0000,
#              6.0000,  1.0000,  1.0000,  1.0000,  3.0000,  1.0000,  1.0000,  4.0000,
#              4.0000,  0.0000,  1.0000,  0.0000,  2.0000,  4.0000,  3.0000,  0.0000,
#              0.0000,  5.0000,  2.0000,  1.0000,  4.0000,  1.0000,  0.0000,  1.0000,
#              4.0000,  1.0000,  0.0000,  1.0000,  1.0000,  2.0000,  3.0000,  4.0000,
#              3.0000,  2.0000,  0.0000,  0.0000,  4.0000,  2.0000]]),
#    tensor([[ 0.2137,  0.2066,  0.1015,  0.0915,  0.0864,  0.0781,  0.0739,  0.0707,
#              0.0678,  0.0658,  0.5464,  0.5449,  0.5442,  0.4877,  0.4867,  0.4816,
#              0.4805,  0.4788,  0.4702,  0.4694,  0.4976,  0.4963,  0.4918,  0.4851,
#              0.4800,  0.4790,  0.4692,  0.4621,  0.4606,  0.4578,  0.2392,  0.2297,
#              0.2209,  0.2114,  0.1907,  0.1884,  0.1869,  0.1834,  0.1828,  0.1826,
#              0.2145,  0.2091,  0.2075,  0.2016,  0.1957,  0.1422,  0.1157,  0.0947,
#              0.0707,  0.0517,  0.3266,  0.3257,  0.3097,  0.2999,  0.2968,  0.0000,
#              0.0000,  0.0000,  0.0000,  0.0000, 12.0000,  0.1304,  4.0000,  1.0000,
#              3.0000,  4.0000,  1.0000,  0.0000,  4.0000,  1.0000,  5.0000,  2.0000,
#              0.0000,  1.0000,  0.0000,  3.0000,  2.0000,  1.0000,  1.0000,  4.0000,
#              2.0000,  1.0000,  9.0000,  0.0000,  0.0000,  1.0000,  5.0000,  0.0000,
#              1.0000,  2.0000,  5.0000,  0.0000,  2.0000,  2.0000,  0.0000,  0.0000,
#              8.0000,  1.0000,  1.0000,  1.0000,  4.0000,  2.0000,  1.0000,  4.0000,
#              4.0000,  0.0000,  1.0000,  1.0000,  2.0000,  5.0000,  3.0000,  0.0000,
#              0.0000,  6.0000,  2.0000,  2.0000,  5.0000,  1.0000,  0.0000,  2.0000,
#              4.0000,  1.0000,  0.0000,  1.0000,  1.0000,  2.0000,  3.0000,  6.0000,
#              4.0000,  2.0000,  0.0000,  0.0000,  4.0000,  2.0000]]),
#    tensor([[ 0.2066,  0.1015,  0.0915,  0.0864,  0.0781,  0.0739,  0.0707,  0.0678,
#              0.0658,  0.0657,  0.5464,  0.5449,  0.5442,  0.4877,  0.4867,  0.4816,
#              0.4805,  0.4788,  0.4702,  0.4694,  0.4976,  0.4963,  0.4918,  0.4851,
#              0.4800,  0.4790,  0.4692,  0.4621,  0.4606,  0.4578,  0.2392,  0.2297,
#              0.2209,  0.2114,  0.1907,  0.1884,  0.1869,  0.1834,  0.1828,  0.1826,
#              0.2145,  0.2091,  0.2075,  0.2016,  0.1957,  0.1422,  0.1157,  0.0947,
#              0.0707,  0.0517,  0.3266,  0.3257,  0.3097,  0.2999,  0.2968,  0.0000,
#              0.0000,  0.0000,  0.0000,  0.0000, 12.0000,  0.0435,  4.0000,  1.0000,
#              3.0000,  4.0000,  1.0000,  0.0000,  4.0000,  1.0000,  5.0000,  2.0000,
#              0.0000,  1.0000,  0.0000,  3.0000,  2.0000,  1.0000,  1.0000,  4.0000,
#              2.0000,  1.0000,  9.0000,  0.0000,  0.0000,  1.0000,  5.0000,  0.0000,
#              1.0000,  2.0000,  5.0000,  0.0000,  2.0000,  2.0000,  0.0000,  0.0000,
#              8.0000,  1.0000,  1.0000,  1.0000,  4.0000,  2.0000,  1.0000,  4.0000,
#              4.0000,  0.0000,  1.0000,  1.0000,  2.0000,  5.0000,  3.0000,  0.0000,
#              0.0000,  6.0000,  2.0000,  2.0000,  5.0000,  1.0000,  0.0000,  2.0000,
#              4.0000,  1.0000,  0.0000,  1.0000,  1.0000,  2.0000,  3.0000,  6.0000,
#              5.0000,  2.0000,  0.0000,  0.0000,  4.0000,  2.0000]]),
#    tensor([[ 0.0739,  0.0707,  0.0678,  0.0658,  0.0657,  0.0632,  0.0592,  0.0568,
#              0.0567,  0.0566,  0.5442,  0.4877,  0.4867,  0.4816,  0.4805,  0.4788,
#              0.4702,  0.4694,  0.4509,  0.4504,  0.4578,  0.4570,  0.4410,  0.4353,
#              0.3888,  0.3867,  0.3865,  0.3831,  0.3811,  0.3789,  0.2392,  0.2297,
#              0.2209,  0.2114,  0.1907,  0.1884,  0.1869,  0.1834,  0.1828,  0.1826,
#              0.2016,  0.1957,  0.1422,  0.1157,  0.0947,  0.0707,  0.0517,  0.0454,
#              0.0186,  0.0000,  0.2968,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#              0.0000,  0.0000,  0.0000,  0.0000, 14.0000,  0.0000,  5.0000,  1.0000,
#              4.0000,  4.0000,  1.0000,  0.0000,  4.0000,  1.0000,  7.0000,  2.0000,
#              0.0000,  1.0000,  0.0000,  3.0000,  2.0000,  1.0000,  1.0000,  4.0000,
#              2.0000,  1.0000, 11.0000,  0.0000,  0.0000,  1.0000,  6.0000,  0.0000,
#              1.0000,  2.0000,  6.0000,  0.0000,  2.0000,  2.0000,  0.0000,  0.0000,
#             10.0000,  1.0000,  1.0000,  2.0000,  4.0000,  2.0000,  1.0000,  5.0000,
#              6.0000,  0.0000,  1.0000,  1.0000,  2.0000,  5.0000,  3.0000,  0.0000,
#              1.0000,  6.0000,  2.0000,  3.0000,  5.0000,  1.0000,  2.0000,  2.0000,
#              4.0000,  1.0000,  0.0000,  1.0000,  1.0000,  2.0000,  3.0000,  8.0000,
#              6.0000,  2.0000,  0.0000,  0.0000,  4.0000,  2.0000]])],
#   'actions': [0, 5, 4, 1, 4, 0, 4, 1, 0, 4, 5, 0, 0, 0, 1],
#   'rewards': [np.float64(0.06182828432020597),
#    np.float64(0.0895259506677463),
#    np.float64(0.11303829399605561),
#    np.float64(0.15625146919761704),
#    np.float64(0.16186392401746963),
#    np.float64(0.17483600572574345),
#    np.float64(0.18010349726063432),
#    np.float64(0.21875250815224406),
#    np.float64(0.23028870020601735),
#    np.float64(0.23546679119593364),
#    np.float64(0.24125315578198875),
#    np.float64(0.24854284354865636),
#    np.float64(0.25210462414031615),
#    np.float64(0.2555476105100877),
#    np.float64(0.2646170361174434)],
#   'log_probs': [tensor(-1.2330, grad_fn=<LogBackward0>),
#    tensor(-1.9701, grad_fn=<LogBackward0>),
#    tensor(-2.0955, grad_fn=<LogBackward0>),
#    tensor(-1.8032, grad_fn=<LogBackward0>),
#    tensor(-2.0320, grad_fn=<LogBackward0>),
#    tensor(-1.3037, grad_fn=<LogBackward0>),
#    tensor(-2.0568, grad_fn=<LogBackward0>),
#    tensor(-1.7028, grad_fn=<LogBackward0>),
#    tensor(-1.0499, grad_fn=<LogBackward0>),
#    tensor(-2.3010, grad_fn=<LogBackward0>),
#    tensor(-2.3061, grad_fn=<LogBackward0>),
#    tensor(-0.8473, grad_fn=<LogBackward0>),
#    tensor(-0.7409, grad_fn=<LogBackward0>),
#    tensor(-0.7238, grad_fn=<LogBackward0>),
#    tensor(-1.5425, grad_fn=<LogBackward0>)]}}

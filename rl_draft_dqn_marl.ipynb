# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np

import gymnasium as gym
from gymnasium import spaces
import numpy as npimport 

import math
import random
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count
from pprint import pprint
from typing import List, Tuple, Dict, Any, Union

import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %% [markdown]
# actions: [QB, RB, WR, TE, K, DEF]
#
# state: [
#     next 15 QB FP
#
#     next 30 RB FP
#
#     next 30 WR FP
#
#     next 15 TE FP
#
#     next 15 Ks FP
#
#     next 15 DEF FP
#
#     team comps: 6 positions * 12 managers
#
#     n until next pick (scaled  /12)
#
#     round (scaled scaled /15)
#
#     ]
#
#
# 120 future players
# current team = 6 spots for QBs, 6 spots for k, 6 spots for def, 9 spots for RB, 9 for WR, 8 for TE (this allows full starters and anything else) = 44
# +1 for picks remaining
# +1 for number of opp picks before next pick
# 166 total
#
# or 330 if i include a variance with each player
#
#
# reward function: sum fpts when starting lineup is full, 0 when starting lineup not full

# %%
df_sleeper = pd.read_csv("data/sleeper/all_players.csv")
# df_sleeper = df_sleeper.loc[df_sleeper["rank_int"] < 50]
print(df_sleeper.shape)
df_sleeper.columns
# Out:
# (3670, 56)
# Index(['sleeper_id', 'injury_notes', 'oddsjam_id', 'search_last_name',
#        'college', 'team_abbr', 'birth_state', 'yahoo_id', 'search_first_name',
#        'pandascore_id', 'years_exp', 'fantasy_positions', 'injury_status',
#        'active', 'team', 'competitions', 'high_school', 'number', 'birth_city',
#        'search_full_name', 'last_name', 'birth_country',
#        'practice_description', 'depth_chart_order', 'fantasy_data_id',
#        'status', 'injury_start_date', 'news_updated', 'age', 'search_rank',
#        'practice_participation', 'opta_id', 'full_name', 'swish_id',
#        'birth_date', 'rotowire_id', 'weight', 'height', 'stats_id', 'espn_id',
#        'metadata', 'player_id', 'first_name', 'sport', 'injury_body_part',
#        'position', 'gsis_id', 'sportradar_id', 'hashtag',
#        'depth_chart_position', 'rotoworld_id', 'Player Id', 'positional_rank',
#        'adp', 'adp_date', 'rank_int'],
#       dtype='object')

# %%
SCORING = {
    'pass_yd': .04,
    'pass_td': 4,
    'pass_2pt': 2,
    'pass_int': -1,
    'rush_yd': .1,
    'rush_td': 6,
    'rush_2pt': 2,
    'rec_rcpt': .5,
    'rec_yd': .1,
    'rec_td': 6,
    'rec_2pt': 2,
    'fg_1_39_made': 3,
    'fg_40_49_made': 4,
    'fg_50_made': 5,
    'xp_missed': -1,
    'xp_made': 1,
    'def_td': 6,
    'def_int': 2,
    'def_sck': 1,
    'def_fum_rec': 2,
    'def_fum_forced': 1,
    'def_sfty': 2,
    'remainder': 1
}

POSITIONS = ['QB', 'RB', 'WR', 'TE', 'K', 'DEF']
STARTER_COMPOSITION = {'QB': 1, 'RB': 2, 'WR': 2, 'FLEX': 2, 'TE': 1, 'K': 1, 'DEF': 1}
TEAM_SIZE = 15

# %%
df_qb_proj = pd.read_csv("data/projections/QB_projections.csv")
df_rb_proj = pd.read_csv("data/projections/RB_projections.csv")
df_wr_proj = pd.read_csv("data/projections/WR_projections.csv")
df_te_proj = pd.read_csv("data/projections/TE_projections.csv")
df_k_proj = pd.read_csv("data/projections/K_projections.csv")
df_def_proj = pd.read_csv("data/projections/DEF_projections.csv")

df_qb_proj = df_qb_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)
df_rb_proj = df_rb_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)
df_wr_proj = df_wr_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)
df_te_proj = df_te_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)
df_k_proj = df_k_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)
df_def_proj = df_def_proj.loc[:, ["sleeper_id", "full_name", "team", "position", "source", "fpts"]].sort_values(by="fpts", ascending=False)

df_proj = pd.concat([df_qb_proj, df_rb_proj, df_wr_proj, df_te_proj, df_k_proj, df_def_proj])
df_proj.columns

df_proj_agg = df_proj.groupby('sleeper_id')['fpts'].agg(['mean', 'std']).reset_index()
df_proj_agg['sleeper_id'] = df_proj_agg['sleeper_id'].astype(str)


df_players = df_proj_agg.merge(df_sleeper.loc[:, ['sleeper_id', 'full_name', 'position', 'team']], 
                                on='sleeper_id', 
                                how='left')
print(df_players.shape)
df_players = df_players.dropna(subset=['mean', 'std'])
print(df_players.shape)
# Out:
# (796, 6)
# (647, 6)

# %%
# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display
plt.ion()

# if GPU is to be used
device = torch.device(
    "cuda" if torch.cuda.is_available() else
    "mps" if torch.backends.mps.is_available() else
    "cpu"
)

# %% [markdown]
# # Init environment and RL network

# %%
from rl_env import DraftEnv

from dqn import (
    DQN, ReplayMemory, Transition,
    NUM_MGRS, NUM_DRAFT_ROUNDS, ACTION_SPACE_DIM, 
    STATE_SPACE_DIM, STARTER_COMPOSITION
    )

# %%
# BATCH_SIZE is the number of transitions sampled from the replay buffer
# GAMMA is the discount factor as mentioned in the previous section
# EPS_START is the starting value of epsilon
# EPS_END is the final value of epsilon
# EPS_DECAY controls the rate of exponential decay of epsilon, higher means a slower decay
# TAU is the update rate of the target network
# LR is the learning rate of the ``AdamW`` optimizer
BATCH_SIZE = 128
GAMMA = 0.99
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 10000
TAU = 0.005
LR = 1e-4

env = DraftEnv(df_players)

# Get number of actions from gym action space
n_actions = env.action_space.n
# Get the number of state observations
state, info = env.reset()
n_observations = len(state)

mgr_networks = {i: {} for i in range(NUM_MGRS)}
for mgr in mgr_networks.values():
    mgr["policy"] = DQN(n_observations, n_actions).to(device)
    mgr["target"] = DQN(n_observations, n_actions).to(device)
    mgr["optimizer"] = optim.AdamW(mgr["policy"].parameters(), lr=LR, amsgrad=True)
    mgr["memory"] = ReplayMemory(100)
    mgr["target"].load_state_dict(mgr["policy"].state_dict())

steps_done = 0

# %%
def select_action(state, policy_net, env, device):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            # t.max(1) will return the largest column value of each row.
            # second column on max result is index of where max element was
            # found, so we pick action with the larger expected reward.
            return policy_net(state).max(1).indices.view(1, 1)
    else:
        if random.random() < 0.2:
            return torch.tensor([[env.action_space.sample()]], device=device, dtype=torch.long)
        else:
            return torch.tensor([[env.reasonable_option()]], device=device, dtype=torch.long)


def optimize_model(memory, policy_net, target_net, optimizer):
    if len(memory) < BATCH_SIZE:
        return 
    transitions = memory.sample(BATCH_SIZE)
    # Transpose the batch (see https://stackoverflow.com/a/19343/3343043 for
    # detailed explanation). This converts batch-array of Transitions
    # to Transition of batch-arrays.
    batch = Transition(*zip(*transitions))

    # Compute a mask of non-final states and concatenate the batch elements
    # (a final state would've been the one after which simulation ended)
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
    # columns of actions taken. These are the actions which would've been taken
    # for each batch state according to policy_net
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    # Compute V(s_{t+1}) for all next states.
    # Expected values of actions for non_final_next_states are computed based
    # on the "older" target_net; selecting their best reward with max(1).values
    # This is merged based on the mask, such that we'll have either the expected
    # state value or 0 in case the state was final.
    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    with torch.no_grad():
        next_state_values[non_final_mask] = target_net(non_final_next_states).max(1).values
    # Compute the expected Q values
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Compute Huber loss
    criterion = nn.SmoothL1Loss()
    loss = criterion(state_action_values, expected_state_action_values.unsqueeze(1))

    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    # In-place gradient clipping
    torch.nn.utils.clip_grad_value_(policy_net.parameters(), 100)
    optimizer.step()
    
    return loss

# %%
if torch.cuda.is_available() or torch.backends.mps.is_available():
    num_episodes = 600
    # num_episodes = 50
else:
    num_episodes = 50

losses = {mgr_num: [] for mgr_num in range(NUM_MGRS)}
drafts = []
rewards = []

# %%
for i_episode in range(num_episodes):
    env.reset()
    print(f"Episode: {i_episode}")
    for _, row in env.draft.iterrows():
        # print(f"Round: {row[1]['round']}, Manager: {row[1]['mgr']}")
        mgr_num = row["mgr"]
        mgr = mgr_networks[mgr_num]
        
        state = torch.tensor(env.get_state(), dtype=torch.float32, device=device).unsqueeze(0)
        action = select_action(state, mgr["policy"], env, device)
        observation, reward, terminated, info = env.step(action.item())
        reward = torch.tensor([reward], dtype=torch.float32, device=device)

        done = terminated 
        
        if terminated:
            next_state = None
        else:
            next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)

        # Store the transition in memory
        mgr["memory"].push(state, action, next_state, reward)
        
        # Move to the next state
        state = next_state


    round_rewards = {}
    for i, mgr in mgr_networks.items():
        # Perform one step of the optimization (on the policy network)
        loss = optimize_model(mgr["memory"], mgr["policy"], mgr["target"], mgr["optimizer"])
        loss = loss.item() if loss is not None else None
        losses[i].append(loss)
        drafts.append(env.draft.copy())
        round_rewards[i] = env.compute_reward(i)
        
        # Soft update of the target network's weights
        # θ′ ← τ θ + (1 −τ )θ′
        target_net_state_dict = mgr["target"].state_dict()
        policy_net_state_dict = mgr["policy"].state_dict()
        for key in policy_net_state_dict:
            target_net_state_dict[key] = policy_net_state_dict[key]*TAU + target_net_state_dict[key]*(1-TAU)
        mgr["target"].load_state_dict(target_net_state_dict)
    rewards.append(round_rewards)
    print(f"Total round rewards:{np.sum(list(round_rewards.values()))}")
    losses.values()
    # sum losses
    cur_loss_sum = 0  # Initialize the total sum to 0
    for mgr_num, loss_list in losses.items():
        cur_loss_sum += loss_list[-1]  if loss_list[-1] is not None else 0

    print(f"Average loss: {cur_loss_sum / NUM_MGRS}")
    eps_threshold = EPS_END + (EPS_START - EPS_END) * math.exp(-1. * steps_done / EPS_DECAY)
    print(f"Epsilon: {eps_threshold}")
    
        

        
print('Complete')
# Out:
# Episode: 0
# Total round rewards:5.958064465550313
# Average loss: 0.0
# Epsilon: 0.8848368775045556
# Episode: 1
# Total round rewards:1.5560878652559245
# Average loss: 0.0
# Epsilon: 0.8699442494606546
# Episode: 2
# Total round rewards:3.2301159734087803
# Average loss: 0.0
# Epsilon: 0.8553172905265286
# Episode: 3
# Total round rewards:2.01616661459675
# Average loss: 0.0
# Epsilon: 0.8409512614395249
# Episode: 4
# Total round rewards:3.6118612460385955
# Average loss: 0.0
# Epsilon: 0.826841507480544
# Episode: 5
# Total round rewards:2.2314854881334
# Average loss: 0.0
# Epsilon: 0.8129834569658697
# Episode: 6
# Total round rewards:3.6436229420352144
# Average loss: 0.0
# Epsilon: 0.7993726197659037
# Episode: 7
# Total round rewards:2.073092494747118
# Average loss: 0.0
# Epsilon: 0.7860045858503243
# Episode: 8
# Total round rewards:3.8082852430527705
# Average loss: 0.0
# Epsilon: 0.772875023859198
# Episode: 9
# Total round rewards:2.3926047064040263
# Average loss: 0.0
# Epsilon: 0.7599796796995812
# Episode: 10
# Total round rewards:3.7527728390231743
# Average loss: 0.0
# Epsilon: 0.7473143751671564
# Episode: 11
# Total round rewards:2.159060144858953
# Average loss: 0.0
# Epsilon: 0.7348750065924577
# Episode: 12
# Total round rewards:3.9318909277541194
# Average loss: 0.0
# Epsilon: 0.7226575435112463
# Episode: 13
# Total round rewards:2.243683661292988
# Average loss: 0.0
# Epsilon: 0.7106580273586042
# Episode: 14
# Total round rewards:3.511923639577695
# Average loss: 0.0
# Epsilon: 0.6988725701863252
# Episode: 15
# Total round rewards:2.232917822417497
# Average loss: 0.0
# Epsilon: 0.6872973534031851
# Episode: 16
# Total round rewards:3.5565948561387057
# Average loss: 0.0
# Epsilon: 0.675928626537685
# Episode: 17
# Total round rewards:2.3308117205195034
# Average loss: 0.0
# Epsilon: 0.664762706022866
# Episode: 18
# Total round rewards:3.732879807195556
# Average loss: 0.0
# Epsilon: 0.6537959740028007
# Episode: 19
# Total round rewards:2.214584151688435
# Average loss: 0.0
# Epsilon: 0.6430248771603764
# Episode: 20
# Total round rewards:3.8159527079849296
# Average loss: 0.0
# Epsilon: 0.6324459255659898
# Episode: 21
# Total round rewards:2.171572578210513
# Average loss: 0.0
# Epsilon: 0.6220556915467784
# Episode: 22
# Total round rewards:4.027566027194279
# Average loss: 0.0
# Epsilon: 0.6118508085760257
# Episode: 23
# Total round rewards:2.127610221969204
# Average loss: 0.0
# Epsilon: 0.6018279701823753
# Episode: 24
# Total round rewards:4.125862815061787
# Average loss: 0.0
# Epsilon: 0.5919839288785074
# Episode: 25
# Total round rewards:2.2428185395235363
# Average loss: 0.0
# Epsilon: 0.5823154951089226
# Episode: 26
# Total round rewards:3.8782039444855534
# Average loss: 0.0
# Epsilon: 0.5728195362164994
# Episode: 27
# Total round rewards:2.098246504193064
# Average loss: 0.0
# Epsilon: 0.563492975427485
# Episode: 28
# Total round rewards:3.929254323101369
# Average loss: 0.0
# Epsilon: 0.5543327908545942
# Episode: 29
# Total round rewards:2.150255129746883
# Average loss: 0.0
# Epsilon: 0.5453360145178912
# Episode: 30
# Total round rewards:3.6546426615702847
# Average loss: 0.0
# Epsilon: 0.5364997313831382
# Episode: 31
# Total round rewards:2.145604353212449
# Average loss: 0.0
# Epsilon: 0.5278210784172991
# Episode: 32
# Total round rewards:3.74768215620868
# Average loss: 0.0
# Epsilon: 0.519297243660891
# Episode: 33
# Total round rewards:2.203471270474362
# Average loss: 0.0
# Epsilon: 0.5109254653168858
# Episode: 34
# Total round rewards:3.5939073275760687
# Average loss: 0.0
# Epsilon: 0.5027030308558627
# Episode: 35
# Total round rewards:2.085845637453139
# Average loss: 0.0
# Epsilon: 0.49462727613712565
# Episode: 36
# Total round rewards:3.609719914031888
# Average loss: 0.0
# Epsilon: 0.48669558454549855
# Episode: 37
# Total round rewards:2.196568371220502
# Average loss: 0.0
# Epsilon: 0.47890538614351846
# Episode: 38
# Total round rewards:3.3279197525197692
# Average loss: 0.0
# Epsilon: 0.4712541568387537
# Episode: 39
# Total round rewards:2.093168783928149
# Average loss: 0.0
# Epsilon: 0.4637394175659759
# Episode: 40
# Total round rewards:3.4902107363775947
# Average loss: 0.0
# Epsilon: 0.4563587334839209
# Episode: 41
# Total round rewards:2.144591548856655
# Average loss: 0.0
# Epsilon: 0.4491097131863793
# Episode: 42
# Total round rewards:3.6920467855855112
# Average loss: 0.0
# Epsilon: 0.44199000792735965
# Episode: 43
# Total round rewards:2.263477891392312
# Average loss: 0.0
# Epsilon: 0.43499731086007404
# Episode: 44
# Total round rewards:3.630300956972902
# Average loss: 0.0
# Epsilon: 0.42812935628949994
# Episode: 45
# Total round rewards:1.9959269669171191
# Average loss: 0.0
# Epsilon: 0.421383918938275
# Episode: 46
# Total round rewards:3.622760078268266
# Average loss: 0.0
# Epsilon: 0.41475881322568764
# Episode: 47
# Total round rewards:2.258829729499317
# Average loss: 0.0
# Epsilon: 0.40825189255953
# Episode: 48
# Total round rewards:3.6595862316727636
# Average loss: 0.0
# Epsilon: 0.401861048640583
# Episode: 49
# Total round rewards:1.818735919216451
# Average loss: 0.0
# Epsilon: 0.3955842107795092
# Episode: 50
# Total round rewards:3.1933123589928734
# Average loss: 0.0
# Epsilon: 0.38941934522593136
# Episode: 51
# Total round rewards:2.271193306635525
# Average loss: 0.0
# Epsilon: 0.3833644545094792
# Episode: 52
# Total round rewards:3.404504376512636
# Average loss: 0.0
# Epsilon: 0.3774175767925919
# Episode: 53
# Total round rewards:2.186743432054365
# Average loss: 0.0
# Epsilon: 0.37157678523486526
# Episode: 54
# Total round rewards:3.314891430662722
# Average loss: 0.0
# Epsilon: 0.36584018736873886
# Episode: 55
# Total round rewards:2.150445176211632
# Average loss: 0.0
# Epsilon: 0.36020592448631966
# Episode: 56
# Total round rewards:3.3119301174344513
# Average loss: 0.0
# Epsilon: 0.35467217103714477
# Episode: 57
# Total round rewards:2.091321695220876
# Average loss: 0.0
# Epsilon: 0.3492371340366869
# Episode: 58
# Total round rewards:3.566709917696642
# Average loss: 0.0
# Epsilon: 0.3438990524854116
# Episode: 59
# Total round rewards:2.3786150118978346
# Average loss: 0.0
# Epsilon: 0.33865619679819825
# Episode: 60
# Total round rewards:2.9695552555383613
# Average loss: 0.0
# Epsilon: 0.3335068682439392
# Episode: 61
# Total round rewards:2.1756937626198236
# Average loss: 0.0
# Epsilon: 0.3284493983951361
# Episode: 62
# Total round rewards:2.969160271829268
# Average loss: 0.0
# Epsilon: 0.32348214858731467
# Episode: 63
# Total round rewards:2.118196537684491
# Average loss: 0.0
# Epsilon: 0.3186035093880832
# Episode: 64
# Total round rewards:3.338187566566084
# Average loss: 0.0
# Epsilon: 0.31381190007566223
# Episode: 65
# Total round rewards:2.1725759209583275
# Average loss: 0.0
# Epsilon: 0.3091057681267173
# Episode: 66
# Total round rewards:3.0898787096480453
# Average loss: 0.0
# Epsilon: 0.30448358871332715
# Episode: 67
# Total round rewards:2.033814387394135
# Average loss: 0.0
# Epsilon: 0.2999438642089266
# Episode: 68
# Total round rewards:3.0703777579533322
# Average loss: 0.0
# Epsilon: 0.2954851237030623
# Episode: 69
# Total round rewards:2.3331022517971887
# Average loss: 0.0
# Epsilon: 0.2911059225248048
# Episode: 70
# Total round rewards:2.953642733866003
# Average loss: 0.0
# Epsilon: 0.28680484177466276
# Episode: 71
# Total round rewards:2.145052450424269
# Average loss: 0.0
# Epsilon: 0.28258048786484685
# Episode: 72
# Total round rewards:3.0767534502819895
# Average loss: 0.0
# Epsilon: 0.2784314920677352
# Episode: 73
# Total round rewards:2.2269676263926916
# Average loss: 0.0
# Epsilon: 0.2743565100723938
# Episode: 74
# Total round rewards:2.8823141507499512
# Average loss: 0.0
# Epsilon: 0.2703542215490078
# Episode: 75
# Total round rewards:2.1018579270123023
# Average loss: 0.0
# Epsilon: 0.2664233297210832
# Episode: 76
# Total round rewards:2.9003483794914535
# Average loss: 0.0
# Epsilon: 0.26256256094528
# Episode: 77
# Total round rewards:2.2132958153680122
# Average loss: 0.0
# Epsilon: 0.2587706642987404
# Episode: 78
# Total round rewards:2.835425151946205
# Average loss: 0.0
# Epsilon: 0.25504641117377913
# Episode: 79
# Total round rewards:2.1629524467950323
# Average loss: 0.0
# Epsilon: 0.2513885948798035
# Episode: 80
# Total round rewards:3.248634171487459
# Average loss: 0.0
# Epsilon: 0.24779603025233543
# Episode: 81
# Total round rewards:2.1499467659159195
# Average loss: 0.0
# Epsilon: 0.2442675532690074
# Episode: 82
# Total round rewards:3.204622048279742
# Average loss: 0.0
# Epsilon: 0.24080202067240947
# Episode: 83
# Total round rewards:1.9412820440600855
# Average loss: 0.0
# Epsilon: 0.23739830959966352
# Episode: 84
# Total round rewards:2.7942916356012453
# Average loss: 0.0
# Epsilon: 0.234055317218606
# Episode: 85
# Total round rewards:1.882760094112541
# Average loss: 0.0
# Epsilon: 0.2307719603704606
# Episode: 86
# Total round rewards:2.8090313682814627
# Average loss: 0.0
# Epsilon: 0.2275471752188854
# Episode: 87
# Total round rewards:2.1237632272436855
# Average loss: 0.0
# Epsilon: 0.22437991690528059
# Episode: 88
# Total round rewards:2.873922387521868
# Average loss: 0.0
# Epsilon: 0.22126915921024504
# Episode: 89
# Total round rewards:1.7579554449942976
# Average loss: 0.0
# Epsilon: 0.21821389422107246
# Episode: 90
# Total round rewards:2.9966461253706407
# Average loss: 0.0
# Epsilon: 0.21521313200517855
# Episode: 91
# Total round rewards:1.9769685814642104
# Average loss: 0.0
# Epsilon: 0.21226590028935438
# Episode: 92
# Total round rewards:2.420959483555834
# Average loss: 0.0
# Epsilon: 0.2093712441447414
# Episode: 93
# Total round rewards:2.0502412520748554
# Average loss: 0.0
# Epsilon: 0.20652822567742596
# Episode: 94
# Total round rewards:2.9041924564888904
# Average loss: 0.0
# Epsilon: 0.2037359237245538
# Episode: 95
# Total round rewards:2.1882001392935564
# Average loss: 0.0
# Epsilon: 0.2009934335558647
# Episode: 96
# Total round rewards:2.7411267635130945
# Average loss: 0.0
# Epsilon: 0.1982998665805526
# Episode: 97
# Total round rewards:1.9906439132212785
# Average loss: 0.0
# Epsilon: 0.19565435005935378
# Episode: 98
# Total round rewards:2.5544778500425127
# Average loss: 0.0
# Epsilon: 0.1930560268217722
# Episode: 99
# Total round rewards:2.0542756331793472
# Average loss: 0.0
# Epsilon: 0.19050405498834855
# Episode: 100
# Total round rewards:2.544432428491321
# Average loss: 0.0
# Epsilon: 0.18799760769788387
# Episode: 101
# Total round rewards:1.9068959689103302
# Average loss: 0.0
# Epsilon: 0.18553587283952938
# Episode: 102
# Total round rewards:2.6784525565149844
# Average loss: 0.0
# Epsilon: 0.18311805278965554
# Episode: 103
# Total round rewards:1.9144472329640294
# Average loss: 0.0
# Epsilon: 0.18074336415341485
# Episode: 104
# Total round rewards:2.8068033310997484
# Average loss: 0.0
# Epsilon: 0.17841103751091525
# Episode: 105
# Total round rewards:1.8940475094116191
# Average loss: 0.0
# Epsilon: 0.17612031716792098
# Episode: 106
# Total round rewards:2.5491127648703684
# Average loss: 0.0
# Epsilon: 0.17387046091100156
# Episode: 107
# Total round rewards:1.9202828381931787
# Average loss: 0.0
# Epsilon: 0.17166073976704785
# Episode: 108
# Total round rewards:2.2652881352399725
# Average loss: 0.0
# Epsilon: 0.16949043776707828
# Episode: 109
# Total round rewards:2.0345675535160743
# Average loss: 0.0
# Epsilon: 0.1673588517142589
# Episode: 110
# Total round rewards:2.4760374090498
# Average loss: 0.0
# Epsilon: 0.16526529095606124
# Episode: 111
# Total round rewards:1.9458373354606273
# Average loss: 0.0
# Epsilon: 0.163209077160485
# Episode: 112
# Total round rewards:2.579089321790327
# Average loss: 0.0
# Epsilon: 0.1611895440962725
# Episode: 113
# Total round rewards:1.7602600011357405
# Average loss: 0.0
# Epsilon: 0.15920603741704376
# Episode: 114
# Total round rewards:2.3680100004723985
# Average loss: 0.0
# Epsilon: 0.15725791444928294
# Episode: 115
# Total round rewards:2.046140243597095
# Average loss: 0.0
# Epsilon: 0.15534454398410602
# Episode: 116
# Total round rewards:2.561459449193583
# Average loss: 0.0
# Epsilon: 0.153465306072744
# Episode: 117
# Total round rewards:1.7646793951310196
# Average loss: 0.0
# Epsilon: 0.1516195918256738
# Episode: 118
# Total round rewards:2.4500154066719224
# Average loss: 0.0
# Epsilon: 0.14980680321533293
# Episode: 119
# Total round rewards:1.9396061664906308
# Average loss: 0.0
# Epsilon: 0.14802635288235313
# Episode: 120
# Total round rewards:2.3965611547150636
# Average loss: 0.0
# Epsilon: 0.14627766394525105
# Episode: 121
# Total round rewards:1.938039418674744
# Average loss: 0.0
# Epsilon: 0.1445601698135133
# Episode: 122
# Total round rewards:2.1395976159959473
# Average loss: 0.0
# Epsilon: 0.14287331400401648
# Episode: 123
# Total round rewards:2.1028479484429408
# Average loss: 0.0
# Epsilon: 0.14121654996072142
# Episode: 124
# Total round rewards:2.63923784596178
# Average loss: 0.0
# Epsilon: 0.13958934087758468
# Episode: 125
# Total round rewards:1.8161563151160418
# Average loss: 0.0
# Epsilon: 0.13799115952462832
# Episode: 126
# Total round rewards:2.313479600779593
# Average loss: 0.0
# Epsilon: 0.13642148807711285
# Episode: 127
# Total round rewards:1.988327822691027
# Average loss: 0.0
# Epsilon: 0.13487981794775775
# Episode: 128
# Total round rewards:2.449409502281741
# Average loss: 0.0
# Epsilon: 0.13336564962195435
# Episode: 129
# Total round rewards:1.974481952487903
# Average loss: 0.0
# Epsilon: 0.1318784924959191
# Episode: 130
# Total round rewards:2.3949668451987955
# Average loss: 0.0
# Epsilon: 0.13041786471773326
# Episode: 131
# Total round rewards:1.9526827724431388
# Average loss: 0.0
# Epsilon: 0.12898329303121908
# Episode: 132
# Total round rewards:2.2309752731405803
# Average loss: 0.0
# Epsilon: 0.12757431262260027
# Episode: 133
# Total round rewards:1.9240375826889133
# Average loss: 0.0
# Epsilon: 0.12619046696989866
# Episode: 134
# Total round rewards:2.1902770877977122
# Average loss: 0.0
# Epsilon: 0.12483130769501667
# Episode: 135
# Total round rewards:1.928456356349719
# Average loss: 0.0
# Epsilon: 0.12349639441845923
# Episode: 136
# Total round rewards:2.1813605863796357
# Average loss: 0.0
# Epsilon: 0.12218529461664675
# Episode: 137
# Total round rewards:1.7382919747327445
# Average loss: 0.0
# Epsilon: 0.12089758348177389
# Episode: 138
# Total round rewards:2.4198018654331395
# Average loss: 0.0
# Epsilon: 0.11963284378416786
# Episode: 139
# Total round rewards:1.797051140770868
# Average loss: 0.0
# Epsilon: 0.11839066573710258
# Episode: 140
# Total round rewards:2.5676487182142966
# Average loss: 0.0
# Epsilon: 0.11717064686402413
# Episode: 141
# Total round rewards:1.6884392754426278
# Average loss: 0.0
# Epsilon: 0.11597239186814479
# Episode: 142
# Total round rewards:2.6763236137745414
# Average loss: 0.0
# Epsilon: 0.11479551250436346
# Episode: 143
# Total round rewards:1.9487654662287004
# Average loss: 0.0
# Epsilon: 0.11363962745347078
# Episode: 144
# Total round rewards:2.33035485432367
# Average loss: 0.0
# Epsilon: 0.11250436219859854
# Episode: 145
# Total round rewards:1.5417903129119448
# Average loss: 0.0
# Epsilon: 0.11138934890387267
# Episode: 146
# Total round rewards:2.214348049283731
# Average loss: 0.0
# Epsilon: 0.1102942262952315
# Episode: 147
# Total round rewards:1.5700671089168738
# Average loss: 0.0
# Epsilon: 0.10921863954336958
# Episode: 148
# Total round rewards:2.4886834123530983
# Average loss: 0.0
# Epsilon: 0.10816224014876996
# Episode: 149
# Total round rewards:1.636779890458073
# Average loss: 0.0
# Epsilon: 0.10712468582878729
# Episode: 150
# Total round rewards:2.179357411329107
# Average loss: 0.0
# Epsilon: 0.10610564040674533
# Episode: 151
# Total round rewards:1.7971303726008083
# Average loss: 0.0
# Epsilon: 0.10510477370301258
# Episode: 152
# Total round rewards:2.286030072656176
# Average loss: 0.0
# Epsilon: 0.10412176142802138
# Episode: 153
# Total round rewards:1.9677214830205283
# Average loss: 0.0
# Epsilon: 0.10315628507719515
# Episode: 154
# Total round rewards:2.6115304752405692
# Average loss: 0.0
# Epsilon: 0.10220803182775011
# Episode: 155
# Total round rewards:1.7542203125637577
# Average loss: 0.0
# Epsilon: 0.10127669443733808
# Episode: 156
# Total round rewards:2.1442913293145343
# Average loss: 0.0
# Epsilon: 0.1003619711444971
# Episode: 157
# Total round rewards:1.7201137201009462
# Average loss: 0.0
# Epsilon: 0.09946356557087824
# Episode: 158
# Total round rewards:2.213901476393254
# Average loss: 0.0
# Epsilon: 0.09858118662521625
# Episode: 159
# Total round rewards:1.4276113412713507
# Average loss: 0.0
# Epsilon: 0.09771454840901367
# Episode: 160
# Total round rewards:2.1863986485951235
# Average loss: 0.0
# Epsilon: 0.09686337012390697
# Episode: 161
# Total round rewards:1.7286405705817345
# Average loss: 0.0
# Epsilon: 0.09602737598068563
# Episode: 162
# Total round rewards:2.2447052755102486
# Average loss: 0.0
# Epsilon: 0.09520629510993384
# Episode: 163
# Total round rewards:1.6940299266306078
# Average loss: 0.0
# Epsilon: 0.09439986147426663
# Episode: 164
# Total round rewards:2.2438599445321734
# Average loss: 0.0
# Epsilon: 0.09360781378213125
# Episode: 165
# Total round rewards:1.6229933130327325
# Average loss: 0.0
# Epsilon: 0.09282989540314657
# Episode: 166
# Total round rewards:2.0437202483479027
# Average loss: 0.0
# Epsilon: 0.09206585428495248
# Episode: 167
# Total round rewards:1.461306627085083
# Average loss: 0.0
# Epsilon: 0.09131544287154277
# Episode: 168
# Total round rewards:2.0552297312398604
# Average loss: 0.0
# Epsilon: 0.09057841802305486
# Episode: 169
# Total round rewards:1.7397448673909375
# Average loss: 0.0
# Epsilon: 0.08985454093699022
# Episode: 170
# Total round rewards:2.3303548118995985
# Average loss: 0.0
# Epsilon: 0.08914357707084047
# Episode: 171
# Total round rewards:1.7643669977914445
# Average loss: 0.0
# Epsilon: 0.08844529606609339
# Episode: 172
# Total round rewards:2.1605094653406796
# Average loss: 0.0
# Epsilon: 0.0877594716735948
# Episode: 173
# Total round rewards:1.8285511475004483
# Average loss: 0.0
# Epsilon: 0.08708588168024187
# Episode: 174
# Total round rewards:2.1194064828940866
# Average loss: 0.0
# Epsilon: 0.08642430783698415
# Episode: 175
# Total round rewards:1.5523228092538774
# Average loss: 0.0
# Epsilon: 0.0857745357881089
# Episode: 176
# Total round rewards:1.7729753474337353
# Average loss: 0.0
# Epsilon: 0.08513635500178801
# Episode: 177
# Total round rewards:1.4650061674226558
# Average loss: 0.0
# Epsilon: 0.08450955870186386
# Episode: 178
# Total round rewards:2.0369981776994357
# Average loss: 0.0
# Epsilon: 0.083893943800852
# Episode: 179
# Total round rewards:1.9604132132305687
# Average loss: 0.0
# Epsilon: 0.08328931083413901
# Episode: 180
# Total round rewards:2.3949844504746656
# Average loss: 0.0
# Epsilon: 0.08269546389535434
# Episode: 181
# Total round rewards:1.734963685031349
# Average loss: 0.0
# Epsilon: 0.08211221057289478
# Episode: 182
# Total round rewards:2.2135948569269805
# Average loss: 0.0
# Epsilon: 0.08153936188758146
# Episode: 183
# Total round rewards:1.7187755182156916
# Average loss: 0.0
# Epsilon: 0.08097673223142907
# Episode: 184
# Total round rewards:2.6235386353913337
# Average loss: 0.0
# Epsilon: 0.080424139307507
# Episode: 185
# Total round rewards:1.6676876797057691
# Average loss: 0.0
# Epsilon: 0.07988140407087384
# Episode: 186
# Total round rewards:2.2642138969031667
# Average loss: 0.0
# Epsilon: 0.07934835067056498
# Episode: 187
# Total round rewards:1.6338599362872808
# Average loss: 0.0
# Epsilon: 0.07882480639261553
# Episode: 188
# Total round rewards:2.1173612895814156
# Average loss: 0.0
# Epsilon: 0.07831060160409942
# Episode: 189
# Total round rewards:1.5931300828085329
# Average loss: 0.0
# Epsilon: 0.07780556969816685
# Episode: 190
# Total round rewards:2.0132156195689928
# Average loss: 0.0
# Epsilon: 0.07730954704006222
# Episode: 191
# Total round rewards:1.6525238811622323
# Average loss: 0.0
# Epsilon: 0.0768223729141051
# Episode: 192
# Total round rewards:2.1990205654182713
# Average loss: 0.0
# Epsilon: 0.07634388947161677
# Episode: 193
# Total round rewards:1.6453832053492559
# Average loss: 0.0
# Epsilon: 0.07587394167977611
# Episode: 194
# Total round rewards:1.8997996628877283
# Average loss: 0.0
# Epsilon: 0.07541237727138737
# Episode: 195
# Total round rewards:1.626219568028161
# Average loss: 0.0
# Epsilon: 0.07495904669554443
# Episode: 196
# Total round rewards:1.9058841328455831
# Average loss: 0.0
# Epsilon: 0.07451380306917496
# Episode: 197
# Total round rewards:1.4555088784715138
# Average loss: 0.0
# Epsilon: 0.07407650212944895
# Episode: 198
# Total round rewards:2.0561516899506005
# Average loss: 0.0
# Epsilon: 0.07364700218703642
# Episode: 199
# Total round rewards:1.6454222528692837
# Average loss: 0.0
# Epsilon: 0.07322516408019868
# Episode: 200
# Total round rewards:1.705568199257884
# Average loss: 0.0
# Epsilon: 0.07281085112969886
# Episode: 201
# Total round rewards:1.5763055818227854
# Average loss: 0.0
# Epsilon: 0.07240392909451654
# Episode: 202
# Total round rewards:2.25219387036039
# Average loss: 0.0
# Epsilon: 0.07200426612835253
# Episode: 203
# Total round rewards:1.6376607683155142
# Average loss: 0.0
# Epsilon: 0.07161173273690952
# Episode: 204
# Total round rewards:1.9154339335650914
# Average loss: 0.0
# Epsilon: 0.07122620173593473
# Episode: 205
# Total round rewards:1.3591010163074517
# Average loss: 0.0
# Epsilon: 0.07084754821001121
# Episode: 206
# Total round rewards:2.1526135792010557
# Average loss: 0.0
# Epsilon: 0.07047564947208405
# Episode: 207
# Total round rewards:1.5809672791343392
# Average loss: 0.0
# Epsilon: 0.07011038502370877
# Episode: 208
# Total round rewards:2.153031633526802
# Average loss: 0.0
# Epsilon: 0.06975163651600871
# Episode: 209
# Total round rewards:1.617905516772521
# Average loss: 0.0
# Epsilon: 0.06939928771132903
# Episode: 210
# Total round rewards:2.154805754587364
# Average loss: 0.0
# Epsilon: 0.06905322444557462
# Episode: 211
# Total round rewards:1.4823088131520687
# Average loss: 0.0
# Epsilon: 0.06871333459121998
# Episode: 212
# Total round rewards:2.0965372449040784
# Average loss: 0.0
# Epsilon: 0.06837950802097892
# Episode: 213
# Total round rewards:1.5735859529411151
# Average loss: 0.0
# Epsilon: 0.06805163657212232
# Episode: 214
# Total round rewards:1.902513648395429
# Average loss: 0.0
# Epsilon: 0.06772961401143252
# Episode: 215
# Total round rewards:1.6730160185534735
# Average loss: 0.0
# Epsilon: 0.06741333600078275
# Episode: 216
# Total round rewards:2.266817003356384
# Average loss: 0.0
# Epsilon: 0.06710270006333074
# Episode: 217
# Total round rewards:1.8091702056216026
# Average loss: 0.0
# Epsilon: 0.0667976055503153
# Episode: 218
# Total round rewards:1.80358442351592
# Average loss: 0.0
# Epsilon: 0.0664979536084452
# Episode: 219
# Total round rewards:1.4582420915380883
# Average loss: 0.0
# Epsilon: 0.06620364714786989
# Episode: 220
# Total round rewards:1.9567655360406466
# Average loss: 0.0
# Epsilon: 0.06591459081072153
# Episode: 221
# Total round rewards:1.5014586089019186
# Average loss: 0.0
# Epsilon: 0.06563069094021819
# Episode: 222
# Total round rewards:2.001377541511231
# Average loss: 0.0
# Epsilon: 0.06535185555031822
# Episode: 223
# Total round rewards:1.3884821513368528
# Average loss: 0.0
# Epsilon: 0.06507799429591606
# Episode: 224
# Total round rewards:2.2284806209826953
# Average loss: 0.0
# Epsilon: 0.06480901844356948
# Episode: 225
# Total round rewards:1.4325280818832369
# Average loss: 0.0
# Epsilon: 0.06454484084274933
# Episode: 226
# Total round rewards:1.8913292602767555
# Average loss: 0.0
# Epsilon: 0.06428537589760185
# Episode: 227
# Total round rewards:1.612519697502418
# Average loss: 0.0
# Epsilon: 0.06403053953921502
# Episode: 228
# Total round rewards:1.9391846814686162
# Average loss: 0.0
# Epsilon: 0.06378024919837938
# Episode: 229
# Total round rewards:1.4446424926004613
# Average loss: 0.0
# Epsilon: 0.06353442377883495
# Episode: 230
# Total round rewards:2.116762776800969
# Average loss: 0.0
# Epsilon: 0.06329298363099525
# Episode: 231
# Total round rewards:1.689961500158836
# Average loss: 0.0
# Epsilon: 0.0630558505261403
# Episode: 232
# Total round rewards:2.110273370339203
# Average loss: 0.0
# Epsilon: 0.06282294763106962
# Episode: 233
# Total round rewards:1.631441185386612
# Average loss: 0.0
# Epsilon: 0.06259419948320777
# Episode: 234
# Total round rewards:1.9350824649697598
# Average loss: 0.0
# Epsilon: 0.062369531966153705
# Episode: 235
# Total round rewards:1.5362875799221671
# Average loss: 0.0
# Epsilon: 0.062148872285666526
# Episode: 236
# Total round rewards:1.8552717576243913
# Average loss: 0.0
# Epsilon: 0.06193214894607939
# Episode: 237
# Total round rewards:1.4633506037510269
# Average loss: 0.0
# Epsilon: 0.06171929172713435
# Episode: 238
# Total round rewards:1.8618235418707956
# Average loss: 0.0
# Epsilon: 0.06151023166123036
# Episode: 239
# Total round rewards:1.957919696396836
# Average loss: 0.0
# Epsilon: 0.061304901011077204
# Episode: 240
# Total round rewards:1.8647037009835388
# Average loss: 0.0
# Epsilon: 0.06110323324774799
# Episode: 241
# Total round rewards:1.4801211910844843
# Average loss: 0.0
# Epsilon: 0.060905163029123174
# Episode: 242
# Total round rewards:2.009240252938759
# Average loss: 0.0
# Epsilon: 0.060710626178719196
# Episode: 243
# Total round rewards:1.6501535824899798
# Average loss: 0.0
# Epsilon: 0.060519559664894675
# Episode: 244
# Total round rewards:1.7145845109052134
# Average loss: 0.0
# Epsilon: 0.0603319015804277
# Episode: 245
# Total round rewards:1.4925251036664748
# Average loss: 0.0
# Epsilon: 0.060147591122457225
# Episode: 246
# Total round rewards:1.7605875222872853
# Average loss: 0.0
# Epsilon: 0.05996656857278252
# Episode: 247
# Total round rewards:1.5846267152530074
# Average loss: 0.0
# Epsilon: 0.05978877527851387
# Episode: 248
# Total round rewards:1.7794524675529972
# Average loss: 0.0
# Epsilon: 0.0596141536330686
# Episode: 249
# Total round rewards:1.608729197268141
# Average loss: 0.0
# Epsilon: 0.05944264705750596
# Episode: 250
# Total round rewards:2.166702879846705
# Average loss: 0.0
# Epsilon: 0.05927419998219513
# Episode: 251
# Total round rewards:1.5909631413701564
# Average loss: 0.0
# Epsilon: 0.0591087578288101
# Episode: 252
# Total round rewards:1.8573171665713604
# Average loss: 0.0
# Epsilon: 0.05894626699264588
# Episode: 253
# Total round rewards:1.5426972993301402
# Average loss: 0.0
# Epsilon: 0.05878667482525007
# Episode: 254
# Total round rewards:2.073180270109998
# Average loss: 0.0
# Epsilon: 0.0586299296173643
# Episode: 255
# Total round rewards:1.4760175380042213
# Average loss: 0.0
# Epsilon: 0.05847598058217
# Episode: 256
# Total round rewards:1.7379286543443269
# Average loss: 0.0
# Epsilon: 0.05832477783883299
# Episode: 257
# Total round rewards:1.5022956885505088
# Average loss: 0.0
# Epsilon: 0.05817627239634172
# Episode: 258
# Total round rewards:1.9389055686474872
# Average loss: 0.0
# Epsilon: 0.058030416137633656
# Episode: 259
# Total round rewards:1.5413962816595432
# Average loss: 0.0
# Epsilon: 0.057887161804005036
# Episode: 260
# Total round rewards:1.7280340877040588
# Average loss: 0.0
# Epsilon: 0.05774646297979853
# Episode: 261
# Total round rewards:1.4779455382186975
# Average loss: 0.0
# Epsilon: 0.05760827407736429
# Episode: 262
# Total round rewards:2.0094503118879796
# Average loss: 0.0
# Epsilon: 0.05747255032228901
# Episode: 263
# Total round rewards:1.6521742877761352
# Average loss: 0.0
# Epsilon: 0.05733924773888873
# Episode: 264
# Total round rewards:2.103950147129386
# Average loss: 0.0
# Epsilon: 0.05720832313596028
# Episode: 265
# Total round rewards:1.3493327434338385
# Average loss: 0.0
# Epsilon: 0.057079734092786966
# Episode: 266
# Total round rewards:1.9864364475276741
# Average loss: 0.0
# Epsilon: 0.056953438945393904
# Episode: 267
# Total round rewards:1.6357550818531321
# Average loss: 0.0
# Epsilon: 0.0568293967730485
# Episode: 268
# Total round rewards:1.7606095435430107
# Average loss: 0.0
# Epsilon: 0.05670756738500176
# Episode: 269
# Total round rewards:1.454323677436699
# Average loss: 0.0
# Epsilon: 0.05658791130746619
# Episode: 270
# Total round rewards:1.806747505647127
# Average loss: 0.0
# Epsilon: 0.05647038977082592
# Episode: 271
# Total round rewards:1.4876456470098156
# Average loss: 0.0
# Epsilon: 0.056354964697074975
# Episode: 272
# Total round rewards:1.8266548767142554
# Average loss: 0.0
# Epsilon: 0.056241598687479716
# Episode: 273
# Total round rewards:1.459659968060225
# Average loss: 0.0
# Epsilon: 0.05613025501046129
# Episode: 274
# Total round rewards:1.9893776492681332
# Average loss: 0.0
# Epsilon: 0.0560208975896943
# Episode: 275
# Total round rewards:1.35471916068165
# Average loss: 0.0
# Epsilon: 0.05591349099241776
# Episode: 276
# Total round rewards:1.84003565108169
# Average loss: 0.0
# Epsilon: 0.05580800041795454
# Episode: 277
# Total round rewards:1.6529825287565496
# Average loss: 0.0
# Epsilon: 0.05570439168643568
# Episode: 278
# Total round rewards:1.9715988432367062
# Average loss: 0.0
# Epsilon: 0.05560263122772577
# Episode: 279
# Total round rewards:1.4681370851672622
# Average loss: 0.0
# Epsilon: 0.055502686070545995
# Episode: 280
# Total round rewards:1.9098967703046443
# Average loss: 0.0
# Epsilon: 0.0554045238317911
# Episode: 281
# Total round rewards:1.4496511496595337
# Average loss: 0.0
# Epsilon: 0.055308112706036985
# Episode: 282
# Total round rewards:2.022989788918213
# Average loss: 0.0
# Epsilon: 0.055213421455235494
# Episode: 283
# Total round rewards:1.3869903408293092
# Average loss: 0.0
# Epsilon: 0.05512041939859301
# Episode: 284
# Total round rewards:1.918045261738271
# Average loss: 0.0
# Epsilon: 0.05502907640262958
# Episode: 285
# Total round rewards:1.5701836232643074
# Average loss: 0.0
# Epsilon: 0.05493936287141544
# Episode: 286
# Total round rewards:1.7279913067842898
# Average loss: 0.0
# Epsilon: 0.05485124973698165
# Episode: 287
# Total round rewards:1.5268250471596467
# Average loss: 0.0
# Epsilon: 0.054764708449901826
# Episode: 288
# Total round rewards:2.146073473990439
# Average loss: 0.0
# Epsilon: 0.0546797109700419
# Episode: 289
# Total round rewards:1.7467454290239302
# Average loss: 0.0
# Epsilon: 0.054596229757474815
# Episode: 290
# Total round rewards:1.8570343355724381
# Average loss: 0.0
# Epsilon: 0.054514237763557405
# Episode: 291
# Total round rewards:1.446631968844142
# Average loss: 0.0
# Epsilon: 0.05443370842216637
# Episode: 292
# Total round rewards:1.7486925674538034
# Average loss: 0.0
# Epsilon: 0.05435461564109061
# Episode: 293
# Total round rewards:1.4256416697991712
# Average loss: 0.0
# Epsilon: 0.05427693379357716
# Episode: 294
# Total round rewards:1.9340676959486147
# Average loss: 0.0
# Epsilon: 0.05420063771002785
# Episode: 295
# Total round rewards:1.5581407561746512
# Average loss: 0.0
# Epsilon: 0.05412570266984416
# Episode: 296
# Total round rewards:1.9699877041464111
# Average loss: 0.0
# Epsilon: 0.05405210439341754
# Episode: 297
# Total round rewards:1.5733036075767044
# Average loss: 0.0
# Epsilon: 0.05397981903426258
# Episode: 298
# Total round rewards:1.7698894304600232
# Average loss: 0.0
# Epsilon: 0.053908823171290546
# Episode: 299
# Total round rewards:1.6017654964202697
# Average loss: 0.0
# Epsilon: 0.05383909380122077
# Episode: 300
# Total round rewards:2.0096037173590724
# Average loss: 0.0
# Epsilon: 0.053770608331127345
# Episode: 301
# Total round rewards:1.549918020580767
# Average loss: 0.0
# Epsilon: 0.05370334457111884
# Episode: 302
# Total round rewards:1.8455793345923224
# Average loss: 0.0
# Epsilon: 0.053637280727148594
# Episode: 303
# Total round rewards:1.5665258698939926
# Average loss: 0.0
# Epsilon: 0.05357239539395321
# Episode: 304
# Total round rewards:1.9066771451610973
# Average loss: 0.0
# Epsilon: 0.053508667548117124
# Episode: 305
# Total round rewards:1.5367352618921257
# Average loss: 0.0
# Epsilon: 0.05344607654126078
# Episode: 306
# Total round rewards:1.6725948268930553
# Average loss: 0.0
# Epsilon: 0.053384602093350414
# Episode: 307
# Total round rewards:1.430718696373981
# Average loss: 0.0
# Epsilon: 0.053324224286127105
# Episode: 308
# Total round rewards:1.8457031320687003
# Average loss: 0.0
# Epsilon: 0.05326492355665313
# Episode: 309
# Total round rewards:1.6467370007453974
# Average loss: 0.0
# Epsilon: 0.053206680690973375
# Episode: 310
# Total round rewards:2.107736961425411
# Average loss: 0.0
# Epsilon: 0.05314947681788984
# Episode: 311
# Total round rewards:1.6552394510633972
# Average loss: 0.0
# Epsilon: 0.05309329340284722
# Episode: 312
# Total round rewards:1.9747112459810292
# Average loss: 0.0
# Epsilon: 0.053038112241927546
# Episode: 313
# Total round rewards:1.5338707007197827
# Average loss: 0.0
# Epsilon: 0.05298391545595195
# Episode: 314
# Total round rewards:2.135287026460332
# Average loss: 0.0
# Epsilon: 0.05293068548468766
# Episode: 315
# Total round rewards:1.5949970436086938
# Average loss: 0.0
# Epsilon: 0.05287840508115832
# Episode: 316
# Total round rewards:1.990058199079004
# Average loss: 0.0
# Epsilon: 0.05282705730605583
# Episode: 317
# Total round rewards:1.4131257133143942
# Average loss: 0.0
# Epsilon: 0.052776625522251874
# Episode: 318
# Total round rewards:1.7561512358874576
# Average loss: 0.0
# Epsilon: 0.05272709338940731
# Episode: 319
# Total round rewards:1.6475261371435175
# Average loss: 0.0
# Epsilon: 0.05267844485867778
# Episode: 320
# Total round rewards:1.8546282844223012
# Average loss: 0.0
# Epsilon: 0.05263066416751375
# Episode: 321
# Total round rewards:1.7481026839580867
# Average loss: 0.0
# Epsilon: 0.052583735834553294
# Episode: 322
# Total round rewards:2.084840131543584
# Average loss: 0.0
# Epsilon: 0.052537644654605996
# Episode: 323
# Total round rewards:1.586856148815484
# Average loss: 0.0
# Epsilon: 0.05249237569372635
# Episode: 324
# Total round rewards:2.0377381913228634
# Average loss: 0.0
# Epsilon: 0.05244791428437501
# Episode: 325
# Total round rewards:1.6943151091267203
# Average loss: 0.0
# Epsilon: 0.05240424602066639
# Episode: 326
# Total round rewards:2.202436027379311
# Average loss: 0.0
# Epsilon: 0.05236135675370104
# Episode: 327
# Total round rewards:1.6328476534489658
# Average loss: 0.0
# Epsilon: 0.052319232586981256
# Episode: 328
# Total round rewards:1.76521381410039
# Average loss: 0.0
# Epsilon: 0.05227785987190853
# Episode: 329
# Total round rewards:1.383705719053041
# Average loss: 0.0
# Epsilon: 0.05223722520336122
# Episode: 330
# Total round rewards:1.7676997469532032
# Average loss: 0.0
# Epsilon: 0.05219731541535127
# Episode: 331
# Total round rewards:1.4910432887144567
# Average loss: 0.0
# Epsilon: 0.05215811757675821
# Episode: 332
# Total round rewards:1.8369027226229786
# Average loss: 0.0
# Epsilon: 0.05211961898713944
# Episode: 333
# Total round rewards:1.602736278695579
# Average loss: 0.0
# Epsilon: 0.052081807172615124
# Episode: 334
# Total round rewards:2.057363437989459
# Average loss: 0.0
# Epsilon: 0.052044669881826586
# Episode: 335
# Total round rewards:1.4968404211098578
# Average loss: 0.0
# Epsilon: 0.052008195081966725
# Episode: 336
# Total round rewards:1.9609674885868587
# Average loss: 0.0
# Epsilon: 0.0519723709548813
# Episode: 337
# Total round rewards:1.7308942610433133
# Average loss: 0.0
# Epsilon: 0.05193718589323975
# Episode: 338
# Total round rewards:1.9429626268631053
# Average loss: 0.0
# Epsilon: 0.05190262849677429
# Episode: 339
# Total round rewards:1.802105987771816
# Average loss: 0.0
# Epsilon: 0.051868687568586154
# Episode: 340
# Total round rewards:1.916774611357951
# Average loss: 0.0
# Epsilon: 0.0518353521115177
# Episode: 341
# Total round rewards:1.5674700049617052
# Average loss: 0.0
# Epsilon: 0.051802611324589215
# Episode: 342
# Total round rewards:1.9651159370455498
# Average loss: 0.0
# Epsilon: 0.051770454599499305
# Episode: 343
# Total round rewards:1.5342910959971363
# Average loss: 0.0
# Epsilon: 0.051738871517187736
# Episode: 344
# Total round rewards:1.8583319695858092
# Average loss: 0.0
# Epsilon: 0.05170785184445956
# Episode: 345
# Total round rewards:1.512754499387724
# Average loss: 0.0
# Epsilon: 0.051677385530669424
# Episode: 346
# Total round rewards:1.83038209024959
# Average loss: 0.0
# Epsilon: 0.05164746270446516
# Episode: 347
# Total round rewards:1.350661536058898
# Average loss: 0.0
# Epsilon: 0.0516180736705893
# Episode: 348
# Total round rewards:1.709408245652139
# Average loss: 0.0
# Epsilon: 0.051589208906737766
# Episode: 349
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 9
#       6 mgr_num = row["mgr"]
#       7 mgr = mgr_networks[mgr_num]
# ----> 9 state = torch.tensor(env.get_state(), dtype=torch.float32, device=device).unsqueeze(0)
#      10 action = select_action(state, mgr["policy"], env, device)
#      11 observation, reward, terminated, info = env.step(action.item())
#
# KeyboardInterrupt:

# %%
# plot losses for each manager
for i, loss in losses.items():
    plt.plot(loss)
# add legend for each manager
plt.legend([f"Mgr {i}" for i in losses.keys()])
plt.ioff()
plt.show()

# %%
# pd.set_option('display.max_rows', None)  # Show all rows
# pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.width', None)  # Automatically adjust the display width
# pd.set_option('display.max_colwidth', None)  # Show full content of each column
# # display(env.draft.loc[env.draft["mgr"] == 0])
# display(env.)
# pd.reset_option('display.max_rows')
# pd.reset_option('display.max_columns')
# pd.reset_option('display.width')
# pd.reset_option('display.max_colwidth')

print(env.draft.loc[env.draft["mgr"] == 0])
# env.compute_reward(1)

for i in range(NUM_MGRS):
    print(f"Manager {i} reward: {env.compute_reward(i)}")
# Out:
#      round  mgr sleeper_id            full_name team position   fp_mean  \
# 0        0    0       4984           Josh Allen  BUF       QB       1.0
# 23       1    0       4892       Baker Mayfield   TB       QB  0.736689
# 24       2    0       8155          Breece Hall  NYJ       RB  0.714236
# 47       3    0       8205        Isiah Pacheco   KC       RB  0.584847
# 48       4    0       5850          Josh Jacobs   GB       RB  0.580631
# 71       5    0       7611  Rhamondre Stevenson   NE       RB  0.487682
# 72       6    0       7611  Rhamondre Stevenson   NE       RB  0.487682
# 95       7    0       6130     Devin Singletary  NYG       RB  0.450854
# 96       8    0      11533       Brandon Aubrey  DAL        K  0.375178
# 119      9    0      11533       Brandon Aubrey  DAL        K  0.375178
# 120     10    0      11533       Brandon Aubrey  DAL        K  0.375178
# 143     11    0       5248          Gus Edwards  LAC       RB  0.356908
# 144     12    0       5248          Gus Edwards  LAC       RB  0.356908
# 167     13    0       8134        Khalil Shakir  BUF       WR  0.341044
# 168     14    0       9224          Chase Brown  CIN       RB   0.33311
#
#         fp_std
# 0    51.322362
# 23   30.119865
# 24   25.676804
# 47   19.167158
# 48   26.584809
# 71   22.999671
# 72   22.999671
# 95   32.788531
# 96    4.589032
# 119   4.589032
# 120   4.589032
# 143  34.333775
# 144  34.333775
# 167  18.868019
# 168  25.849831
# Manager 0 reward: 0.05444825289315424
# Manager 1 reward: 0.05069990880021744
# Manager 2 reward: 0.04996091414545714
# Manager 3 reward: 0.06091928493522075
# Manager 4 reward: 0.06117545042606684
# Manager 5 reward: 0.06587074177894844
# Manager 6 reward: 0.05344269984338702
# Manager 7 reward: 0.058150298496738854
# Manager 8 reward: 0.05477281579245727
# Manager 9 reward: 0.020333646912953716
# Manager 10 reward: 0.05868411108878583
# Manager 11 reward: 0.038928783079250705
